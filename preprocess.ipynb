# %%
import os
import json
import re
from tqdm import tqdm
import pickle
import itertools
import networkx as nx
from matplotlib import pyplot as plt
import networkx

# %%
from bokeh.io import output_notebook, show, save
from bokeh.models import Range1d, Circle, ColumnDataSource, MultiLine, EdgesAndLinkedNodes, NodesAndLinkedEdges, LabelSet
from bokeh.plotting import figure
from bokeh.plotting import from_networkx
from bokeh.palettes import Blues8, Reds8, Purples8, Oranges8, Viridis8, Spectral8
from bokeh.transform import linear_cmap
from networkx.algorithms import community

# %%
path = './final_proj/'
files = sorted(os.listdir(path))

# %%
N = len(files)

# %%
N
# Out:
# 298694

# %%
with open('companies_vc.txt', 'r') as f:
    companies_vc = f.read()

# %%
len(companies_vc.split('\n'))
# Out:
# 474

# %%
companies_vc = companies_vc.split('\n')

# %%
with open('companies_habr.txt', 'r') as f:
    companies_habr = f.read()

# %%
len(companies_habr.split('\n'))
# Out:
# 18020

# %%
companies_habr = companies_habr.split('\n')

# %%
companies = set(companies_vc).union(set(companies_habr))

# %%
data = 0
with open(path + files[100100]) as json_file:
    data = json.load(json_file)

# %%
data.keys()
# Out:
# dict_keys(['message', 'result'])

# %%
data['result'].keys()
# Out:
# dict_keys(['id', 'url', 'author', 'badges', 'commentsCount', 'commentsSeenCount', 'favoritesCount', 'cover', 'date', 'dateRFC', 'date_favorite', 'last_modification_date', 'hitsCount', 'intro', 'introInFeed', 'isEnabledComments', 'isEnabledLikes', 'isFavorited', 'isRepost', 'likes', 'subsite', 'similar', 'title', 'type', 'entryContent', 'commentatorsAvatars', 'webviewUrl', 'isPinned', 'canEdit', 'etcControls', 'highlight', 'blocks', 'subscribedToTreads', 'is_show_thanks', 'is_still_updating', 'is_filled_by_editors', 'isEditorial', 'audioUrl', 'hotness', 'commentEditor', 'summarize'])

# %%
data['result']['likes']
# Out:
# {'is_liked': 0, 'count': 21, 'summ': 21, 'is_hidden': False}

# %%
data['result']['intro']
# Out:
# 'Пользователи TJ и Nintendo Switch делятся мнением о октябрьских релизах.'

# %%
data['result']['blocks']
# Out:
# [{'type': 'text',
#   'data': {'text': 'Пользователи TJ и Nintendo Switch делятся мнением о октябрьских релизах.',
#    'text_truncated': '<<<same>>>'},
#   'cover': True,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'media',
#   'data': {'items': [{'title': '\u200bАрт к игре «The Witcher 3: Wild Hunt»',
#      'author': '',
#      'image': {'type': 'image',
#       'data': {'uuid': '7d93dd4e-8f42-f9a5-b0b6-c9d1a9ae5329',
#        'width': 1920,
#        'height': 1016,
#        'size': 469401,
#        'type': 'jpg',
#        'color': '344543',
#        'hash': '',
#        'external_service': []}}}],
#    'with_background': False,
#    'with_border': False},
#   'cover': True,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Вот и подошла к концу середина осени. Октябрь был не самым насыщенным месяцем для гибридной консоли, однако, несколько громких и необычных релизов всё-таки было. Пользователи TJ поделились своими впечатлениями для ежемесячной рубрики.',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'header',
#   'data': {'text': '«Ori and the Blind Forest: Definitive Edition»',
#    'style': 'h3'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '**Платформа**: Nintendo Switch',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'video',
#   'data': {'video': {'type': 'video',
#     'data': {'thumbnail': {'type': 'image',
#       'data': {'uuid': '2163fa95-3a4d-cee2-2bcd-714f88af3418',
#        'width': 1280,
#        'height': 720,
#        'size': 196543,
#        'type': 'jpg',
#        'color': 'c55449',
#        'hash': '',
#        'external_service': []}},
#      'width': 800,
#      'height': 450,
#      'time': 0,
#      'external_service': {'name': 'youtube', 'id': 'PFnardzPg-I'}}},
#    'title': ''},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '***Автор**: [Syldys Nya](https://tjournal.ru/u/7535-syldys-nya)*',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Ori — отличный платформер. Думаю, многие уже в неё поиграли на ПК. Игра известная и получила очень много хороших отзывов от критиков и рядовых игроков. Все, что они говорят про игру, правда, они не врут. Я ещё в прошлом году хотела в неё поиграть, поэтому во время очередных скидок купила ее на Xbox. Но я очень странный человек, не люблю играть перед тв. В итоге через пару минут блуждания по карте отложила игру до лучших времён.',
#    'text_truncated': '<p>Ori — отличный платформер. Думаю, многие уже в неё поиграли на ПК. Игра известная и получила очень много хороших отзывов от критиков и рядовых игроков. Все, что они говорят про игру, правда, они не врут. Я ещё в прошлом году хотела в неё поиграть, поэтому во время очередных скидок купила ее на Xbox. Но я очень странный человек, не люблю играть…</p>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Было красиво, движения героя были плавные и быстрые. История трогательная. Но именно из-за того, что надо сидеть перед тв, я забросила игру. 4К, 60 fps, большая картинка и тд — вот это все мне по итогу не так важно, как возможность валяться в кровати и деградировать со свитчом в руках, лол. Поэтому когда Ori вышел на свитч, я ее решила купить и снова попробовать. Да и стоит у нас не больше $20. Через пару часов игры ни разу не пожалела о том, что купила ее дважды. Очень красиво, интересно, бодро. Местами было сложновато, но это меня абсолютно не оттолкнуло от игры.',
#    'text_truncated': '<p>Было красиво, движения героя были плавные и быстрые. История трогательная. Но именно из-за того, что надо сидеть перед тв, я забросила игру. 4К, 60 fps, большая картинка и тд — вот это все мне по итогу не так важно, как возможность валяться в кровати и деградировать со свитчом в руках, лол. Поэтому когда Ori вышел на свитч, я ее решила купить и…</p>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Очень нравится, что точку сохранения можно сделать почти где угодно. Нет специальных мест, где ты воскрешаешься. Самое забавное, что от игры у меня почти не горела жопа. Обычно игры меня заставляют материться и гореть от злости во время прохождения. С этой же игрой я была немного спокойнее. Хотелось бы верить в то, что повзрослела и успокоилась, и вещи вокруг воспринимаю с терпением Будды. Но это очень вряд ли. Думаю, что дело в игре.',
#    'text_truncated': '<p>Очень нравится, что точку сохранения можно сделать почти где угодно. Нет специальных мест, где ты воскрешаешься. Самое забавное, что от игры у меня почти не горела жопа. Обычно игры меня заставляют материться и гореть от злости во время прохождения. С этой же игрой я была немного спокойнее. Хотелось бы верить в то, что повзрослела и успокоилась,…</p>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Как итог хочу сказать, что те, кто не играл в неё, то абсолютно точно дайте ей шанс на свитч. Если же уже поиграли в неё, то подождите скидок (чёрная пятница и Рождество) и тоже купите. Мне кажется, опыт прохождения этой игры на свитч будет отличаться от опыта на ПК и Xbox. П.С. Я ещё прохожу ее. Застряла на уровне, где надо от совы сбежать. Бесючая птица.',
#    'text_truncated': '<p>Как итог хочу сказать, что те, кто не играл в неё, то абсолютно точно дайте ей шанс на свитч. Если же уже поиграли в неё, то подождите скидок (чёрная пятница и Рождество) и тоже купите. Мне кажется, опыт прохождения этой игры на свитч будет отличаться от опыта на ПК и Xbox. П.С. Я ещё прохожу ее. Застряла на уровне, где надо от совы сбежать.…</p>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'header',
#   'data': {'text': '«Overwatch: Legendary Edition»', 'style': 'h3'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '**Платформа**: Nintendo Switch',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'video',
#   'data': {'video': {'type': 'video',
#     'data': {'thumbnail': {'type': 'image',
#       'data': {'uuid': 'b333ee7d-5239-f517-e1be-1ada40518bb9',
#        'width': 1280,
#        'height': 720,
#        'size': 209160,
#        'type': 'jpg',
#        'color': 'ede6db',
#        'hash': '',
#        'external_service': []}},
#      'width': 800,
#      'height': 450,
#      'time': 0,
#      'external_service': {'name': 'youtube', 'id': 'i39Pgu_36H0'}}},
#    'title': ''},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '***Автор**: [Авдеев](https://tjournal.ru/u/29796-avdeev)*',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'О выходе популярного онлайн шутер для гибридной консоли я мечтал давно. Кто бы что не говорил, но Overwatch был действительно необходим для Nintendo, особенно для продвижения её Online подписки. Как известно, на Switch особо нет онлайн игр, и выход известной игры был глотком свежего воздуха. Скажу сразу, да графон порезан и чисто внешне он поход на Overwatch на минималках для компьютера, НО, играю в портативном режиме вы этого не заметите.',
#    'text_truncated': '<p>О выходе популярного онлайн шутер для гибридной консоли я мечтал давно. Кто бы что не говорил, но Overwatch был действительно необходим для Nintendo, особенно для продвижения её Online подписки. Как известно, на Switch особо нет онлайн игр, и выход известной игры был глотком свежего воздуха. Скажу сразу, да графон порезан и чисто внешне он поход…</p>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Однако, вы заметите 30 fps, которые будут сильно чувствоваться, если до этого играли на PC, PS4, xBox. Сперва это будет крайне непривычно, вам будет казаться, что всё не так плавно, но со временем привыкните. Да, это тот компромисс, на который пришлось пойти ради портативности, но я вас уверяю, что катка в Overwatch вне дома ни с чем не сравнится.',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Я рад, что онлайн в игре очень хороший. Найти себе игру можно за 2 минуты, и это не в аркадном режиме, что, естественно, очень здорово. На D\\*F много писали про лаги, баги, проседания, это всё было на старте игры. Для справедливости отмечу, что с такими же проблемами сталкивалась и PC версия. Управление не самое привычное, особенно если до этого у вас была клавомышь. Очень огорчает лютый геморой с голосовым общением, который надо провернуть через отдельное приложение для телефона. Это лютые костыли, которыми занимаются далеко не все, а общение тут очень пригодилось бы.',
#    'text_truncated': '<p>Я рад, что онлайн в игре очень хороший. Найти себе игру можно за 2 минуты, и это не в аркадном режиме, что, естественно, очень здорово. На D*F много писали про лаги, баги, проседания, это всё было на старте игры. Для справедливости отмечу, что с такими же проблемами сталкивалась и PC версия. Управление не самое привычное, особенно если до этого у…</p>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'В итоге, я бы посоветовал взять эту игру тем, кто хочет играть в онлайне со своего Switch. Обыгравшись в Splatoon, я понял, что выбора в онлайн стрелялках на Nintendo особо и нет. Overwatch это возможность быстро славить фана в онлайне. Особенно я советую к ней присмотреться на фоне анонса второй части, которая выйдет также и на Nintendo Switch.',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'header',
#   'data': {'text': '«The Witcher 3: Wild Hunt - Complete Edition»',
#    'style': 'h3'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '**Платформа**: Nintendo Switch',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'video',
#   'data': {'video': {'type': 'video',
#     'data': {'thumbnail': {'type': 'image',
#       'data': {'uuid': '58dbffab-5fd0-d6d1-2395-bb573b763a0c',
#        'width': 1280,
#        'height': 720,
#        'size': 216564,
#        'type': 'jpg',
#        'color': '494436',
#        'hash': '',
#        'external_service': []}},
#      'width': 800,
#      'height': 450,
#      'time': 0,
#      'external_service': {'name': 'youtube', 'id': 'tU1XdkELVPE'}}},
#    'title': ''},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '***Автор**: [Micro](https://tjournal.ru/u/69459-micro)*',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Вичер на сыч портировали очень хорошо. Можно конечно поныть про 540р и лоу-рез, но как это часто говорится - никто не заставляет вас покупать игру, тем более когда она доступна на других платформах. Зато тем, кто мечтал играть в ведьмака в портативе, преподнесли офигенный порт, который выглядит и играется намного лучше, чем другие aaa-игры каррент-гена, которые пытались портировать на сыч. Единственное, до чего хочется докопаться, так это не самая лучшая реализация управления: я все время путаюсь в кнопках, чувствуется, что сделать можно было немного удобнее.',
#    'text_truncated': '<p>Вичер на сыч портировали очень хорошо. Можно конечно поныть про 540р и лоу-рез, но как это часто говорится - никто не заставляет вас покупать игру, тем более когда она доступна на других платформах. Зато тем, кто мечтал играть в ведьмака в портативе, преподнесли офигенный порт, который выглядит и играется намного лучше, чем другие aaa-игры…</p>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'В остальном порт получился просто шикарный, при всех недостатках графики я не ожидал такого качества картинки на железе свича. Мыло не бросается в глаза вообще, как это было, например, с Xenoblade Chronicles 2, которая вообще эксклюзив приставки, но работает раз в 100 хуже, чем польский возьмак.',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Я наиграл уже больше 20 часов и могу сказать, что удовольствия сейчас от нее получают намного больше, чем когда проходил ее на пк. Если уж портировать игры карент-гена на свич, то делать это надо как портировали вичера, а не как портировали дум или вольфенштейн. Я правда очень доволен портом и он явно превзошел мои ожидания',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'header',
#   'data': {'text': '«Ring Fit Adventure»', 'style': 'h2'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '**Платформа**: Nintendo Switch',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'video',
#   'data': {'video': {'type': 'video',
#     'data': {'thumbnail': {'type': 'image',
#       'data': {'uuid': '691598e5-a851-6b0d-33fc-222a573b0fe5',
#        'width': 1280,
#        'height': 720,
#        'size': 285142,
#        'type': 'jpg',
#        'color': '577e55',
#        'hash': '',
#        'external_service': []}},
#      'width': 800,
#      'height': 450,
#      'time': 0,
#      'external_service': {'name': 'youtube', 'id': 'wvHELogbm2E'}}},
#    'title': ''},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '***Автор**: [Авдеев](https://tjournal.ru/u/29796-avdeev)*',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Не буду лукавить, когда впервые показали трейлер с этой игрой и чудо кольцом, я от души посмеялся, ведь выглядело это крайне нелепо. Однако, так случалось, что приобрести кольцо стало семейным решением и поздним вечером я был выслан в ближайший магазин электроники.',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Набор выглядел вполне добротно: большая коробка с игрой и с двумя аксессуарами произвели хорошее впечатление. Качество кольца порадовало, липучка на ногу вся такая брендированная, а приставка отлично отзывается из любого угла комнаты. Сама игра не представляет из себя чего-то неординарного в плане сюжета, естественно, он здесь чисто для галочки.',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Но что касается геймплейной части, то она великолепна. С первого запуска вас подробно расспрашивают про вашу физическую подготовку, вес, рост, измеряют пульс (!!!), что стало для меня открытием, ведь я и не знал, что джой коны умеют такое. В игре присутствует кампания, где медленно, но верно вас настраивают на интенсивные тренировки, отдельные мини-игры и просто разминка. Чтобы перемещаться, вам необходимо бежать на месте и паралельно с этим сжимать кольцо, чтобы перепрыгивать препятствия, собирать монетки (для покупки здоровья) и разжимать кольцо, чтобы отбрасывать что-либо. Периодически у вас будут некие битвы, где необходимо будет выполнять настоящие упражнения.',
#    'text_truncated': '<p>Но что касается геймплейной части, то она великолепна. С первого запуска вас подробно расспрашивают про вашу физическую подготовку, вес, рост, измеряют пульс (!!!), что стало для меня открытием, ведь я и не знал, что джой коны умеют такое. В игре присутствует кампания, где медленно, но верно вас настраивают на интенсивные тренировки, отдельные…</p>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': 'Хочу отметить, что результат действительно чувствуется. После 30 минут игры вы почувствуете усталость, одежду можно будет выжимать, а тренер в игре будет продолжать кричать «Давай, ты сможешь ещё!». Это очень необычный опыт, здорово, что Nintendo знает, как можно использовать особенности своей гибридной консоли.',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'delimiter',
#   'data': {'type': 'default'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '*Материал написал благодаря участникам телеграм канала [Zeldachat](https://t.me/joinchat/HOOB7Eu_e8KdkoUUgQzMDw). Сообщество любителей приставок компании Nintendo и пользователей TJ.*',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''},
#  {'type': 'text',
#   'data': {'text': '[\\#tjиграет](https://tjournal.ru/tag/tj%D0%B8%D0%B3%D1%80%D0%B0%D0%B5%D1%82) [\\#игры](https://tjournal.ru/tag/%D0%B8%D0%B3%D1%80%D1%8B)',
#    'text_truncated': '<<<same>>>'},
#   'cover': False,
#   'hidden': False,
#   'anchor': ''}]

# %%
extracted_words = {}
for j in tqdm(range(N)):
    with open(path + files[j]) as json_file:
        data = json.load(json_file)
    num_blocks = len(data['result']['blocks'])
    extracted_words_set = set()
    
    for i in range(num_blocks):
        if data['result']['blocks'][i]['type'] == 'text' or data['result']['blocks'][i]['type'] == 'header':
            extracted_words_set = extracted_words_set.union(set(re.findall(r'«[\w]+»', data['result']['blocks'][i]['data']['text'])))
            #print(re.findall(r'[\s]?[A-Z][A-Za-z]+[\s]|[\s]?[А-Я][А-Яа-я]+[\s]', data['result']['blocks'][i]['data']['text']))
            extracted_words_set = extracted_words_set.union(set(re.findall(r'[A-Z][A-Za-z]*[\.][A-Z][A-Za-z]*|[А-Я][А-Яа-я]*[\.][А-Я][А-Яа-я]*', data['result']['blocks'][i]['data']['text'])))
            extracted_words_set = extracted_words_set.union(set(re.findall(r'[A-Z]+[^a-z]|[А-Я]+[^а-я]', data['result']['blocks'][i]['data']['text'])))
            extracted_words_set = extracted_words_set.union(set(re.findall(r'[A-Z][a-z]+|[А-Я][а-я]+', data['result']['blocks'][i]['data']['text'])))

    extracted_words[files[j]] = [item.lower() for item in extracted_words_set]
    #        print(data['result']['blocks'][i]['data']['text'].split())
# Out:
# 100%|██████████████████████████████████| 298694/298694 [11:33<00:00, 430.86it/s]

# %%
extracted_words
# Out:
# {'0000000002': ['бумаги',
#   'fredirect',
#   'f2',
#   '«воскресенье»',
#   'казачьим',
#   '«ирбис»',
#   'dhttp',
#   'a%',
#   '«бумаги»',
#   'ирбис»',
#   'f0',
#   'fbeta',
#   'петербурге',
#   'f1',
#   'f)',
#   'f%',
#   'fwww',
#   'в ',
#   'furl',
#   'воскресенье',
#   'корреспондент'],
#  '0000000003': ['сноуденом',
#   'fredirect',
#   'whisper',
#   'secure',
#   'a%',
#   'fblog',
#   'text',
#   'fwhatsapp',
#   'ftextsecure',
#   'fgithub',
#   'fwhispersystems',
#   'fbeta',
#   'dhttps',
#   'пока',
#   'whats',
#   'f)',
#   'app',
#   'f%',
#   'используемый',
#   'последняя',
#   'эдвардом',
#   'furl',
#   'systems',
#   'android'],
#  '0000000004': ['phone',
#   'марсель',
#   'фильо',
#   'фернандес',
#   'plus',
#   'предыдущий',
#   'samsung',
#   'подросток',
#   'марселем',
#   'fleksy',
#   'бразилии',
#   'гиннесса',
#   'galaxy',
#   's4'],
#  '0000000005': ['чо'],
#  '0000000006': ['лихачев', 'ваши'],
#  '0000000007': [],
#  '0000000010': ['а ', 'tj ', 'давайте'],
#  '0000000012': ['лебедева',
#   'приставка',
#   'в ',
#   'артемия',
#   'hdmi-',
#   'созданием'],
#  '0000000013': ['tj', 'у '],
#  '0000000014': ['некрасивый'],
#  '0000000015': ['apple', 'популярный', 'tj ', 'существенная', 'отныне'],
#  '0000000016': ['а ',
#   'сми]',
#   'ed%',
#   'fru',
#   'tj]',
#   'd0',
#   'farticles',
#   'однако',
#   'житель',
#   'a%',
#   'ук ',
#   'ee%',
#   'e7',
#   'такая',
#   'fv',
#   'f0',
#   'текст',
#   'e5',
#   'f6',
#   'e9',
#   'e6',
#   'ижевска',
#   'f)',
#   'e3',
#   'f%',
#   'fwiki',
#   'fanekdot',
#   'e8',
#   'fc%',
#   'fstory',
#   'ec%',
#   'ftvrain',
#   'eb%',
#   'e0',
#   'fpikabu',
#   'рф.'],
#  '0000000017': ['при', 'app', 'в ', 'whats'],
#  '0000000018': ['apple',
#   'watch',
#   'с ',
#   'sdk ',
#   'также',
#   'xc',
#   'kit',
#   'code',
#   'os '],
#  '0000000019': ['как'],
#  '0000000020': ['apple',
#   'тимченко',
#   'tj',
#   'tj ',
#   'тджорнал»',
#   'клуб',
#   'наши',
#   'ооо ',
#   'галины',
#   'на',
#   '«тджорнал»',
#   'journal'],
#  '0000000021': ['роман',
#   'ну',
#   'рф»',
#   'некий',
#   'собираем',
#   'худяков',
#   'как',
#   'лдпр)',
#   'о ',
#   'госдуму',
#   'рф.'],
#  '0000000022': ['между',
#   'михаилом',
#   'лесиным',
#   'медиа',
#   'попытаться',
#   'газпром',
#   'эха',
#   'москвы',
#   '«эха»'],
#  '0000000023': ['gta ',
#   'официальный',
#   'переиздание',
#   'ps4',
#   'xbox',
#   'one',
#   'грабители'],
#  '0000000024': ['при', 'hl ', 'с ', 'tauri', 'alma ', 'уникальность'],
#  '0000000025': ['пользователи', 'fov)'],
#  '0000000029': ['кндр,',
#   'юг',
#   'в ',
#   'корее',
#   'северной',
#   'севера',
#   'европейского'],
#  '0000000030': ['условия', 'бесплатный', 'guvera', 'вс', 'россии'],
#  '0000000031': ['google', 'как', 'вы'],
#  '0000000032': ['gta ', 'в ', 'v ', 'франклин', 'у '],
#  '0000000033': ['цб ', 'в '],
#  '0000000034': ['музей', 'паблик'],
#  '0000000035': ['арабский', 'the', 'в ', 'испанский', 'village', 'китайский'],
#  '0000000037': [],
#  '0000000038': ['phone', 'apple', 'по', 'цены', 'plus'],
#  '0000000039': ['компания',
#   'f2',
#   'f)',
#   'f1',
#   'f%',
#   'fnypost',
#   'fuber',
#   'a%',
#   'в ',
#   'uber'],
#  '0000000040': ['v ',
#   'игроки',
#   'play',
#   'xbox',
#   'one',
#   'gta ',
#   'station',
#   'для',
#   '«волшебные»'],
#  '0000000041': ['людмила',
#   'продюсеры',
#   'd ',
#   'первая',
#   'руслан',
#   'александра',
#   'пушкина',
#   'горько',
#   'фильмы'],
#  '0000000042': ['hd ',
#   'd ',
#   'digital',
#   'в ',
#   'blu',
#   'стражей',
#   'dvd ',
#   'галактики'],
#  '0000000043': ['fi', 'wi-', 'у ', 'скоро'],
#  '0000000044': ['g ', 'huawei ', 'китайский', 'россии'],
#  '0000000045': ['fmain',
#   'vevo',
#   'a%',
#   'wired',
#   'video',
#   'funny',
#   'fsamsung',
#   'f)',
#   'die',
#   'f%',
#   'сша.',
#   'fwww',
#   'fgadgets',
#   'samsung',
#   'milk',
#   'fgoogle',
#   'его',
#   'galaxy'],
#  '0000000047': ['госдума'],
#  '0000000048': ['малефисента',
#   'джин',
#   'тимоти',
#   'интерстеллар',
#   'хлоя',
#   'грей',
#   'грейс',
#   'бен',
#   'железная',
#   'на',
#   'роу',
#   'фаннинг',
#   'циклопа',
#   'не',
#   'хейли',
#   'чаламет',
#   'харди',
#   'эль',
#   'морец',
#   'в ',
#   'чарли',
#   'стайнфелд'],
#  '0000000050': ['возникший',
#   'f1',
#   'чуть',
#   'f%',
#   'fmkadfire',
#   'дтп ',
#   'мкад',
#   'сколковского',
#   'fwww',
#   'frussia',
#   'a%',
#   'на',
#   'энтузиастов',
#   'да'],
#  '0000000051': ['по', 'всего', '«заразы»', 'компьютерные'],
#  '0000000052': ['дуров',
#   'whats',
#   'f1',
#   'app',
#   'f%',
#   'telegram',
#   'fwww',
#   'fvillage',
#   'a%',
#   'в ',
#   'павла',
#   'fhopesandfears',
#   'fnews'],
#  '0000000053': ['однако',
#   'доктора',
#   'доктор',
#   'кто',
#   'в ',
#   'питер',
#   'капальди'],
#  '0000000054': ['faddons',
#   'ffjnbnpbmkenffdnngjfgmeleoegfcffe',
#   'chrome',
#   'fru',
#   'firefox',
#   'a%',
#   'fdetail',
#   'измен',
#   'ffirefox',
#   'предлагайте',
#   'fchrome',
#   'не',
#   'f)',
#   'f%',
#   'dru',
#   'fwebstore',
#   'fhl',
#   'убран',
#   'faddon',
#   'fstylish',
#   'панель',
#   'убраны'],
#  '0000000055': ['play',
#   'устройств',
#   'доверенных',
#   'распознавание',
#   'smart',
#   'lock',
#   'servises',
#   'опция',
#   'android',
#   'google'],
#  '0000000056': ['over', 'стена', 'wall', 'сволочи'],
#  '0000000057': ['конахи',
#   'оскар',
#   'мак',
#   'аллее',
#   'интерстеллар',
#   '«интерстеллар»',
#   'поддержать',
#   'нолан',
#   'обладатель',
#   '«оскар»',
#   'мэттью',
#   'кристофер',
#   'он'],
#  '0000000059': ['fprezi',
#   'платформа',
#   'f)',
#   'f%',
#   'a%',
#   'prezi',
#   'около',
#   'по'],
#  '0000000060': ['текст'],
#  '0000000062': ['услугой',
#   'фразы',
#   'f%',
#   'что',
#   'xbox',
#   'fxboxuk',
#   'engadget',
#   'a%',
#   'kinect',
#   'uk]',
#   'fstatus',
#   'ftwitter',
#   'domino',
#   'f5'],
#  '0000000063': ['свердловской', 'жители', 'зарево'],
#  '0000000064': ['анатолия',
#   'автомобилист',
#   'голышева',
#   'тифа',
#   'по',
#   'спортсмен'],
#  '0000000065': ['во', 'жао', 'в ', 'зонгвей', 'хефей', 'разговор'],
#  '0000000066': ['когда'],
#  '0000000067': ['cern ',
#   'ученые',
#   'открытие',
#   'вселенной',
#   'обнаруженные',
#   'большом'],
#  '0000000068': ['петербурга',
#   'краснодара',
#   'москвы',
#   'екатеринбурга',
#   'санкт',
#   'подобные',
#   'операции',
#   'хирург'],
#  '0000000069': ['к ', 'еще', 'да'],
#  '0000000070': ['этот'],
#  '0000000071': ['текст'],
#  '0000000073': ['fmice',
#   'f%',
#   'techreport',
#   'dpdf',
#   'ftechreport',
#   'группа',
#   'италии',
#   'fget',
#   'a%',
#   'tor',
#   'id%',
#   'd1',
#   'индии',
#   'сша,'],
#  '0000000074': ['японии', 'флипбук', 'теперь'],
#  '0000000075': ['tj,', 'хотел', 'но'],
#  '0000000076': ['сша ', 'в ', 'выпало'],
#  '0000000077': ['британская',
#   'королевства',
#   'соединенного',
#   'nats,',
#   'великобритании'],
#  '0000000078': ['f2',
#   'f)',
#   'руб',
#   'f%',
#   'эта',
#   'fpost',
#   'a%',
#   'fhabrahabr',
#   'голдберг',
#   'адам',
#   'магьяр'],
#  '0000000080': ['победительницей',
#   'баитова',
#   'краса',
#   'россии',
#   'татьяна',
#   'курганской',
#   'победительница'],
#  '0000000081': ['волин', 'попытки', 'минкомсвязи', 'алексей'],
#  '0000000082': ['текст'],
#  '0000000083': ['oculus',
#   'марка',
#   'лондоне',
#   'у ',
#   'художник',
#   'фарида',
#   'эксперимент',
#   'rift',
#   'великобритании'],
#  '0000000084': ['fox ',
#   'нил',
#   'лютеров',
#   'снимать',
#   '«лютеров»',
#   'на',
#   'эльба',
#   '«клим»',
#   'клим',
#   'кросс',
#   'россии'],
#  '0000000085': ['команда',
#   'университета',
#   'бахрамом',
#   'bahram',
#   'в ',
#   'qr-',
#   'коннектикута',
#   'джавиди',
#   'javidi',
#   'это'],
#  '0000000086': ['артдокфест',
#   '«артдокфест»',
#   'мединский',
#   'министр',
#   'манского',
#   'владимир',
#   'виталия',
#   'он',
#   'россии'],
#  '0000000087': ['азимова',
#   'джонатан',
#   'основание',
#   '«основание»',
#   'интерстеллар',
#   '«интерстеллар»',
#   'тё',
#   'западный',
#   'мементо',
#   'в ',
#   '«мементо»',
#   'нолан',
#   'айзека'],
#  '0000000088': ['вашингтоне', 'видео', 'действие', 'набирает', 'сша.'],
#  '0000000089': ['yo',
#   'the',
#   'qj',
#   'vo7',
#   'oi',
#   'ko',
#   'di',
#   'd0',
#   'молли',
#   'dhttp',
#   'zy',
#   'a%',
#   'lug',
#   'ftjournal',
#   'zhu',
#   'ab%',
#   'da%',
#   'ag',
#   'qf',
#   'fwww',
#   'fnot',
#   'fj',
#   'хэмингуэй',
#   'dafq',
#   'fo0',
#   'dinternal',
#   'mqqyw',
#   'pm',
#   'iw',
#   'cnh9',
#   'federalist',
#   'bg',
#   'wf',
#   'f%',
#   'агрессивное',
#   'fq',
#   'fpaper',
#   'yh',
#   'furl',
#   'ca',
#   'ft',
#   'du%',
#   'py',
#   'yk'],
#  '0000000090': ['film',
#   'вам',
#   'выживут',
#   'сквозь',
#   'одержимость',
#   'отрочество',
#   'известный',
#   'в ',
#   'стрингер'],
#  '0000000091': ['милонову', 'только'],
#  '0000000092': ['матрицу', 'скоро'],
#  '0000000093': ['предполагается',
#   'f%',
#   'fwww',
#   'британский',
#   'flunar',
#   'фотографии',
#   'a%',
#   'днк ',
#   'fprojects',
#   'луну',
#   'f5'],
#  '0000000094': ['этот'],
#  '0000000095': ['звукорежессиры',
#   'bros',
#   'интерстеллар',
#   'warner',
#   '«интерстеллар»',
#   'soundworks',
#   'collection',
#   'сайт'],
#  '0000000096': ['бесконечное', 'лето', 'стиме', 'популярная'],
#  '0000000097': ['f2',
#   'mozilla',
#   'яндекс',
#   'firefox',
#   'a%',
#   'fblog',
#   'изменения',
#   'yahoo',
#   'компания',
#   'f)',
#   'f1',
#   'f%',
#   'сша.',
#   'fpromoting',
#   'что',
#   '«яндекс»'],
#  '0000000098': ['например',
#   'производители',
#   'нежный',
#   'путин',
#   'добрейшей',
#   'в ',
#   'президент',
#   'добрый',
#   'плачущий',
#   'владимир',
#   'ввп ',
#   'россии'],
#  '0000000099': ['цб ',
#   'россии',
#   'оао ',
#   'глава',
#   'visa',
#   'национальная',
#   'торре',
#   'нспк)',
#   'эндрю'],
#  '0000000100': ['компания', 'parrot', 'bebop'],
#  '0000000101': ['согласно', 'вирус', 'lookout', 'android'],
#  '0000000102': ['mirai', 'японский', '«mirai»', 'toyota', 'по', 'новый'],
#  '0000000103': ['луганска', 'не', 'хочу', 'нет', 'он'],
#  '0000000104': ['этот', 'пишет', 'ксения', 'я ', 'message', 'да'],
#  '0000000105': ['но', 'путин', '«двадцатки»'],
#  '0000000106': ['fchrome',
#   'foiaejidbmkiecgbjeifoejpgmdaleoha',
#   'если',
#   'вы',
#   'f%',
#   'chrome',
#   'fwebstore',
#   'tj ',
#   'вас',
#   'a%',
#   'stylebot',
#   'fstylebot',
#   'fdetail'],
#  '0000000107': ['f2',
#   'f1',
#   'f%',
#   'fslideshow',
#   'брауна',
#   'potcritic.',
#   'fwww',
#   'встречайте',
#   'ffashion',
#   'a%',
#   'круче',
#   'джейка',
#   'f0'],
#  '0000000108': ['джобса',
#   'бэйлом',
#   'ди',
#   'кинокомпания',
#   'переговоры',
#   'кристианом',
#   'вот',
#   'каприо',
#   'леонардо'],
#  '0000000109': ['поаплодируем'],
#  '0000000110': ['по', 'грузовые', 'россией', 'калининградской'],
#  '0000000111': ['пока',
#   'tj ',
#   'буффало',
#   'полеты',
#   'джим',
#   'послезавтра',
#   'грималди',
#   'на'],
#  '0000000112': ['буду'],
#  '0000000113': ['всего',
#   'необходимые',
#   'f2',
#   'f)',
#   'f1',
#   'f%',
#   'fjolla',
#   'fwww',
#   'fprojects',
#   'nokia',
#   'a%',
#   'flenta',
#   'fnews'],
#  '0000000114': ['fr',
#   'кремниевой',
#   'a%',
#   'daily',
#   'farticle',
#   'knightscope',
#   'mail',
#   'f%',
#   'fwww',
#   'fsciencetech',
#   'valley',
#   'k5',
#   'помимо',
#   'silicon',
#   'по',
#   'robo',
#   'американская'],
#  '0000000115': ['королева',
#   'она',
#   'в ',
#   'елизавета',
#   'величество',
#   'ii ',
#   'ее'],
#  '0000000116': ['tj', 'я ', 'на', 'делал'],
#  '0000000117': ['российское',
#   'более',
#   'владимир',
#   'прич',
#   'российского',
#   'салуянов'],
#  '0000000118': ['прощай', 'tj.', 'я ', 'tj ', 'и ', 'tj,', 'это'],
#  '0000000119': ['а ', 'если', 'tj!', 'tj '],
#  '0000000121': ['компания', 'спустя', 'сша ', 'mica,', 'intel'],
#  '0000000123': ['но', 'джефф', 'смит'],
#  '0000000124': ['fnrt',
#   'f)',
#   'любители',
#   'f%',
#   'fwww',
#   'a%',
#   'android',
#   'для',
#   'скачать'],
#  '0000000126': ['jolla',
#   'sailfish',
#   'удивительно',
#   'накануне',
#   'os ',
#   'tablet'],
#  '0000000128': ['дурова', 'великолепная', 'павла', 'мирилашвили', 'вк '],
#  '0000000129': ['рейхентал', 'как', 'ави', 'd-', 'разница'],
#  '0000000130': ['the',
#   'подробная',
#   'полученными',
#   'f1',
#   'f%',
#   'fwww',
#   'village',
#   'career',
#   'fvillage',
#   'a%',
#   'fhopesandfears',
#   'по',
#   'fnews',
#   'hr-'],
#  '0000000131': ['и ', 'если'],
#  '0000000132': ['view',
#   'для',
#   'обновление',
#   'street',
#   'google',
#   'html ',
#   'maps'],
#  '0000000133': ['компания',
#   'mac',
#   'app',
#   'первым',
#   'store',
#   'form',
#   'relative',
#   'wave',
#   'google'],
#  '0000000134': ['мы',
#   'как',
#   'обратившись',
#   'теперь',
#   'вчера',
#   'и ',
#   'александрии'],
#  '0000000135': ['мы', 'в ', 'вы'],
#  '0000000136': ['блан', 'жюльен', 'более', 'по', 'blanc', 'julien', 'англию'],
#  '0000000137': ['он', 'видите', 'а ', 'иногда'],
#  '0000000138': ['стивом',
#   'мак',
#   'юкатана',
#   'куином',
#   'downey',
#   'пиратов',
#   'rosio',
#   'team',
#   'различные',
#   'карибского',
#   'сценарий',
#   'terry'],
#  '0000000139': ['cut',
#   'паула',
#   'вашингтон',
#   'youtube',
#   'video',
#   'you',
#   'дейдра',
#   'доротея'],
#  '0000000140': ['f)',
#   'сериал',
#   'f%',
#   'кросс',
#   'fwww',
#   'прошло',
#   'ник',
#   'a%',
#   'fnews',
#   'f5'],
#  '0000000141': ['высшей', 'в ', 'сп', 'пб', 'у ', 'гу '],
#  '0000000142': ['warfare', 'точных', 'advanced', 'activision'],
#  '0000000143': ['элон', 'маск'],
#  '0000000144': ['привет',
#   'p.s',
#   's.',
#   'стандартные',
#   'roman',
#   'но',
#   'узкие',
#   'как',
#   'на',
#   'new',
#   'p.',
#   'times'],
#  '0000000145': ['что', 'буффало'],
#  '0000000147': ['автор',
#   'спутник',
#   'drake',
#   'k,',
#   'землей',
#   'james',
#   'л,',
#   'timelapse',
#   'земли',
#   'электро',
#   'л ',
#   'tyrwhitt'],
#  '0000000148': ['кажется'],
#  '0000000149': ['the', 'observer', 'немного', 'в '],
#  '0000000150': ['state',
#   'джейсон',
#   'facebook',
#   'сам',
#   'студент',
#   'university',
#   'florida',
#   'дерфьюсс'],
#  '0000000151': ['виктор',
#   'об',
#   'федеральной',
#   'наркоманы',
#   'иванов',
#   'он',
#   'россии'],
#  '0000000153': ['mail',
#   'представив',
#   'контакте',
#   'ru',
#   '«вконтакте»',
#   'экспресс',
#   'mail.ru',
#   'вот',
#   'live ',
#   'вк'],
#  '0000000157': ['анастасия',
#   'яров',
#   'сергей',
#   'повседневная',
#   'ленинграда',
#   'кдпв ',
#   'в ',
#   'кто',
#   'как',
#   'ася',
#   'казанцева'],
#  '0000000161': ['прикрепить', 'аналогичная'],
#  '0000000162': ['а ',
#   'f2',
#   'первое',
#   'ои',
#   'fsap)',
#   'бонусом',
#   'fru',
#   'fgoogleglass',
#   'a%',
#   'fvimeo',
#   'на',
#   'fsiliconrus',
#   'то',
#   'google',
#   'р.',
#   'glass',
#   'f1',
#   'f)',
#   'f%',
#   'fwiki',
#   'sap '],
#  '0000000163': ['текст'],
#  '0000000164': ['мэтта', 'сми,', 'тейлора', 'официальными'],
#  '0000000165': ['minecraft',
#   'christopher',
#   'лондонская',
#   'андре',
#   'tate',
#   'derain',
#   'невинсона',
#   'кристофера',
#   'andr',
#   'дерена',
#   'nevinson'],
#  '0000000166': ['phone', 'москве', 'devices', 'на', 'официальная', 'yota'],
#  '0000000167': ['d8',
#   'fmt',
#   'os]',
#   'notebook',
#   'photoshop',
#   'a%',
#   'adobe',
#   'fitunes',
#   'illustrator',
#   'fus',
#   'fid',
#   'графические',
#   'fmoleskine',
#   'f%',
#   'smart',
#   'с ',
#   'moleskine',
#   'fapp'],
#  '0000000169': ['f%', 'вероятно', 'fvk', 'мда', 'a%', 'fwall', 'павел', 'вк '],
#  '0000000170': ['ангелов',
#   'finstagram',
#   'f%',
#   "о'",
#   'девушка',
#   'комик',
#   'анджелеса',
#   'лорен',
#   'также',
#   'instagram',
#   'города',
#   'a%',
#   'брайэн',
#   'fthelaurenobrien',
#   'лос'],
#  '0000000171': ['александре', 'алексей', 'мамуте', 'новый', 'гореславский'],
#  '0000000172': ['расследование',
#   'боинг',
#   'малазийский',
#   'украины',
#   'зрк ',
#   'youtube',
#   'mh1',
#   'на',
#   'интернет',
#   'бук ',
#   'россии'],
#  '0000000173': ['во',
#   'bad',
#   'солу',
#   'amc ',
#   'breaking',
#   'премьера',
#   'saul',
#   'better',
#   'хронологически',
#   'call',
#   'лучше',
#   'американский'],
#  '0000000175': ['некоторые', 'но', 'буквально', 'tj ', 'хотя', 'у ', 'да'],
#  '0000000176': ['один', 'сначала', 'reddit'],
#  '0000000177': ['the',
#   'wolf',
#   'всего',
#   'mac',
#   'os.',
#   'xbox',
#   'game',
#   'ps4',
#   'telltale',
#   'us',
#   'pc,',
#   'thrones',
#   'games',
#   'dead',
#   'among',
#   'walking',
#   'в ',
#   'выйдет',
#   'ps3',
#   'one'],
#  '0000000178': ['ubisoft', 'unity', 'только', 'creed', 'assassin'],
#  '0000000179': ['рост', 'apple', 'в '],
#  '0000000180': ['fnatgeoru',
#   'россия',
#   'привет',
#   'finstagram',
#   'f%',
#   'instagram',
#   'geographic',
#   'a%',
#   'national'],
#  '0000000182': ['то', 'украинской', 'это', 'россии', 'сегодня', 'казахстане'],
#  '0000000184': ['«неформат»', 'tj»', 'клуб'],
#  '0000000185': ['дурова',
#   'мы',
#   'тимченко',
#   'telegram',
#   'он',
#   'контакте',
#   'мда',
#   'галины',
#   'павла',
#   'материал',
#   'вк',
#   'вчера'],
#  '0000000186': ['стивен', 'kinect', 'эдвард', 'разработчик'],
#  '0000000187': ['плюс', 'такие', 'sap ', 'hana.'],
#  '0000000189': ['c4',
#   'hanna',
#   'вы',
#   'f%',
#   'анна',
#   'c6',
#   'fobojnak',
#   'fwww',
#   'тушина',
#   'a%',
#   'jachimska',
#   'на',
#   'яхимска',
#   'flodz'],
#  '0000000190': ['кпрф ', 'представляю', 'депутат', 'соловьев', 'вадим'],
#  '0000000191': ['не', 'никто', 'приезжай', 'евромайдана'],
#  '0000000192': ['митрополит',
#   'он',
#   'о ',
#   'кирилловский',
#   'согласно',
#   'вологодский'],
#  '0000000193': ['nv',
#   'zs',
#   'la',
#   'наследование',
#   'gd',
#   'па',
#   'видео',
#   'a%',
#   'rr',
#   'fwatch',
#   'dl',
#   'fv',
#   'vo',
#   'инкапсуляция',
#   'ro',
#   'f%',
#   '«па»',
#   'fwww',
#   'dj',
#   'выбор',
#   'как',
#   'youtube',
#   'rc',
#   'полиморфизм'],
#  '0000000194': ['к ', 'короткий', 'розетта', '«розетта»', 'исландии'],
#  '0000000195': ['картинки', 'вк.', 'у '],
#  '0000000196': ['сми.',
#   'харриса',
#   'работники',
#   'бич',
#   'снимок',
#   'нью',
#   'смирна',
#   'taco',
#   'bell',
#   'харрис',
#   'габриэль'],
#  '0000000197': ['джерард',
#   'лиза',
#   'данэм',
#   'батлер',
#   'лена',
#   'сэндлер',
#   'бритни',
#   'кудроу',
#   'в ',
#   'спирс',
#   'крис',
#   'пэлтроу',
#   'адам',
#   'гвинет',
#   'прэтт'],
#  '0000000198': ['компания',
#   'futurefon',
#   'dragonfly',
#   'idealfuture',
#   'изначально'],
#  '0000000199': ['f2',
#   'tube',
#   'f%',
#   'flistings',
#   'fwww',
#   'a%',
#   'fmag',
#   'you',
#   'fpeople',
#   'все'],
#  '0000000200': ['kickstarter',
#   'достижение',
#   'вы',
#   'на',
#   'вашем',
#   'зато',
#   'eyeteleporter'],
#  '0000000201': ['будущее'],
#  '0000000202': ['обсуждение',
#   'роскомнадзор',
#   'fgeektimes',
#   '«хабрахабру»',
#   'f2',
#   'f)',
#   'git',
#   'f%',
#   'hub',
#   'хабрахабру',
#   'fpost',
#   'a%',
#   'предыдущая',
#   'geek',
#   'times'],
#  '0000000203': ['такую', 'theatres', 'сша.', 'для', 'paramount', 'amc '],
#  '0000000205': ['«неправильные»',
#   'ну',
#   'mozilla',
#   'f%',
#   'a%',
#   'как',
#   'fstatus',
#   'ftwitter',
#   'ffirefox',
#   'f5',
#   'кнопка'],
#  '0000000206': ['nike', 'apple', 'ребята', 'volkswagen'],
#  '0000000207': ['к ', 'timelaps', 'гб', 'ar '],
#  '0000000208': ['спойлер',
#   'никиты',
#   'добрый',
#   'я ',
#   'tj.',
#   'viber',
#   'диалоги'],
#  '0000000209': ['be%',
#   'ba%',
#   'fdata',
#   'feed',
#   'b%',
#   'buzz',
#   'd0',
#   'b2',
#   'c1',
#   'a%',
#   'a0',
#   'd%',
#   'fmaps',
#   'c%',
#   'c3',
#   'bb.',
#   'великобритании',
#   'bb%',
#   'fheres',
#   'странные',
#   'f%',
#   'b1',
#   'fwww',
#   'вобля',
#   'fplace',
#   'fpatricksmith',
#   'вот',
#   'd1',
#   'b0'],
#  '0000000210': ['этот'],
#  '0000000211': ['google'],
#  '0000000212': ['бараку',
#   'blackberry',
#   'ad',
#   'репорт',
#   'bloomberg',
#   'a%',
#   'fstatus',
#   'сша,',
#   'обаме',
#   'f%',
#   'fdougmillsnyt',
#   'ny ',
#   'я ',
#   'free',
#   'как',
#   'ftwitter',
#   'f5',
#   'times'],
#  '0000000213': ['черной', 'политика', 'walmart', 'этим', 'перед'],
#  '0000000214': ['а ',
#   'спустя',
#   'os.',
#   'chrome',
#   'доступно',
#   'photoshop',
#   'adobe',
#   'но',
#   'js.',
#   'google',
#   'd.'],
#  '0000000215': ['в ', 'f1', 'opt ', 'сша ', 'b,', 'h1'],
#  '0000000216': ['стэнфордского',
#   'команда',
#   'человек',
#   'fstanfords',
#   'f2',
#   'f1',
#   'f)',
#   'f%',
#   'вдохновил',
#   'паук',
#   'fsingularityhub',
#   'a%',
#   'f0'],
#  '0000000217': ['три', 'оказывается', 'в '],
#  '0000000218': ['the',
#   'bbc.',
#   'f2',
#   'a%',
#   'york',
#   'на',
#   'fopinions',
#   'f0',
#   'f)',
#   'любимые',
#   'f%',
#   'fwww',
#   'fwp',
#   'huffington',
#   'guardian',
#   'cnn,',
#   'fthe',
#   'в ',
#   'post',
#   'new',
#   'fnews',
#   'washington',
#   'times'],
#  '0000000219': ['phone',
#   'apple',
#   'в ',
#   'министерства',
#   'сша ',
#   'больше',
#   'представители'],
#  '0000000220': ['media',
#   'tns.',
#   'вконтакте',
#   'digital',
#   'gazprom',
#   'число',
#   'gpmd)',
#   'это'],
#  '0000000227': ['по', 'сша ', 'источник', 'reddit'],
#  '0000000228': ['fdesigned', 'a%', 'в ', 'apple', 'f%', 'coub', 'fwww'],
#  '0000000229': ['credo',
#   'f)',
#   'f%',
#   'ru',
#   'михаила',
#   'fportal',
#   'a%',
#   'credo.ru',
#   'как',
#   'баранова',
#   'портала'],
#  '0000000230': ['северо',
#   'аграрно',
#   'университете',
#   'лесном',
#   'но',
#   'в ',
#   'шэньси',
#   'западном'],
#  '0000000231': ['к ',
#   'пекинского',
#   'beijing',
#   'студент',
#   'university',
#   'цзили',
#   'geely',
#   'нападавший'],
#  '0000000232': ['ян', 'яну', 'когда', 'бизнесмен'],
#  '0000000233': ['к"', 'о ', 'турист', 'колизея', 'единственное', 'россии'],
#  '0000000234': ['флагман',
#   'rgb ',
#   'motorola',
#   'led ',
#   'google',
#   'root',
#   'скорее'],
#  '0000000235': ['работа',
#   'technology',
#   'a%',
#   'mailing',
#   'international',
#   'f)',
#   'fucking',
#   'f%',
#   'fwww',
#   'advanced',
#   'научный',
#   'excellent',
#   'get',
#   'your',
#   'list',
#   'computer',
#   'journal'],
#  '0000000236': ['ну',
#   'l-',
#   'vyal',
#   'hz',
#   'th',
#   'a%',
#   'f3',
#   'eve ',
#   'dlwtb',
#   'cw',
#   'fuc',
#   'fchannel',
#   'gd',
#   'f%',
#   'fwww',
#   'online',
#   'несколько',
#   'l0',
#   'rw'],
#  '0000000237': ['показать', 'предлагаю', 'tj ', 'после', 'клуб'],
#  '0000000238': ['ali', 'известная', 'за', 'на', 'express'],
#  '0000000239': ['этот',
#   'nature',
#   'ребята',
#   'machines',
#   'android',
#   'устройством'],
#  '0000000240': ['у '],
#  '0000000241': ['первую',
#   'мишель',
#   'obama',
#   'thanks',
#   'michelle',
#   'белый',
#   'по',
#   'школьники',
#   'этим',
#   '«поблагодарили»',
#   'обамы'],
#  '0000000242': ['fpsychologies',
#   'f)',
#   'f%',
#   'fwww',
#   'рецензии',
#   'a%',
#   'электронная',
#   'подарок',
#   'fbooks',
#   'fawaken'],
#  '0000000243': ['f)',
#   'открыты',
#   'f%',
#   'cubic',
#   'что',
#   'fcubicrobotics',
#   'a%',
#   'российских',
#   'сайт'],
#  '0000000244': ['robbaz', 'far', 'cry', 'летсплеер', 'стоит'],
#  '0000000246': ['такая', 'google', 'хотя', 'translate'],
#  '0000000247': ['хотел', 'просьба', 'мне', 'самый', 'у '],
#  '0000000248': ['операция', 'беларуси', 'в ', 'причиной'],
#  '0000000249': ['радио',
#   'белорусское',
#   'никиту',
#   'свобода',
#   'и ',
#   'т-',
#   'редакции'],
#  '0000000250': ['во', 'индию', 'а ', 'интернетом', 'земли', 'индонезию'],
#  '0000000251': ['российский',
#   'спутник',
#   'л"',
#   'электро',
#   'земли',
#   'образовач'],
#  '0000000252': ['priebe', 'как', 'на', 'patrick', 'мощность', '«стрельбы»'],
#  '0000000253': ['правда'],
#  '0000000254': ['арнолд',
#   'нерахер',
#   'v.',
#   'kamikaze',
#   'жисси',
#   'байк',
#   'франсуа',
#   'ракетную',
#   'хотя'],
#  '0000000255': ['gen', 'в ', 'сингапур', 'd ', 'next'],
#  '0000000256': ['go', 'ролик', 'буффало', 'pro', 'редкое'],
#  '0000000257': ['висмейер', 'nfc-', 'в ', 'nfc.', 'мартин', 'bitcoin'],
#  '0000000258': ['somnus"', 'устав'],
#  '0000000259': ['тони',
#   'мартина',
#   'эй',
#   'зима',
#   'в ',
#   'повесть',
#   'старк',
#   'игры',
#   'джонстона'],
#  '0000000260': ['рекомендую'],
#  '0000000261': ['а ', 'чатиками"'],
#  '0000000262': ['джоли', 'в ', 'актриса', 'tjournal', 'анджелина', 'ой'],
#  '0000000263': ['mail', 'apple', 'моя', 'россии', 'iphone', 'это'],
#  '0000000264': ['этот'],
#  '0000000265': ['nasa ', 'давно', 'изучением', 'ученые'],
#  '0000000266': ['duck',
#   'marvel',
#   'стражи',
#   'чип',
#   'куинонс',
#   'здарски',
#   'howard',
#   'за',
#   'галактики',
#   'говард',
#   'ранее',
#   'джо'],
#  '0000000267': ['почты',
#   'министерство',
#   'россии',
#   'сочи',
#   'никифоров',
#   'николай',
#   'дней'],
#  '0000000268': ['текст'],
#  '0000000270': ['установлено', 'phone', 'ооо ', 'бор', 'на', 'вскоре'],
#  '0000000272': ['исследовать', 'vr ', 'головой', 'oculus', 'они'],
#  '0000000273': ['основатель', 'на', 'майкл', 'illegal!', 'ольсен'],
#  '0000000275': ['wi',
#   'loon',
#   'сети',
#   'проект',
#   'project',
#   'на',
#   'fi',
#   'google'],
#  '0000000276': ['fiportal',
#   'и ',
#   'fp',
#   'f%',
#   'f9',
#   'всем',
#   'украины',
#   'novyny',
#   'it.',
#   'fn',
#   'a%',
#   'на',
#   'fnews',
#   'вр ',
#   'povidomlennya'],
#  '0000000277': ['почти',
#   '«сыендук»',
#   'что',
#   'космос',
#   'николая',
#   'нолана',
#   'кристофера',
#   'носова',
#   'сыендук'],
#  '0000000278': ['зарядить', 'xoo ', 'belt', 'идея'],
#  '0000000280': ['человеческое', 'в '],
#  '0000000281': ['chromebook', 'если', 'tb ', 'pixel', 'для', 'gb'],
#  '0000000282': ['огайо', 'кливленде', 'на', 'звонивший'],
#  '0000000283': ['the',
#   'warfare',
#   'far',
#   'gotham',
#   'auto',
#   'collection',
#   'master',
#   'lego',
#   'call',
#   'station',
#   'fifa ',
#   'grand',
#   'duty',
#   'age',
#   'dragon',
#   'advanced',
#   'batman',
#   'minecraft',
#   'chief',
#   'v.',
#   'halo',
#   'unity',
#   'beyond',
#   'assassin',
#   'wwe ',
#   'cry',
#   'creed',
#   'edition',
#   'play',
#   'theft',
#   'инквизиция',
#   'k1'],
#  '0000000284': ['bbc ',
#   'f%',
#   'ими',
#   'ждем',
#   'tj!',
#   'fvk',
#   'fdecaying',
#   'a%',
#   'репортеры'],
#  '0000000285': ['этот'],
#  '0000000286': ['если',
#   'google',
#   'яндекса',
#   'market',
#   'explay',
#   'play',
#   'gms ',
#   'все'],
#  '0000000287': ['но'],
#  '0000000288': ['the', 'будут', 'star', 'force', 'disney', 'awakens', 'wars'],
#  '0000000289': ['художница',
#   'f2',
#   'f%',
#   'fmedia',
#   'fwww',
#   'fset',
#   'де',
#   'fearth',
#   'сара',
#   'fstory',
#   'было',
#   'a%',
#   'd3',
#   'da',
#   'ремер'],
#  '0000000290': ['led ',
#   'будущее',
#   'тутонги',
#   'с ',
#   'майкла',
#   'на',
#   'kickstarter',
#   'он'],
#  '0000000292': ['центр',
#   'луркоморье',
#   '«луркоморье»',
#   'кадырове',
#   'полицию',
#   'молотова',
#   'мвд ',
#   'рамзане'],
#  '0000000293': ['проиллюстрировав', 'омска', 'образоваче'],
#  '0000000294': ['znak',
#   'f2',
#   'dnevnov',
#   'некоторые',
#   'furfo',
#   'fvk',
#   'a%',
#   'лобушкин',
#   'tj,',
#   'fcontent',
#   'павел',
#   'fpavel',
#   'сми ',
#   'ранее',
#   'fyandsearch',
#   'дуров',
#   'd2',
#   'fscience',
#   'f1',
#   'dalldocs',
#   'мк]',
#   'f%',
#   'fwww',
#   'fraznoe',
#   'в ',
#   'fwall',
#   'fnews',
#   'георгий',
#   'finterests'],
#  '0000000295': ['с ', 'команда', 'принстонского', 'в '],
#  '0000000296': ['кэти',
#   'f2',
#   'f1',
#   'flirtmoji',
#   'f%',
#   'калифорнии',
#   'fwww',
#   'мак',
#   'группа',
#   'карти',
#   'f7',
#   'a%',
#   'по',
#   'fflirtmoji'],
#  '0000000297': ['f2',
#   'мануэля',
#   'fmanuel',
#   'ffrance',
#   'мануэль',
#   'a%',
#   'fnord',
#   'f1',
#   'пост',
#   'f%',
#   'fwww',
#   'ffbid',
#   'в ',
#   'd7',
#   'fphoto',
#   'd1',
#   'da'],
#  '0000000298': ['a%',
#   'fstatus',
#   'american',
#   'direction',
#   'music',
#   'джерри',
#   'f%',
#   'правда',
#   'drew',
#   'kenyon',
#   'началось',
#   'fd',
#   'fjrtoh',
#   'совсем',
#   'awards',
#   'ftwitter',
#   'one',
#   'f5'],
#  '0000000299': ['the',
#   'детали',
#   'европейского',
#   'союза',
#   'по.',
#   'в ',
#   'сноуден',
#   'intercept',
#   'сша ',
#   'эдвард',
#   'ранее',
#   'великобритании',
#   'belgacom'],
#  '0000000301': ['view',
#   'street',
#   'яндекс',
#   'максюков',
#   'фотограф',
#   'панорамы',
#   'google',
#   'он',
#   'даниил'],
#  '0000000302': ['сибирский',
#   'европа',
#   'реклама',
#   'плюс',
#   'несколько',
#   'алексеем',
#   'гурман',
#   'тумановым',
#   'даниловым',
#   'рунете'],
#  '0000000303': ['brown',
#   'тем',
#   'fhashtag',
#   'йоркских',
#   'wt.',
#   'a%',
#   'f7',
#   'dtop',
#   'decision',
#   'f)',
#   'суд',
#   'fwww',
#   'dtren',
#   'fripm',
#   'homepage',
#   'dclick',
#   'fdwtsfinale',
#   'flive',
#   'd1',
#   'fmichael',
#   'f2',
#   'ftwitter',
#   'fnation',
#   'нью',
#   'fferguson',
#   'f1',
#   'f%',
#   'ff',
#   'ferguson',
#   'dh',
#   'ripm',
#   'fstory',
#   'dphoto',
#   'mike',
#   'в ',
#   'fhp',
#   'fnews',
#   'fsrc',
#   'твиттера'],
#  '0000000304': ['разработчики',
#   'flirtmoji',
#   'калифорнии',
#   'f%',
#   'fu',
#   'fwww',
#   'message',
#   'safari',
#   'a%',
#   'должно',
#   'на',
#   'f5'],
#  '0000000305': ['нефтяная', 'освобождение', 'бесплатно', 'право'],
#  '0000000306': ['phone',
#   'apple',
#   'акция',
#   'blackberry',
#   'канаде',
#   'точная',
#   'shop',
#   'passport',
#   'berry',
#   'сша ',
#   'владельцы',
#   'amazon',
#   'black'],
#  '0000000307': ['райлли',
#   'история',
#   'фаррелла',
#   'келли',
#   'мак',
#   'фаррелл',
#   'вон',
#   'рэйчел',
#   'винса',
#   'адамс',
#   'колина',
#   'тейлор',
#   'китч',
#   'кроме',
#   'вона'],
#  '0000000308': ['по', 'p3', 'nexus', 'на'],
#  '0000000309': ['гарвардского', 'исследователи', 'полученные', 'такие'],
#  '0000000311': ['universal',
#   'джобса',
#   'спустя',
#   'sony',
#   'фассбендер',
#   'бойл',
#   'дэнни',
#   'на',
#   'майкл'],
#  '0000000312': ['сша ', 'в '],
#  '0000000313': ['рпц ', 'на'],
#  '0000000314': ['born', 'индия', 'internet', 'мтс ', 'просто'],
#  '0000000315': ['trubat', 'дизайнер', 'lesia'],
#  '0000000318': ['fchrome',
#   'is',
#   'f%',
#   'chrome',
#   'fwebstore',
#   'все',
#   'расширение',
#   'ftime',
#   'a%',
#   'money',
#   'fdetail',
#   'google',
#   'fooppbnomdcjmoepangldchpmjhkeendl',
#   'time',
#   'скачать'],
#  '0000000319': ['fyoutu',
#   'd2',
#   'f%',
#   'фергюсона',
#   'fsw',
#   'у ',
#   'a%',
#   'в ',
#   'ju',
#   'uwc',
#   'ft',
#   'ta',
#   'момент',
#   'wk',
#   'aqm'],
#  '0000000320': ['fwylsacom',
#   'apple',
#   'если',
#   'тем',
#   'f%',
#   'store',
#   'wylsacom',
#   'fru',
#   'a%',
#   'fstore',
#   'ftwitter',
#   'блогер',
#   'россии'],
#  '0000000321': ['magic', 'city', 'festival', 'quebec'],
#  '0000000322': ['пока', 'в '],
#  '0000000323': ['но', 'в ', 'теперь', 'никита', 'срок', 'белых'],
#  '0000000324': ['f)',
#   'когда',
#   'f%',
#   'fdaves',
#   'fwww',
#   'сегодня',
#   'шта»',
#   'fbuzzfeeds',
#   'a%',
#   'funexplainable',
#   'buzzfeed',
#   'pizza',
#   'farticle',
#   '«шта»',
#   'totino'],
#  '0000000325': ['йельским',
#   'к ',
#   'каролиной',
#   'выглядит',
#   'панорама',
#   'в ',
#   'фейк',
#   'на',
#   'северной'],
#  '0000000326': ['текст'],
#  '0000000328': ['текст'],
#  '0000000329': ['motors', 'европе', 'маск', 'элон', 'tesla', 'bmw '],
#  '0000000330': ['tj', 'комментарии'],
#  '0000000331': ['ежегодно', 'apple', 'в ', 'watch', 'time'],
#  '0000000332': ['rss ', 'судя', 'рунета', 'рунету', 'сегодня', 'премия'],
#  '0000000333': ['гб ', 'phone', 'за', 'цены', 'plus'],
#  '0000000334': ['текст'],
#  '0000000335': ['f)',
#   'be',
#   'f%',
#   'go',
#   'a%',
#   'в ',
#   'fmedgadgets',
#   'heal',
#   'и '],
#  '0000000336': ['apple', 'car', 'android', 'google', 'play', 'auto', 'и '],
#  '0000000337': ['поттере',
#   'review',
#   'роузом',
#   'glow',
#   'business',
#   'harward',
#   'cap',
#   'гарри',
#   'дэвидом'],
#  '0000000338': ['при',
#   'поправки',
#   '«пиратским»',
#   'теперь',
#   '«антипиратскому»',
#   'россии',
#   'антипиратскому'],
#  '0000000339': ['ftoloka',
#   'f%',
#   'данный',
#   'запустился',
#   'a%',
#   '«толока»',
#   'исполнитель',
#   'толока'],
#  '0000000340': ['cм', '«mouse»', '«windows»', 'например'],
#  '0000000341': ['текст'],
#  '0000000342': ['деньги',
#   'mail',
#   'финансовые',
#   '«ведомости»',
#   'qiwi',
#   'ведомости',
#   'сама',
#   'group'],
#  '0000000343': ['дуров', 'павел', 'с ', 'европе'],
#  '0000000344': ['стали',
#   'war',
#   'гб,',
#   'craft',
#   'но',
#   'в ',
#   'hearthstone',
#   'android',
#   'heroes'],
#  '0000000345': ['а ', 'ахтунг', 'данное', 'я ', 'обсе!'],
#  '0000000346': ['в ', 'гостей', 'гостям', 'побег', 'тюремном'],
#  '0000000347': ['atr-',
#   'игарки',
#   'airlines',
#   'вынужденная',
#   'nord',
#   'таймыр',
#   'star',
#   '«таймыр»',
#   'самолет'],
#  '0000000348': ['facebook'],
#  '0000000349': ['apple',
#   'insider',
#   'safari',
#   'как',
#   'business',
#   'согласно',
#   'google',
#   'yahoo',
#   'microsoft'],
#  '0000000350': ['the',
#   'когда',
#   'теперь',
#   'tj',
#   'twi',
#   'потом',
#   'как',
#   'journal',
#   'j?',
#   'tj.',
#   't '],
#  '0000000351': ['произойти',
#   'bild',
#   'f%',
#   'fwww',
#   'iii ',
#   'auto',
#   'tesla',
#   'fartikel',
#   'a%',
#   'но',
#   'finterview',
#   'непонятно',
#   'model',
#   'iii.',
#   'об'],
#  '0000000352': ['велосипед', 'du', 'предназначение', 'bike'],
#  '0000000353': ['говорят', 'называется', 'создана', 'и ', 'liftware'],
#  '0000000354': ['текст'],
#  '0000000355': ['farxiv',
#   'исследователи',
#   'остальные',
#   'f1',
#   'f%',
#   'fabs',
#   'мадридского',
#   'a%',
#   'большинство',
#   'для'],
#  '0000000356': ['во', 'приятного', 'видео', 'холодное', 'по'],
#  '0000000357': ['аддис', 'американский', 'ноа'],
#  '0000000358': ['скидки', 'a%', 'fstore', 'f)', 'f%', 'fsteamdb', 'fsales'],
#  '0000000359': ['betaworks',
#   'facebook',
#   'app',
#   'например',
#   'store',
#   'homescreen',
#   'messenger',
#   'для'],
#  '0000000361': ['inc',
#   'издание',
#   'fonline',
#   'hero',
#   'hd ',
#   'f%',
#   'farticles',
#   'wsj ',
#   'go',
#   'a%',
#   'fgopro',
#   'аппараты',
#   'pro'],
#  '0000000362': ['россия',
#   'журналисты',
#   'фергюссон',
#   'группа',
#   'миа ',
#   'при',
#   'луис',
#   'сент'],
#  '0000000363': ['fassassins',
#   'farticles',
#   'список',
#   'a%',
#   'unity',
#   'издатель',
#   'kings',
#   'f)',
#   'f%',
#   'жаль',
#   'dead',
#   'запуск',
#   'assassin',
#   'dlc ',
#   'fkanobu',
#   'creed'],
#  '0000000364': ['linux', 'вчера', 'гис,', 'os ', 'x '],
#  '0000000365': ['континентальной',
#   'между',
#   'ссср,',
#   'в ',
#   'братиславе',
#   'ярославля',
#   'слованом',
#   'локомотивом',
#   'по',
#   'россии'],
#  '0000000366': ['tunes',
#   'америки',
#   'изначально',
#   'wars',
#   'в ',
#   'star',
#   'trailers',
#   'северной'],
#  '0000000367': ['developer',
#   'firefox',
#   'aurora',
#   'adapter',
#   'edition',
#   'новый',
#   'tools'],
#  '0000000369': ['совета',
#   'а.',
#   'член',
#   'кодекса',
#   'в.',
#   'бастрыкина',
#   'архангельской',
#   'добрынин',
#   'а.и',
#   'милонова',
#   'федерации',
#   'рф ',
#   'константин',
#   'и.',
#   'ск ',
#   'российской',
#   'в.в',
#   'уголовного'],
#  '0000000370': ['фиделя', 'салинаса', 'эта'],
#  '0000000371': ['этот'],
#  '0000000372': ['все', 'ваш', '«макросов»'],
#  '0000000373': ['по', 'каждый', 'фудзисаве'],
#  '0000000374': ['дюрана',
#   'издание',
#   'pravda',
#   'f%',
#   'контакте',
#   'норвежские',
#   'первоисточником',
#   'fvk',
#   'при',
#   'апокалипсис',
#   'a%',
#   'наращивание',
#   'fwall',
#   'вк'],
#  '0000000375': ['tj', 'у ', 'получить', 'нам'],
#  '0000000376': ['никакой', 'twitter', 'если'],
#  '0000000377': ['комнаты'],
#  '0000000378': ['хотя', 'много', 'хоть', 'и ', 'g+'],
#  '0000000379': ['пока', 'google', 'поэтому', 'кубы'],
#  '0000000380': ['первое',
#   'чё',
#   'официальный',
#   'зв',
#   'пробуждение',
#   'премьера'],
#  '0000000381': ['майбаума',
#   'филы',
#   'майкла',
#   'изменения',
#   'но',
#   'солнцу',
#   'по',
#   '«полушарий»',
#   '«филы»'],
#  '0000000382': ['змейка',
#   'tube',
#   'coolermaster',
#   'quick',
#   'fire',
#   'классическую',
#   'you',
#   'rapid',
#   '«змейка»',
#   'судя'],
#  '0000000383': ['аватар',
#   '«аватар»',
#   'кинематографист',
#   'кэмерон',
#   'вы',
#   'они',
#   'я ',
#   'джеймс',
#   'empire',
#   'американский'],
#  '0000000384': ['в ',
#   'россии',
#   'шалтай',
#   'донбассе',
#   'болтай',
#   'константином',
#   'малофеевым'],
#  '0000000385': ['что', 'меня', 'если'],
#  '0000000387': ['ассоциации',
#   'russia',
#   'национальное',
#   'visit',
#   'об',
#   'россии'],
#  '0000000388': ['«римейке»', '«копьем»', 'леонида', 'посетители', 'в '],
#  '0000000389': ['библии',
#   '«богоугодной»',
#   'ос ',
#   'f)',
#   'os.',
#   'f%',
#   'основными',
#   'temple',
#   'fwww',
#   'оф',
#   'дэвис',
#   'a%',
#   'сша ',
#   'os ',
#   'терри'],
#  '0000000390': ['phone', 'apple', 'pad', 'смартфоны', 'теперь', 'многие'],
#  '0000000391': ['то', 'арб ', 'ой', 'сбербанк', 'у '],
#  '0000000392': ['inc',
#   'space',
#   'd ',
#   'технология',
#   'made',
#   'мкс ',
#   'in',
#   'космический',
#   'на',
#   'nasa '],
#  '0000000394': ['во',
#   'кастомная',
#   'fyadi',
#   'fa',
#   'a%',
#   'tv',
#   'fimgur',
#   'bg',
#   'bh%',
#   'fd',
#   'f%',
#   'fftv',
#   'r)',
#   'примеры',
#   'может',
#   'ручные',
#   'vt',
#   'raw.'],
#  '0000000395': ['благодаря', 'канаде'],
#  '0000000397': ['гугл', 'напомню'],
#  '0000000398': ['москве', 'в ', 'дню', 'это', 'россии', 'сша,'],
#  '0000000399': ['yrwt_',
#   'aldo',
#   'именно',
#   'бейонсе',
#   'a%',
#   'fwatch',
#   'fv',
#   'одна',
#   'и ',
#   'f%',
#   'fwww',
#   'одно',
#   'dk',
#   'один',
#   'спасибо',
#   'тж.'],
#  '0000000400': ['мизулиной', 'на'],
#  '0000000401': ['thrones',
#   'mac',
#   'os.',
#   'xbox',
#   'game',
#   'студия',
#   'ice',
#   'со',
#   'from',
#   'ps4',
#   'iron',
#   'one',
#   'telltale',
#   'pc,'],
#  '0000000408': ['шайа', 'она', 'там', 'мне', 'минут'],
#  '0000000409': ['fwhat',
#   'f2',
#   'f)',
#   'f1',
#   'f%',
#   'что',
#   'starbucks',
#   'блог',
#   'instagram',
#   'a%',
#   'pretty',
#   'witty',
#   'fwittyandpretty'],
#  '0000000410': ['спасо',
#   'зимней',
#   'у ',
#   'около',
#   'русской',
#   'преображенского',
#   'дороже',
#   'валаамского'],
#  '0000000411': ['нью', 'йорка', 'дня', 'более'],
#  '0000000414': ['lamoda', 'в ', 'омон.'],
#  '0000000415': ['согласно', 'левада', 'всех'],
#  '0000000416': ['болгарский', 'но', 'несомненно', 'азис', 'мразиш'],
#  '0000000418': ['пока',
#   'присоединяйтесь',
#   'лебедев',
#   'читатели',
#   'крыма',
#   'tj ',
#   'артемий'],
#  '0000000420': ['контакте', '«вконтакте»', 'вк', 'около'],
#  '0000000421': ['годзиллы',
#   'кинокомпания',
#   'гарета',
#   '«годзиллы»',
#   'эдвардса',
#   'legendary'],
#  '0000000422': ['доллар', 'зато'],
#  '0000000423': ['горжусь'],
#  '0000000424': ['из', 'автовладельцы', 'россии'],
#  '0000000425': ['f2',
#   'fbroken',
#   'сейчас',
#   'a%',
#   'dream',
#   'торонто',
#   'f0',
#   'после',
#   'ikea ',
#   'f1',
#   'f)',
#   'f%',
#   'darwin',
#   'fwww',
#   'в ',
#   'fcity',
#   'fikea',
#   'fnews',
#   'для'],
#  '0000000427': ['я ', 'сообщают', 'россии'],
#  '0000000428': ['компания',
#   'f2',
#   'f1',
#   'f)',
#   'f%',
#   'fa',
#   'plus',
#   'cyanogen',
#   'a%',
#   'в ',
#   'fblog',
#   'foneplus',
#   'one',
#   'cyanogenmod',
#   'micromax'],
#  '0000000429': ['лагаем'],
#  '0000000430': ['дрейк',
#   'университета',
#   'тирвитт',
#   'получилось',
#   'джеймс',
#   'викторианского',
#   'электро',
#   'л '],
#  '0000000431': ['однако', 'за'],
#  '0000000432': ['к ', 'проблема', 'как', 'x '],
#  '0000000433': ['текст'],
#  '0000000434': ['текст'],
#  '0000000435': ['компания',
#   'summer',
#   'харады',
#   'lesson',
#   'кацухиро',
#   'bandai',
#   'station',
#   'play',
#   'tekken',
#   'namco'],
#  '0000000436': ['duty',
#   'приятного',
#   'почему',
#   'steam',
#   'friday',
#   'лучшие',
#   'machine',
#   'joyhunter',
#   'call',
#   'вс',
#   'alienware',
#   'kikstarter',
#   'black'],
#  '0000000437': ['a%',
#   'комментатор',
#   'так',
#   'd2',
#   'россия',
#   'оригинал',
#   'f%',
#   'findex',
#   'fwww',
#   'fortress',
#   'dview',
#   'team',
#   'в ',
#   'foption',
#   'd1',
#   'dcom'],
#  '0000000438': ['phone', 'получилась', 'выросло', 'клубе', 'торе', 'tj.'],
#  '0000000439': ['«royals»',
#   'airlines',
#   'девушку',
#   'royals',
#   'youtube',
#   'на',
#   'запись',
#   'american',
#   'lorde'],
#  '0000000440': ['этот'],
#  '0000000441': ['хотите', 'интернет', 'want'],
#  '0000000442': ['киселеве', 'rt ', 'о ', 'это'],
#  '0000000443': ['как', 'в ', 'google', 'так', 'nexus'],
#  '0000000445': ['оризонти',
#   'в ',
#   'инцидент',
#   'оба',
#   'карлос',
#   'пратес',
#   'белу'],
#  '0000000446': ['что', 'джордж', 'лукас'],
#  '0000000447': ['tj.', 'вопрос', 'именно', 'завтра'],
#  '0000000449': ['видео', 'гундяевым'],
#  '0000000450': ['ba%',
#   'be%',
#   'fru',
#   'c_',
#   'd0',
#   'b2',
#   'доцент',
#   'a%',
#   'алекс',
#   'b8',
#   'bb%',
#   'бирюков',
#   'f%',
#   'например',
#   'fwiki',
#   'люксембурга',
#   'e%',
#   'для',
#   'd1',
#   'bitcoin',
#   'b5'],
#  '0000000451': ['reading', 'в ', 'есть', 'ложь', 'smart', 'довольно', 'и '],
#  '0000000452': ['информация',
#   'автоваз',
#   'лада',
#   'повышение',
#   'lada',
#   'за',
#   'цены'],
#  '0000000453': ['этот'],
#  '0000000454': ['по', 'сми,'],
#  '0000000455': ['немецкая', 'krupp', 'thyssen', 'кроме', 'такие'],
#  '0000000456': ['valve', 'life', 'half', 'deathmatch', 'сегодня'],
#  '0000000457': ['текст'],
#  '0000000458': ['тесла', 'audi', 'выпустят'],
#  '0000000459': ['гарай',
#   'зенит',
#   'кураньи',
#   '«зенит»',
#   '«зенита»',
#   'зенита',
#   'больше',
#   'динамо',
#   'александр',
#   'россии',
#   'эсекиэль',
#   'кевин',
#   'второе',
#   'кокорин',
#   'халк',
#   '«динамо»',
#   'его'],
#  '0000000460': ['этот'],
#  '0000000461': ['не', 'разработчикам', 'контакте', 'сегодня', 'вк'],
#  '0000000462': ['стартовая', 'кто', 'стиву', 'снес', 'джобсу', 'вк]'],
#  '0000000463': ['f2',
#   '«неофициальным»',
#   'александра',
#   'a%',
#   'whois',
#   'владимира',
#   'сайт',
#   'судя',
#   'fhttp',
#   'archive',
#   'f)',
#   'f%',
#   'fwww',
#   'путина',
#   'internet',
#   'белоруссии',
#   'fweb'],
#  '0000000465': ['в ', 'золотую', 'русский', 'рыбку', 'россии'],
#  '0000000466': ['gg ', 'кстати', 'с ', 'intel'],
#  '0000000467': ['wikimart',
#   'ru',
#   'яндекс',
#   'a%',
#   'маркет',
#   'на',
#   '«яндекса»',
#   'bay',
#   'mail',
#   'f)',
#   'f%',
#   'товары',
#   'price',
#   'товарные',
#   'fnota',
#   'яндекса'],
#  '0000000468': ['платформа', 's,', 'model', 'доставят', 'x '],
#  '0000000469': ['этот'],
#  '0000000471': ['по'],
#  '0000000472': ['f2',
#   'источники',
#   'яндекс',
#   'a%',
#   'mobile',
#   'google',
#   'f0',
#   'f1',
#   'f)',
#   'f%',
#   'fandroid',
#   'еврокомиссия',
#   'fgigaom',
#   'fkit',
#   'services',
#   'android',
#   'еврокомиссии'],
#  '0000000473': ['бансы',
#   'f%',
#   'например',
#   'fesquire',
#   'людвигсхафене',
#   'a%',
#   'esquire',
#   'feditors',
#   'перед'],
#  '0000000476': ['лебедева', 'екатеринбургу', 'теперь', 'артемия', 'студия'],
#  '0000000477': ['occupy',
#   'china',
#   'a%',
#   'farticle',
#   'адмиралти',
#   'south',
#   'central',
#   'f1',
#   'fhong',
#   'f%',
#   'fstudent',
#   'fwww',
#   'в ',
#   'post',
#   'fnews',
#   'гонконге',
#   'morning'],
#  '0000000478': ['сети', 'ну', 'октября', 'еще', 'и '],
#  '0000000479': ['uber', 'с ', 'кроме'],
#  '0000000480': ['cube', 'о ', 'ice', 'южном'],
#  '0000000481': ['рассказали', 'в ', 'появилось'],
#  '0000000482': ['netflix', 'карточный', 'house', 'cards', 'премьера'],
#  '0000000483': ['mos',
#   'wi',
#   'metro',
#   'максима',
#   'free',
#   'официальный',
#   'fi',
#   'телеком',
#   '«максимателеком»'],
#  '0000000486': ['миллиардер',
#   'жириновскому',
#   'прохоров',
#   'лдпр ',
#   'михаил',
#   'автомобиль',
#   'жириновского',
#   'владимиру'],
#  '0000000487': ['f%',
#   'картинка',
#   'falbum',
#   'fvk',
#   'dphoto',
#   'a%',
#   'в ',
#   '«лентач»',
#   'foldlentach',
#   'fz',
#   'лентач',
#   'frev'],
#  '0000000488': ['цель', 'sports', 'в '],
#  '0000000489': ['норвежский', 'норвегии', 'как', 'инцидент'],
#  '0000000490': ['mob',
#   'кабинет',
#   'g ',
#   'ещ',
#   'украины',
#   'украине',
#   'g.',
#   '«нормального»',
#   'tri',
#   'да'],
#  '0000000491': ['ces ', 'nabu', 'официальная', 'razer', 'после', 'тот'],
#  '0000000492': ['прежде',
#   'бонда',
#   'джеймса',
#   'я ',
#   'хокинг.прежде',
#   'хокинг',
#   'известный',
#   'большого',
#   'теории'],
#  '0000000493': ['дурова',
#   'secrecy',
#   'android',
#   'telegram',
#   'perfect',
#   'в ',
#   'павла',
#   'forward',
#   'os '],
#  '0000000494': ['этот'],
#  '0000000495': ['тим',
#   'оригинал',
#   'tumblr',
#   'photoshop',
#   'циркулирующая',
#   'i ',
#   'nsfw ',
#   'tim'],
#  '0000000496': ['контакте', 'написал', 'вк', 'прошу'],
#  '0000000497': ['пирамидам'],
#  '0000000498': ['всего', 'хромбуков', 'так', 'достигается'],
#  '0000000499': ['оливер',
#   'самым',
#   'мухаммед.за',
#   'мухаммед',
#   'джеймс',
#   'за',
#   'джек',
#   'чарли',
#   'гарри',
#   'ной',
#   'великобритании'],
#  '0000000500': ['запасаемся'],
#  '0000000501': ['похоже',
#   'впрочем',
#   'sky',
#   'гитлером',
#   'помните',
#   'iron',
#   'запретить!',
#   'или'],
#  '0000000502': ['frpod', 'a%', 'старейший', 'f)', 'тем', 'f%'],
#  '0000000503': ['«дождя»',
#   'дождя',
#   'рингтоны',
#   'tube',
#   'тв ',
#   'you',
#   'на',
#   'россии'],
#  '0000000504': ['or',
#   'f%',
#   'fisup',
#   'everyone',
#   'down',
#   'гитхаб',
#   'сервис',
#   'a%',
#   'for',
#   'just',
#   'me',
#   'fgithub'],
#  '0000000505': ['ave',
#   'f%',
#   'одноклассников',
#   'fa',
#   '«одноклассников»',
#   'кафанову',
#   'мише',
#   'a%',
#   'кто',
#   'fstatus',
#   'за',
#   'misha',
#   'ftwitter',
#   'f5'],
#  '0000000506': ['россия',
#   'вы',
#   'собственные',
#   'удивляться',
#   'госдумы',
#   'евгений',
#   'единая',
#   'федоров',
#   'это'],
#  '0000000508': ['международная', 'как', 'iata)', 'на'],
#  '0000000509': ['этот'],
#  '0000000510': ['threshold',
#   '«threshold»',
#   'windows',
#   'xbox',
#   'continuum',
#   'о ',
#   'на',
#   'one',
#   'microsoft'],
#  '0000000512': ['и ', 'когда'],
#  '0000000514': ['не', 'facebook', 'git', 'на', 'роскомнадзора', 'hub'],
#  '0000000515': ['не',
#   'apple',
#   'xbox',
#   'tizen',
#   'geektime',
#   'oс',
#   'uber',
#   'kinect',
#   'google'],
#  '0000000516': ['текст'],
#  '0000000517': ['иван',
#   'антон',
#   'рф ',
#   'депутаты',
#   'сухарев',
#   'госдумы',
#   'ищенко',
#   'уголовного'],
#  '0000000518': ['nordnet', 'такой', 'скандинавская'],
#  '0000000519': ['этот'],
#  '0000000520': ['mashable',
#   'галински',
#   'по',
#   'сша ',
#   'трц ',
#   'майкла',
#   'портал'],
#  '0000000522': ['age',
#   'дэнверс',
#   'marvel',
#   'captain',
#   'pinewood',
#   'кэрол',
#   'на',
#   'avengers',
#   'по',
#   'ultron'],
#  '0000000523': ['тасс ', 'ленинградской', 'эксперимент', 'по', 'глонасс.'],
#  '0000000524': [],
#  '0000000525': ['valve',
#   'broadcasting',
#   '«подсматривать»',
#   'twitch',
#   'бета',
#   'по',
#   'благодаря',
#   'steam'],
#  '0000000527': ['fwatch',
#   'il',
#   'не',
#   'cut',
#   'f)',
#   'f%',
#   'fwww',
#   'ao',
#   'a%',
#   'ga',
#   'fv',
#   'lmd',
#   'от',
#   'os3',
#   'dc'],
#  '0000000528': ['пока', 'белорусы', 'в '],
#  '0000000529': ['ну',
#   'tj ',
#   'такой',
#   'хотелось',
#   'клуб',
#   'надеюсь',
#   'конечно',
#   'лихачева',
#   'сми,'],
#  '0000000530': ['victory',
#   'kotaku',
#   'у ',
#   'assassin',
#   'вслед',
#   'creed',
#   'парижем',
#   'лондон'],
#  '0000000531': ['бейонсе', 'за', 'девушек'],
#  '0000000532': ['tj', 'тем', 'journal'],
#  '0000000534': ['к ', 'привет', 'вам', 'делается'],
#  '0000000535': ['текст'],
#  '0000000536': ['ранее', 'you', 'tube', 'небось'],
#  '0000000537': ['эйр',
#   'suicide',
#   'смит',
#   'режис',
#   'уилл',
#   'джай',
#   'капитана',
#   'кортни',
#   'квинн',
#   'warner',
#   'бумеранга',
#   'кара',
#   'робби',
#   'отряд',
#   'лето',
#   'марго',
#   'джаред',
#   'флэга',
#   'squad',
#   'чародейку',
#   'харди',
#   'bros',
#   'том',
#   'харли',
#   'дэвид',
#   'дэдшота',
#   'джокера',
#   'студией',
#   'делевинь',
#   'самоубийц',
#   'рика'],
#  '0000000538': ['компания', 'необходимость', 'многие'],
#  '0000000539': ['фонд',
#   'red',
#   'apple',
#   'app',
#   'спид',
#   'store',
#   'с ',
#   'pod',
#   'глобальный',
#   'pad',
#   'подобная',
#   'дом'],
#  '0000000540': ['трудовой', 'госдума', 'жалеем', 'жд'],
#  '0000000541': ['ps1', 'её', 'station', 'play', 'консоль'],
#  '0000000542': ['красноярского', 'западно', 'игарки', 'сибирская'],
#  '0000000543': ['dts',
#   'facebook',
#   'fhashtag',
#   'dhash',
#   'a%',
#   'холлоуэй',
#   'после',
#   'girls',
#   'fselfiecampaign',
#   'под',
#   'f%',
#   'fwww',
#   'ugly',
#   'club',
#   'студентки',
#   'ройял',
#   'ftwitter',
#   'fuglygirlsclub',
#   'twitter',
#   'ffref',
#   'fsrc'],
#  '0000000544': ['читающее', 'там'],
#  '0000000545': ['спойлер',
#   'f%',
#   'russia',
#   'ведущие',
#   'саудовской',
#   'fkermlinrussia',
#   'a%',
#   'kermlin',
#   'аравией',
#   'ftwitter',
#   'ввп ',
#   'россии'],
#  '0000000546': ['леди',
#   'твиттере',
#   'угадайте',
#   '«бинго»',
#   'марк',
#   'гага',
#   'герагос',
#   'готвальд',
#   'хотя',
#   'лукаш',
#   'и '],
#  '0000000551': ['но', 'ос ', 'cicret', 'то', 'android'],
#  '0000000552': ['этот'],
#  '0000000553': ['developers', 'dvd.', 'google', 'groups', 'сегодня'],
#  '0000000554': ['phone', 'а ', 'devices', 'что', 'yota'],
#  '0000000555': ['you', 'летом', 'судя', 'porn'],
#  '0000000556': ['текст'],
#  '0000000557': ['афиша.город',
#   'дмитрий',
#   'артемий',
#   'мгу ',
#   'песков',
#   'как',
#   'лебедев',
#   'город',
#   'афиша',
#   'собянин'],
#  '0000000558': ['в ', 'японии', 'station', 'play', 'ps ', 'сегодня', 'по'],
#  '0000000559': ['латинской',
#   'народные',
#   'машину',
#   'азии',
#   'африке',
#   'америке',
#   'ак4'],
#  '0000000560': ['шум', 'игра', 'австралии', 'rockstar', 'это'],
#  '0000000561': ['«паз»', 'мужчина', 'внутри', 'по', 'паз»'],
#  '0000000562': ['google', 'api.', 'на'],
#  '0000000563': ['r,',
#   'solmy',
#   'win',
#   'dota',
#   'qo',
#   'p,',
#   'yp:',
#   'сегодня',
#   'ребятами',
#   'mengue',
#   'состав',
#   'team',
#   'lq',
#   'ragabash',
#   'play',
#   'lawliet',
#   'lo'],
#  '0000000564': ['теперь'],
#  '0000000565': ['ncfv',
#   'если',
#   'f)',
#   'finstagram',
#   'f%',
#   'vlz',
#   'fp',
#   'a%',
#   'google',
#   'fv',
#   'кстати'],
#  '0000000566': ['а '],
#  '0000000567': ['еще'],
#  '0000000568': ['дотком',
#   'ким',
#   'хиллари',
#   'megaupload',
#   'сша ',
#   'основатель'],
#  '0000000569': ['хорошая', 'роем', 'ксензов', 'максим'],
#  '0000000570': ['а ', 'неожиданно'],
#  '0000000571': ['по', 'федеральное', 'полная'],
#  '0000000572': ['текст'],
#  '0000000574': ['чуров', 'если', 'на', 'это'],
#  '0000000577': ['f6',
#   'аполлон',
#   'fchannel',
#   'f%',
#   '«орион»',
#   'fwww',
#   '«аполлон»',
#   'орион',
#   'live',
#   'a%',
#   'он'],
#  '0000000578': ['вос.', 'если', 'вос '],
#  '0000000581': ['как', 'в ', 'наса,', 'сша ', 'орион'],
#  '0000000583': ['airbnb', 'два'],
#  '0000000584': ['приложение'],
#  '0000000586': ['всем'],
#  '0000000587': ['quadrofoil', 'словенская'],
#  '0000000588': ['при', 'a%', 'в ', 'finstagram', 'f%', 'android', 'sorry'],
#  '0000000589': ['первые',
#   'дженифер',
#   'f2',
#   'fyearinreview',
#   'f%',
#   'tumblr',
#   'лоуренс',
#   'a%',
#   'беня',
#   'камбербэтч'],
#  '0000000590': ['рамзан', 'phone', 'yota', 'федеральному'],
#  '0000000592': ['фбр ',
#   'интервью',
#   'сеть',
#   'sony',
#   'кореи',
#   'поводом',
#   'кима',
#   'в ',
#   'на',
#   '«интервью»',
#   'pictures',
#   'северной'],
#  '0000000593': ['f%', 'tj', 'fvk', 'ftj', 'a%', 'на', 'ftjournal', 'journal'],
#  '0000000594': ['бенедикт',
#   'fryan',
#   'marvel',
#   'стрэнджа',
#   'джон',
#   'спэйтс',
#   'также',
#   'дэдпула',
#   'a%',
#   'дерриксон',
#   'рейнольдс',
#   'компания',
#   'доктора',
#   'сценарий',
#   'f)',
#   'f%',
#   'запланированная',
#   'fwww',
#   'райан',
#   'скотт',
#   'камбербэтч'],
#  '0000000595': ['git',
#   'f%',
#   'hub',
#   'froskomnadzor',
#   'росконадзора',
#   'a%',
#   'в ',
#   'роскомнадзоров',
#   'fgithub',
#   'россии'],
#  '0000000596': ['топ ', 'tj', 'заходишь', 'journal'],
#  '0000000597': ['marvel',
#   'a%',
# ...
#   'f%',
#   'gwi',
#   'fwww',
#   'dplq',
#   'ql',
#   'японии',
#   'bko',
#   'ob',
#   'ncn',
#   'в ',
#   'you',
#   'tq)',
#   'xg'],
#  '0000001078': ['кирилла',
#   'накануне',
#   'оба',
#   'олегом',
#   'патриарха',
#   'киселевым',
#   'дмитрием',
#   'добродеевым',
#   'россии'],
#  '0000001079': ['эхо',
#   'демина',
#   'главный',
#   'интерфакс',
#   'генеральным',
#   'михаил',
#   'эха',
#   'москвы',
#   'алексей',
#   '«интерфакс»',
#   'такое',
#   'венедиктов',
#   'демин',
#   '«эха»'],
#  '0000001080': ['the',
#   'новым',
#   'всего',
#   'red',
#   'keds',
#   'усачев',
#   'микус',
#   'руслан',
#   'boys',
#   'вэй',
#   'давыдов',
#   'hungry',
#   'стас',
#   'паша',
#   'players',
#   'продюсерский',
#   'grape',
#   'мария'],
#  '0000001081': ['devices',
#   'пользователи',
#   'ftwitter',
#   'f%',
#   'fp',
#   'ru',
#   'fy',
#   'a%',
#   'porkido',
#   'fstatus',
#   'покойся',
#   'all',
#   'yota',
#   'f5',
#   'да'],
#  '0000001082': [],
#  '0000001083': ['chat', 'fire', 'оппозиционные', 'сообщения'],
#  '0000001084': ['плющева',
#   'идея',
#   'рябцева',
#   'иванова',
#   'михаилом',
#   'лесиным',
#   'твит',
#   'эха',
#   'инициатором',
#   'москвы',
#   'александра',
#   'сергея',
#   'алексея',
#   'венедиктова',
#   'олеся'],
#  '0000001085': ['средняя', 'в ', 'планшеты', 'пк '],
#  '0000001086': ['сша ', 'социологи'],
#  '0000001088': ['новым',
#   'я ',
#   'скоро',
#   'но',
#   'за',
#   'от',
#   'добрый',
#   'ура',
#   'предлагаю'],
#  '0000001089': ['леонтьевым',
#   'боинг',
#   'украины',
#   'пришел',
#   'однако',
#   'в ',
#   'ввс ',
#   'комсомольской'],
#  '0000001090': ['грэма',
#   'рейнольдсона',
#   'как',
#   'на',
#   'по',
#   'amazon',
#   'дефисы'],
#  '0000001092': ['c,',
#   'мы',
#   'мощнейшая',
#   'а ',
#   'кэррингтона',
#   'антарктике',
#   'солнечным',
#   'предлагаю',
#   'm ',
#   'современные',
#   'солнечные',
#   'одно',
#   'такие',
#   'выбор',
#   'x.',
#   'буквой',
#   'по',
#   'b,',
#   'кэррингтон',
#   'скалистых',
#   'x1',
#   'некоторые',
#   'линии',
#   'европе',
#   'событие',
#   'америке',
#   'это',
#   'анализ',
#   'не',
#   'то',
#   'a,',
#   'особенно',
#   'продолжительность',
#   'nasa)',
#   'в ',
#   'гренландии',
#   'индекс',
#   'ричард'],
#  '0000001093': ['фбр ',
#   'fstatic',
#   'fdata',
#   'истории',
#   'insider',
#   'vt7',
#   'sec',
#   'a%',
#   'business',
#   'anti',
#   'adobe',
#   'fvisualizations',
#   'fworlds',
#   'после',
#   'chat',
#   'apple',
#   'издание',
#   'можно',
#   'f)',
#   'z)',
#   'f%',
#   'fpastebin',
#   'fwww',
#   'например',
#   'fnf',
#   'в ',
#   'snap'],
#  '0000001094': ['этот'],
#  '0000001095': ['fmultimedia',
#   'ангара',
#   'разгонный',
#   'a%',
#   'бриз',
#   'gallery',
#   'fid',
#   '«ангара»',
#   'fxn',
#   'кроме',
#   'photo',
#   'минобороны',
#   'f%',
#   'м»',
#   'роскосмос',
#   'fphoto',
#   'fgallery',
#   'd1'],
#  '0000001096': ['выход',
#   'a%',
#   'f)',
#   'star',
#   'f%',
#   'frobertsspaceindustries',
#   'citizen'],
#  '0000001097': ['компания', 'на', 'сочельник', 'клауса', 'google', 'санты'],
#  '0000001098': ['apple',
#   'note ',
#   'те',
#   'новый',
#   'm1',
#   'цена',
#   'но',
#   'примерно'],
#  '0000001099': ['востоке',
#   'не',
#   'журналист',
#   'квентин',
#   'bbc ',
#   'соммервиль',
#   'видео',
#   'ближнем',
#   'афганистане'],
#  '0000001100': ['вообще', 'маск', 'илон'],
#  '0000001101': ['так', 'предприимчивые'],
#  '0000001102': ['a%', 'falltheminutes', 'f)', 'f%', 'всем', 'хорошие', 'блин'],
#  '0000001103': ['анжела', 'сю', 'asus', 'балтии', 'снг ', 'россию', 'россии'],
#  '0000001105': ['к ',
#   'tj',
#   'tj)',
#   'но',
#   'android',
#   'os ',
#   'после',
#   'так',
#   'journal'],
#  '0000001106': ['the', 'telegraph', 'эта', 'fi', 'es', 'об', 'французские'],
#  '0000001107': ['полностью',
#   'f)',
#   'f%',
#   'журнал',
#   'fspace',
#   'ftime',
#   'a%',
#   'в ',
#   'f3',
#   'time'],
#  '0000001109': ['phone',
#   'компактность',
#   'бейсболла',
#   'a%',
#   'кто',
#   'республика\\',
#   'радиус',
#   'на',
#   'телефон',
#   'american',
#   'japan',
#   'starwood',
#   'наггетс',
#   'clu',
#   'россии',
#   'к ',
#   'mc',
#   'apple',
#   'nivea',
#   'лига',
#   'люди',
#   'по',
#   'hotels',
#   'wwdc ',
#   'f2',
#   'чуть',
#   'os.',
#   'главная',
#   'мак',
#   'однако',
#   'но',
#   'wallmart',
#   'bluetooth',
#   'f0',
#   'вкратце',
#   'beacon',
#   'чикен',
#   'atlantic',
#   'f1',
#   'сеть',
#   'f%',
#   'airlines',
#   'donalds',
#   'virgin',
#   'mlb)',
#   'в ',
#   'как',
#   'fthe',
#   'материал'],
#  '0000001110': ['хованского',
#   'вы',
#   'тем',
#   'волна',
#   'азалию',
#   'игги',
#   'афиша',
#   'и '],
#  '0000001111': ['давно',
#   'а ',
#   'сми;',
#   'f%',
#   'tj ',
#   'fvk',
#   'a%',
#   'fwall',
#   'вот',
#   'кстати'],
#  '0000001112': ['зайцеву',
#   'ирину',
#   'жиенбаев',
#   'ик№',
#   'уфисн ',
#   'арсен',
#   'бывший',
#   'после',
#   'омской'],
#  '0000001113': ['а ',
#   'эминема',
#   'радио',
#   'a%',
#   'на',
#   'ведь',
#   'кроме',
#   'такого ',
#   'любовь',
#   'f)',
#   "d'",
#   'я ',
#   'формат',
#   'уфой',
#   'rammstein',
#   'любэ',
#   'fmnhttn',
#   'абсолютный',
#   'очень',
#   'fatboy',
#   'manhattan',
#   'фрэнка',
#   'fm-',
#   'fradio',
#   'круто',
#   'уфе',
#   'пресли',
#   'впервые',
#   'radio',
#   'шансон',
#   'f%',
#   'sonics',
#   'однажды',
#   'b ',
#   'в ',
#   'slim',
#   'станция',
#   'элвиса',
#   'и ',
#   'сказать',
#   'синатры'],
#  '0000001116': ['s:',
#   'f%',
#   'блокируют',
#   'fwww',
#   'ттк.',
#   'билайн',
#   'a%',
#   'в ',
#   'на'],
#  '0000001117': ['sa ',
#   'разумеется',
#   'cc-',
#   'мартин',
#   'полиция',
#   'by-',
#   'антонио',
#   'по'],
#  '0000001118': ['аргументам', 'украины', 'бывший'],
#  '0000001119': ['phone',
#   'cowen',
#   's ',
#   'c.',
#   'правда',
#   'company',
#   'аналитик',
#   'и ',
#   'купертино',
#   'продукт'],
#  '0000001120': ['крыму',
#   'под',
#   'одним',
#   'chrome',
#   'обама',
#   'firefox',
#   'java',
#   'it-',
#   'skype',
#   'gmail',
#   'барак'],
#  '0000001121': ['из', 'правоохранительные'],
#  '0000001122': ['ивана',
#   'ну',
#   'первому',
#   'стива',
#   'мечтает',
#   'ивану',
#   'джобс',
#   'какого',
#   'джобса',
#   'не',
#   'с ',
#   'даже',
#   'подводка',
#   'кого',
#   'давай',
#   'иван',
#   'по',
#   'предупреждает',
#   'наш',
#   'его',
#   'стив'],
#  '0000001123': ['я '],
#  '0000001124': ['рфпл,', 'сша ', 'стороны'],
#  '0000001125': ['московское',
#   'московского',
#   'шоталндии',
#   'f%',
#   'fvk',
#   'подслушано',
#   'a%',
#   'в ',
#   'fmetrooverhear',
#   'основатель',
#   'такую'],
#  '0000001126': ['fm',
#   'доброй',
#   'редакция',
#   'f%',
#   'наткнулся',
#   'a%',
#   'в ',
#   'fvasek',
#   'это'],
#  '0000001127': ['октябрьского',
#   'ранее',
#   'решением',
#   'лошагина',
#   'прокопьевой',
#   'арест',
#   'известного',
#   'юлии'],
#  '0000001130': ['армии',
#   'чен',
#   'fshaunwalker',
#   'глава',
#   'kcna.',
#   'об',
#   'a%',
#   'fstatus',
#   'кндр.',
#   'групповой',
#   'народной',
#   'f%',
#   'кореи',
#   'ким',
#   'ын',
#   'ftwitter',
#   'twitter',
#   'северной',
#   'f5'],
#  '0000001131': ['ролик',
#   'украине',
#   'егор',
#   'хоббит',
#   'жгун',
#   'битва',
#   'художник'],
#  '0000001132': ['minecraft',
#   'tunes',
#   'n7',
#   'facebook',
#   'd8',
#   'up',
#   'fview',
#   'fwa',
#   'web',
#   'a%',
#   'fitunes',
#   'objects',
#   'feature',
#   'apple',
#   'dus',
#   'app',
#   'f%',
#   'heads',
#   'store',
#   'fmzs',
#   'fcc',
#   'instagram',
#   'snapchat',
#   'в ',
#   'd9',
#   'полная',
#   'fw',
#   'd1'],
#  '0000001133': ['полишинеля', 'из', 'откровения', 'красным'],
#  '0000001134': ['румынии',
#   'f)',
#   'fsnohetta',
#   'f%',
#   'победителями',
#   'санты',
#   'week',
#   'a%',
#   'helsinki',
#   'design',
#   'snohetta',
#   'на',
#   'особенность',
#   'другие'],
#  '0000001135': ['владимира',
#   'ученик',
#   'благовещенска',
#   'позже',
#   'путин',
#   'путина'],
#  '0000001137': ['как'],
#  '0000001138': ['этот'],
#  '0000001139': ['медуза', '«медуза»'],
#  '0000001140': ['the',
#   'остальные',
#   'f)',
#   'темза',
#   'f%',
#   'fwww',
#   'photography',
#   'british',
#   'tourist',
#   'a%',
#   'среди',
#   'awards',
#   'wildlife',
#   'главным'],
#  '0000001141': ['тем',
#   'узнать',
#   'xd0',
#   'd6',
#   'a%',
#   'популярный',
#   'fwatch',
#   'd-',
#   'fv',
#   'сh',
#   'd2',
#   'dxqxk',
#   'f%',
#   'fwww',
#   'b9',
#   'sia',
#   'pitchfork',
#   'd9',
#   'kelb'],
#  '0000001142': ['a%', 'fads', 'f%', 'тема', 'был', 'после'],
#  '0000001143': ['дуров', 'berry', 'telegram', 'призовой', 'black'],
#  '0000001144': ['деньги', 'вести', 'напомню', 'ru', 'сми '],
#  '0000001145': ['phone',
#   'сейчас',
#   'devices',
#   'владислав',
#   'гендиректор',
#   'yota',
#   'мартынов'],
#  '0000001146': ['землянский',
#   'антон',
#   'цао ',
#   'заблокированный',
#   'москвы',
#   'администрацию',
#   'twitter',
#   'коробков',
#   'сша,'],
#  '0000001147': ['animals',
#   'клаус',
#   'программист',
#   'fadvent',
#   'a%',
#   'буквы',
#   'все',
#   'book',
#   'эда',
#   'f)',
#   'рождеству',
#   'f%',
#   'fp',
#   'санта',
#   'fen',
#   'fwiki',
#   'эмберли',
#   'processing',
#   'drawing',
#   'рождества',
#   'в ',
#   'kirk',
#   'каждый'],
#  '0000001148': ['фотография',
#   'reconnaissance',
#   'nasa ',
#   'rise,',
#   'hi',
#   'orbiter',
#   'mars'],
#  '0000001149': ['мы', 'как', 'в '],
#  '0000001150': ['андрей',
#   'олимпиаде',
#   'тарусов',
#   'художник',
#   'крым',
#   'календарь',
#   'осторожно',
#   'на'],
#  '0000001151': ['компания',
#   'маркете',
#   'яндекс.маркете',
#   'яндекс',
#   'м.видео',
#   'м.',
#   'видео',
#   'розничная',
#   'маркет',
#   '«маркет»'],
#  '0000001152': ['renault',
#   'ваз',
#   'автопроизводитель',
#   'lifan',
#   'по',
#   'зовские',
#   'и '],
#  '0000001153': ['между',
#   'а ',
#   'ольга',
#   'a%',
#   'на',
#   'от',
#   'владимир',
#   'александр',
#   'россии',
#   'из',
#   'сталине',
#   'f)',
#   'сергей',
#   'татьяна',
#   'советую',
#   'елена',
#   'ефросинью',
#   'денис',
#   'наталья',
#   'георгий',
#   'популярность',
#   'карина',
#   'анна',
#   'брежневе',
#   'fnames',
#   'михаил',
#   'весьма',
#   'анисью',
#   'или',
#   'вместе',
#   'меркатор',
#   'большая',
#   'леонид',
#   'полина',
#   'отличную',
#   'f%',
#   'например',
#   'арина',
#   'мария',
#   'глафира',
#   'в ',
#   'устинью',
#   'зою',
#   'общей'],
#  '0000001154': ['однако', 'наблюдавшие', 'в ', 'севастополе'],
#  '0000001155': ['смущает', 'а ', 'roem', 'tj ', 'султан', 'в ', 'меня', 'и '],
#  '0000001156': ['а ', 'a%', 'f)', 'в ', 'f%', 'немного', 'fchernyie', 'fv'],
#  '0000001157': ['обсуждать',
#   'чехоев',
#   'де',
#   'готовится',
#   'анатолий',
#   'южная',
#   'осетия',
#   'россии'],
#  '0000001158': ['международная', 'платежная', 'visa', 'крым'],
#  '0000001159': ['мы',
#   'а ',
#   'вы',
#   'fsociety',
#   'fens',
#   'центр',
#   'остапенко',
#   'fitem',
#   'на',
#   'мчс]',
#   'уран',
#   'есть',
#   'я ',
#   'офтоп',
#   'вот',
#   'спвир ',
#   'fkiborgi',
#   'd1',
#   'стоит',
#   'сердюкова',
#   'поскольку',
#   'гнииц ',
#   'f2',
#   'дарпы',
#   'fspvir',
#   'после',
#   'система',
#   'спвир.',
#   'fscience',
#   'минобороны',
#   'федерации',
#   'fmore',
#   'можно',
#   'f1',
#   'findex',
#   'нии ',
#   'российской',
#   'центра',
#   'окр',
#   'нир',
#   'впрочем',
#   'потом',
#   'a%',
#   'рф,',
#   'россии',
#   'фпи,',
#   'fwww',
#   'правда',
#   'роскосмос',
#   'шойгу',
#   'f5',
#   'фонд',
#   'министерства',
#   'чтобы',
#   'ры',
#   'олег',
#   'они',
#   'рт ',
#   'но',
#   'fnekrolog',
#   'fid',
#   'f0',
#   'так',
#   'все',
#   'мчс ',
#   'дело',
#   'прежде',
#   'мчс.',
#   'f%',
#   'главный',
#   'мо ',
#   'frobot',
#   'с ',
#   'инновации',
#   'союза',
#   'министерству',
#   'рогозина',
#   'fnews',
#   'и '],
#  '0000001160': ['специально',
#   'phone',
#   'apple',
#   'рождеству',
#   'возняка',
#   'стиву',
#   'оста',
#   'yota',
#   'это'],
#  '0000001161': ['во',
#   'надзорный',
#   'fpapernews',
#   'a%',
#   'fitem',
#   'на',
#   'автоматы',
#   'оказывается',
#   'f)',
#   'fwww',
#   'петербургского',
#   'при',
#   '«фонтанки»',
#   'по',
#   'f2',
#   'возмущение',
#   'f3',
#   'фонтанки',
#   'fid',
#   'после',
#   'fzheton',
#   'лично',
#   'издание',
#   '«фонтанка»',
#   'f1',
#   'неизменными',
#   'f%',
#   'тут',
#   'со',
#   'метрополитен',
#   'в ',
#   'фонтанка',
#   'fnews',
#   'и ',
#   'сегодня',
#   'fpaperpaper'],
#  '0000001162': ['надеюсь', 'джеки', 'чан', 'чану', 'джейси', 'известный'],
#  '0000001163': ['ажиотаж', 'скупка', 'петербургский', 'метро'],
#  '0000001164': ['slon',
#   'f)',
#   'f%',
#   'слона',
#   'a%',
#   'fslon',
#   'максим',
#   'кашулинский',
#   'сайт',
#   '«слона»'],
#  '0000001166': ['москвы',
#   'ситуация',
#   'прекратить',
#   'люди',
#   'отдать',
#   'сообщают',
#   'полиция'],
#  '0000001167': ['республикой',
#   'симферопоаля',
#   'укрзал',
#   'с ',
#   'крым',
#   'севастополя',
#   '«укрзалізниця»'],
#  '0000001168': ['the',
#   'wilson',
#   'tom',
#   'tube',
#   'world',
#   'around',
#   'том',
#   'you',
#   'пользователь',
#   'us',
#   'уилсон'],
#  '0000001169': ['card',
#   'крыму',
#   'интерфакс',
#   'слышите',
#   'кажется',
#   'visa',
#   'следом',
#   'master',
#   '«интерфакс»',
#   'об',
#   'рф,'],
#  '0000001170': ['новый', 'никита', 'лихач', 'хочу', 'tj,', 'год'],
#  '0000001172': ['как',
#   'министерства',
#   'дождь',
#   'украины',
#   'крым',
#   'об',
#   'крымом'],
#  '0000001173': ['fapps',
#   'циан',
#   'fdetails',
#   'fru',
#   'd0',
#   'a%',
#   'fitunes',
#   'dc)',
#   'fid',
#   'b8',
#   'вид',
#   'fplay',
#   'wp]',
#   'f)',
#   'f%',
#   'bd%',
#   'fstat',
#   'dru',
#   'fwww',
#   'fapp',
#   'fstore',
#   'в ',
#   'd1',
#   'b0',
#   'f8'],
#  '0000001174': ['fail', 'ребята', 'army', 'enjoy'],
#  '0000001175': ['автор', 'кто', 'ино', 'прессой', 'wp ', 'россии'],
#  '0000001176': ['f6',
#   'кндр ',
#   'sony',
#   'f%',
#   'северной',
#   'кореи',
#   'однако',
#   'a%',
#   'на',
#   'farticle',
#   'frussian',
#   'pictures',
#   'ранее',
#   'сша,'],
#  '0000001177': ['эрик', 'роунер', 'американец'],
#  '0000001178': ['f2',
#   'fmap',
#   'a%',
#   'согласно',
#   'веселого',
#   'будьте',
#   'так',
#   'китая',
#   'дотком',
#   'не',
#   'f)',
#   'f%',
#   'ea ',
#   'fwww',
#   'fr',
#   'fbattlefield',
#   'fcomments',
#   'ким',
#   'fpsa',
#   'сша '],
#  '0000001179': ['твиттере',
#   '«happy»',
#   'ftwitter',
#   'обамы',
#   'fhashtag',
#   'b%',
#   'украины',
#   'd0',
#   'bc%',
#   'a%',
#   'танцы',
#   'happy',
#   'россии',
#   'ирака',
#   'a2',
#   'под',
#   'f%',
#   'bd%',
#   'b1',
#   'оригинал',
#   'dtren',
#   'афганистана',
#   'e%',
#   'в ',
#   'сша ',
#   'fsrc',
#   'd1',
#   'b0'],
#  '0000001181': ['наблюдать',
#   'warfare',
#   'xbox',
#   'live',
#   'psn.',
#   'также',
#   'fmap',
#   'a%',
#   'рождество',
#   'call',
#   'несмотря',
#   'дотком',
#   'duty',
#   'f)',
#   'f%',
#   'squad',
#   'lizard',
#   's ',
#   'do',
#   'advanced',
#   'ким',
#   'dd'],
#  '0000001182': ['maroon', 'тэйлор', 'свифт', 'фаррелл', 'версии', 'уильямс'],
#  '0000001183': ['lbtrb',
#   'spinnin',
#   'fpastebin',
#   'f%',
#   'fwlfl',
#   'с ',
#   'a%',
#   'records',
#   'для'],
#  '0000001184': ['fpnref',
#   'акунин',
#   'fnavalny',
#   'парфенова',
#   'a%',
#   'кто',
#   'dstory',
#   'fborisakunin',
#   'фейсбуке',
#   'борис',
#   'навального',
#   'f)',
#   'f%',
#   'fwww',
#   'леонида',
#   'fposts',
#   'алексея',
#   'f4'],
#  '0000001186': ['этот'],
#  '0000001187': ['vy',
#   'valor',
#   'stream',
#   'кисел',
#   'a%',
#   'дмитрия',
#   'fwatch',
#   'y2',
#   'fv',
#   'e5',
#   'не',
#   'f%',
#   'main',
#   'fwww',
#   'dkv',
#   'gi',
#   'ролик'],
#  '0000001188': ['a%', 'fwall', 'f%', 'некоторые', 'fvk'],
#  '0000001189': ['вконтакте', 'информации', 'сегодня'],
#  '0000001196': ['air',
#   'авиакомпания',
#   'asia',
#   'авиалайнер',
#   'на',
#   'белитунг',
#   'большинство'],
#  '0000001197': ['из', '«добавленные»', '«загруженные»'],
#  '0000001198': ['в '],
#  '0000001199': ['tj '],
#  '0000001200': ['ким', 'дэниэл', 'за', 'на', 'pop', 'danthology'],
#  '0000001203': ['текст'],
#  '0000001206': ['алексею',
#   'москве',
#   'землянский',
#   'из',
#   '«твитере»',
#   'гончаренко',
#   'забаненный',
#   'твитере',
#   'причиной',
#   'сша ',
#   'коробков'],
#  '0000001207': ['алгоритм', 'в ', 'например'],
#  '0000001208': ['особый',
#   'вышла',
#   'дождь',
#   'путешествие',
#   'петербурга',
#   'москву'],
#  '0000001209': ['phone', 'известный'],
#  '0000001210': ['ip ',
#   'чирикова',
#   'любопытно',
#   'тем',
#   'парфенова',
#   'евгения',
#   'ольга',
#   'a%',
#   'fstatus',
#   'на',
#   'позднее',
#   'возможно',
#   'это',
#   'funkn',
#   'навального',
#   'fterijoki',
#   'f%',
#   'смс.',
#   'парфеновым',
#   'в ',
#   'помимо',
#   'по',
#   'ftwitter',
#   'романова',
#   'f5'],
#  '0000001213': ['alive',
#   'германии',
#   'f%',
#   'молодой',
#   'fc',
#   'a%',
#   'fde',
#   'clemens',
#   'запись',
#   'channel'],
#  '0000001214': ['парфенова', 'оператор', 'ждем', 'косвено'],
#  '0000001215': ['вашему', 'оказывается', 'киселев', 'димка'],
#  '0000001216': ['nsa ', 'к ', 'в ', 'fb '],
#  '0000001217': ['этот'],
#  '0000001218': ['phone', 'объ', 'yota', 'компании'],
#  '0000001219': ['алексею', 'приговор', 'навальным', 'вынесение', 'олегу'],
#  '0000001223': ['еда',
#   'афишу',
#   'f)',
#   'rambler',
#   'f%',
#   'co',
#   'fwww',
#   'fmir',
#   'мир',
#   'версии',
#   'перезапустят',
#   'a%',
#   'афиша',
#   'читатели',
#   'feda'],
#  '0000001226': ['the',
#   'pirate',
#   'игр',
#   'третий',
#   'gotham',
#   'big',
#   'met',
#   'top',
#   'количество',
#   'bang',
#   'игры',
#   'how',
#   'bay',
#   'dead',
#   'престолов',
#   'theory',
#   'walking',
#   'i ',
#   'your',
#   'mother'],
#  ...}

# %%
#with open('extracted_words.pkl', 'wb') as f:
#    pickle.dump(extracted_words, f)

# %%
'fl' in companies_vc
# Out:
# False

# %%
stop_words = set(['set', 
                  'далее', 
                  'развитие', 
                  'алгоритмы', 
                  'мария', 
                  'red', 
                  'main', 
                  'стартап', 
                  'бюро', 
                  'id', 
                  'поиск', 
                  'ясно',
                  'интерес',
                  'we',
                  'fl',
                  'too',
                  'успех',
                  'система'])

# %%
companies = set(companies_vc)

# %%
companies.add('mail.ru')
companies.add('mail')
companies.add('mail.ru group')
companies.add('мэйл')
#companies.add('facebook')
#companies.add('meta')
companies = companies - stop_words

# %%
extracted_companies = {}
for key in extracted_words.keys():
    for word in extracted_words[key]:
        if word in companies:
            if not key in extracted_companies.keys():
                extracted_companies[key] = []
            extracted_companies[key].append(word)

# %%
extracted_companies
# Out:
# {'0000000013': ['tj'],
#  '0000000020': ['tj'],
#  '0000000097': ['яндекс'],
#  '0000000114': ['mail'],
#  '0000000116': ['tj'],
#  '0000000121': ['intel'],
#  '0000000153': ['mail', 'mail.ru'],
#  '0000000166': ['yota'],
#  '0000000220': ['вконтакте'],
#  '0000000228': ['coub'],
#  '0000000263': ['mail'],
#  '0000000301': ['яндекс'],
#  '0000000330': ['tj'],
#  '0000000342': ['mail', 'qiwi'],
#  '0000000349': ['microsoft'],
#  '0000000350': ['tj'],
#  '0000000375': ['tj'],
#  '0000000414': ['lamoda'],
#  '0000000452': ['автоваз'],
#  '0000000466': ['intel'],
#  '0000000467': ['яндекс', 'mail'],
#  '0000000472': ['яндекс'],
#  '0000000483': ['metro'],
#  '0000000510': ['microsoft'],
#  '0000000532': ['tj'],
#  '0000000554': ['yota'],
#  '0000000590': ['yota'],
#  '0000000593': ['tj'],
#  '0000000596': ['tj'],
#  '0000000644': ['microsoft'],
#  '0000000652': ['tj'],
#  '0000000665': ['одноклассники'],
#  '0000000719': ['mail'],
#  '0000000759': ['ростелеком'],
#  '0000000806': ['тинькофф'],
#  '0000000882': ['yota'],
#  '0000000921': ['одноклассники'],
#  '0000001023': ['mail'],
#  '0000001025': ['вконтакте'],
#  '0000001064': ['intel', 'microsoft'],
#  '0000001080': ['players'],
#  '0000001081': ['yota'],
#  '0000001105': ['tj'],
#  '0000001145': ['yota'],
#  '0000001151': ['яндекс'],
#  '0000001160': ['yota'],
#  '0000001173': ['циан'],
#  '0000001189': ['вконтакте'],
#  '0000001218': ['yota'],
#  '0000001228': ['медиалогия'],
#  '0000001239': ['yota'],
#  '0000001245': ['microsoft'],
#  '0000001251': ['яндекс'],
#  '0000001295': ['вконтакте'],
#  '0000001305': ['tj'],
#  '0000001309': ['mail'],
#  '0000001320': ['вконтакте'],
#  '0000001370': ['вконтакте'],
#  '0000001453': ['microsoft'],
#  '0000001528': ['microsoft'],
#  '0000001536': ['mail'],
#  '0000001550': ['microsoft'],
#  '0000001563': ['макс'],
#  '0000001573': ['microsoft'],
#  '0000001595': ['microsoft'],
#  '0000001618': ['microsoft'],
#  '0000001661': ['вконтакте'],
#  '0000001663': ['мтс'],
#  '0000001684': ['комитет'],
#  '0000001720': ['intel'],
#  '0000001746': ['microsoft'],
#  '0000001760': ['яндекс'],
#  '0000001791': ['mail'],
#  '0000001803': ['вконтакте'],
#  '0000001873': ['яндекс'],
#  '0000001929': ['мегафон'],
#  '0000001957': ['microsoft'],
#  '0000002017': ['microsoft'],
#  '0000002027': ['tj'],
#  '0000002102': ['microsoft'],
#  '0000002115': ['tj'],
#  '0000002132': ['вконтакте'],
#  '0000002133': ['mail', 'mail.ru'],
#  '0000002162': ['microsoft'],
#  '0000002174': ['яндекс'],
#  '0000002213': ['coub'],
#  '0000002275': ['яндекс'],
#  '0000002286': ['microsoft'],
#  '0000002309': ['мегафон'],
#  '0000002315': ['одноклассники', 'ivi'],
#  '0000002319': ['microsoft'],
#  '0000002334': ['mail'],
#  '0000002357': ['microsoft', 'манифест'],
#  '0000002426': ['spotify'],
#  '0000002428': ['microsoft', 'intel'],
#  '0000002447': ['spotify'],
#  '0000002453': ['ростелеком'],
#  '0000002467': ['вконтакте'],
#  '0000002498': ['spotify'],
#  '0000002508': ['яндекс'],
#  '0000002515': ['luxoft'],
#  '0000002566': ['яндекс'],
#  '0000002614': ['яндекс'],
#  '0000002619': ['microsoft'],
#  '0000002663': ['microsoft'],
#  '0000002736': ['одноклассники'],
#  '0000002774': ['яндекс'],
#  '0000002775': ['yota'],
#  '0000002791': ['tj'],
#  '0000002837': ['microsoft'],
#  '0000002867': ['одноклассники', 'вконтакте'],
#  '0000002873': ['microsoft'],
#  '0000002882': ['тинькофф'],
#  '0000002906': ['вконтакте', 'одноклассники'],
#  '0000002918': ['spotify'],
#  '0000002994': ['mail'],
#  '0000003017': ['яндекс'],
#  '0000003022': ['комитет'],
#  '0000003044': ['qiwi'],
#  '0000003046': ['mail', 'mail.ru'],
#  '0000003057': ['microsoft'],
#  '0000003070': ['mail'],
#  '0000003092': ['яндекс'],
#  '0000003107': ['пик'],
#  '0000003119': ['яндекс'],
#  '0000003152': ['metro'],
#  '0000003156': ['яндекс'],
#  '0000003165': ['yota'],
#  '0000003239': ['yota'],
#  '0000003309': ['tj'],
#  '0000003330': ['мегафон'],
#  '0000003380': ['microsoft'],
#  '0000003384': ['tj'],
#  '0000003393': ['microsoft'],
#  '0000003400': ['tj'],
#  '0000003448': ['одноклассники'],
#  '0000003449': ['вконтакте'],
#  '0000003452': ['microsoft'],
#  '0000003461': ['одноклассники'],
#  '0000003467': ['action'],
#  '0000003469': ['вконтакте'],
#  '0000003474': ['intel'],
#  '0000003502': ['microsoft'],
#  '0000003545': ['microsoft'],
#  '0000003627': ['microsoft'],
#  '0000003632': ['yota'],
#  '0000003634': ['microsoft'],
#  '0000003638': ['microsoft'],
#  '0000003713': ['microsoft'],
#  '0000003720': ['mail'],
#  '0000003721': ['tj'],
#  '0000003730': ['yota'],
#  '0000003753': ['хайс'],
#  '0000003774': ['microsoft'],
#  '0000003795': ['microsoft'],
#  '0000003800': ['microsoft'],
#  '0000003912': ['intel'],
#  '0000003921': ['action'],
#  '0000003963': ['яндекс'],
#  '0000003981': ['microsoft'],
#  '0000004008': ['microsoft'],
#  '0000004119': ['яндекс'],
#  '0000004134': ['microsoft'],
#  '0000004140': ['spotify'],
#  '0000004187': ['microsoft'],
#  '0000004188': ['tj'],
#  '0000004197': ['комитет'],
#  '0000004202': ['microsoft'],
#  '0000004229': ['yota'],
#  '0000004242': ['boomstarter'],
#  '0000004254': ['tj'],
#  '0000004262': ['одноклассники'],
#  '0000004268': ['microsoft'],
#  '0000004276': ['mail'],
#  '0000004303': ['microsoft'],
#  '0000004373': ['яндекс'],
#  '0000004424': ['microsoft'],
#  '0000004426': ['mail'],
#  '0000004481': ['spotify'],
#  '0000004495': ['вконтакте'],
#  '0000004531': ['ebay'],
#  '0000004616': ['mail'],
#  '0000004656': ['mail', 'mail.ru'],
#  '0000004663': ['яндекс', 'яндекс.маркет'],
#  '0000004678': ['медиалогия', 'вконтакте'],
#  '0000004698': ['spotify'],
#  '0000004725': ['яндекс'],
#  '0000004743': ['mail'],
#  '0000004751': ['макс'],
#  '0000004759': ['яндекс', 'mail'],
#  '0000004766': ['мегафон'],
#  '0000004776': ['вконтакте'],
#  '0000004788': ['microsoft'],
#  '0000004832': ['ростелеком'],
#  '0000004833': ['вконтакте'],
#  '0000004857': ['макс'],
#  '0000004987': ['microsoft'],
#  '0000005018': ['microsoft'],
#  '0000005019': ['ozon', 'mail.ru', 'microsoft', 'mail', 'яндекс'],
#  '0000005022': ['яндекс'],
#  '0000005024': ['mail'],
#  '0000005123': ['ростелеком'],
#  '0000005186': ['вконтакте'],
#  '0000005187': ['fura'],
#  '0000005211': ['одноклассники'],
#  '0000005259': ['spotify'],
#  '0000005324': ['microsoft'],
#  '0000005405': ['microsoft'],
#  '0000005406': ['мегафон'],
#  '0000005412': ['microsoft'],
#  '0000005453': ['макс'],
#  '0000005480': ['yota'],
#  '0000005502': ['intel'],
#  '0000005517': ['microsoft'],
#  '0000005536': ['яндекс'],
#  '0000005540': ['вконтакте'],
#  '0000005551': ['яндекс'],
#  '0000005593': ['tj'],
#  '0000005599': ['tj'],
#  '0000005721': ['microsoft'],
#  '0000005782': ['microsoft', 'яндекс', 'mail'],
#  '0000005803': ['ингосстрах'],
#  '0000005809': ['qiwi'],
#  '0000005822': ['microsoft'],
#  '0000005860': ['yota'],
#  '0000005869': ['microsoft'],
#  '0000005912': ['mail'],
#  '0000005941': ['microsoft'],
#  '0000006007': ['яндекс'],
#  '0000006008': ['яндекс'],
#  '0000006075': ['microsoft'],
#  '0000006103': ['tj'],
#  '0000006145': ['microsoft'],
#  '0000006206': ['вконтакте'],
#  '0000006314': ['microsoft'],
#  '0000006329': ['tj'],
#  '0000006338': ['вконтакте'],
#  '0000006345': ['ростелеком'],
#  '0000006376': ['точка'],
#  '0000006377': ['microsoft'],
#  '0000006403': ['тинькофф'],
#  '0000006414': ['microsoft'],
#  '0000006421': ['tj'],
#  '0000006490': ['microsoft'],
#  '0000006585': ['microsoft'],
#  '0000006589': ['tj'],
#  '0000006604': ['spotify'],
#  '0000006633': ['yota'],
#  '0000006644': ['microsoft'],
#  '0000006668': ['яндекс'],
#  '0000006698': ['spotify'],
#  '0000006718': ['yota'],
#  '0000006739': ['комитет'],
#  '0000006785': ['microsoft'],
#  '0000006869': ['heineken'],
#  '0000006894': ['tj'],
#  '0000006937': ['microsoft'],
#  '0000006952': ['макс'],
#  '0000006953': ['макс'],
#  '0000006965': ['tj'],
#  '0000006983': ['microsoft'],
#  '0000007001': ['яндекс'],
#  '0000007030': ['yota'],
#  '0000007112': ['yota'],
#  '0000007152': ['honor'],
#  '0000007201': ['microsoft'],
#  '0000007202': ['microsoft'],
#  '0000007220': ['microsoft'],
#  '0000007241': ['яндекс'],
#  '0000007250': ['microsoft'],
#  '0000007366': ['microsoft'],
#  '0000007385': ['тинькофф'],
#  '0000007393': ['microsoft'],
#  '0000007408': ['яндекс'],
#  '0000007413': ['yota'],
#  '0000007448': ['mail'],
#  '0000007449': ['мегафон'],
#  '0000007464': ['microsoft'],
#  '0000007467': ['mail', 'mail.ru'],
#  '0000007497': ['microsoft'],
#  '0000007498': ['tj'],
#  '0000007514': ['tj'],
#  '0000007557': ['microsoft', 'intel'],
#  '0000007588': ['яндекс'],
#  '0000007614': ['яндекс'],
#  '0000007636': ['yota'],
#  '0000007644': ['яндекс'],
#  '0000007681': ['microsoft'],
#  '0000007684': ['simple'],
#  '0000007717': ['mail.ru', 'mail'],
#  '0000007803': ['тинькофф'],
#  '0000007916': ['яндекс'],
#  '0000007955': ['яндекс'],
#  '0000007997': ['boomstarter'],
#  '0000008008': ['microsoft'],
#  '0000008027': ['комитет'],
#  '0000008088': ['вконтакте'],
#  '0000008155': ['action'],
#  '0000008158': ['tj'],
#  '0000008187': ['яндекс'],
#  '0000008270': ['microsoft', 'tj'],
#  '0000008287': ['microsoft'],
#  '0000008327': ['мегафон'],
#  '0000008374': ['microsoft'],
#  '0000008401': ['yota', 'intel'],
#  '0000008434': ['microsoft'],
#  '0000008438': ['яндекс'],
#  '0000008468': ['макс'],
#  '0000008544': ['yota'],
#  '0000008561': ['metro'],
#  '0000008652': ['яндекс'],
#  '0000008714': ['комитет'],
#  '0000008726': ['авито'],
#  '0000008796': ['яндекс'],
#  '0000008806': ['макс'],
#  '0000008852': ['microsoft'],
#  '0000008859': ['tj'],
#  '0000008918': ['tj'],
#  '0000008921': ['макс'],
#  '0000008929': ['мегафон', 'yota'],
#  '0000008970': ['тинькофф'],
#  '0000008971': ['microsoft'],
#  '0000008987': ['microsoft'],
#  '0000009012': ['вконтакте'],
#  '0000009075': ['яндекс', 'gett'],
#  '0000009099': ['microsoft'],
#  '0000009120': ['яндекс'],
#  '0000009130': ['mail'],
#  '0000009147': ['microsoft'],
#  '0000009158': ['макс'],
#  '0000009164': ['spotify'],
#  '0000009182': ['spotify'],
#  '0000009189': ['vk'],
#  '0000009200': ['microsoft'],
#  '0000009212': ['intel'],
#  '0000009215': ['mail'],
#  '0000009218': ['microsoft'],
#  '0000009277': ['комитет'],
#  '0000009333': ['vk'],
#  '0000009369': ['яндекс'],
#  '0000009414': ['яндекс'],
#  '0000009453': ['microsoft'],
#  '0000009494': ['spotify'],
#  '0000009504': ['microsoft'],
#  '0000009529': ['microsoft'],
#  '0000009588': ['mail'],
#  '0000009656': ['microsoft'],
#  '0000009694': ['uniqlo'],
#  '0000009708': ['microsoft'],
#  '0000009717': ['tj'],
#  '0000009743': ['intel'],
#  '0000009794': ['microsoft'],
#  '0000009827': ['gett'],
#  '0000009847': ['tj'],
#  '0000009851': ['microsoft'],
#  '0000009853': ['tj'],
#  '0000009858': ['тинькофф'],
#  '0000009868': ['мтс', 'мегафон'],
#  '0000009876': ['microsoft'],
#  '0000009902': ['лайфхакер', 'spotify'],
#  '0000009908': ['uniqlo'],
#  '0000009947': ['вконтакте'],
#  '0000009955': ['microsoft'],
#  '0000009960': ['комитет'],
#  '0000010050': ['microsoft'],
#  '0000010093': ['microsoft'],
#  '0000010146': ['metro'],
#  '0000010153': ['microsoft'],
#  '0000010154': ['gett'],
#  '0000010160': ['одноклассники'],
#  '0000010183': ['microsoft'],
#  '0000010217': ['вконтакте'],
#  '0000010240': ['gett', 'яндекс'],
#  '0000010260': ['sports.ru'],
#  '0000010284': ['яндекс'],
#  '0000010319': ['комитет'],
#  '0000010416': ['яндекс'],
#  '0000010448': ['yota'],
#  '0000010462': ['комитет'],
#  '0000010464': ['microsoft'],
#  '0000010489': ['мегафон'],
#  '0000010551': ['mail.ru', 'mail'],
#  '0000010573': ['microsoft'],
#  '0000010611': ['microsoft'],
#  '0000010637': ['intel'],
#  '0000010655': ['microsoft'],
#  '0000010675': ['microsoft'],
#  '0000010677': ['microsoft'],
#  '0000010682': ['mail'],
#  '0000010684': ['microsoft'],
#  '0000010685': ['одноклассники'],
#  '0000010695': ['microsoft'],
#  '0000010696': ['microsoft'],
#  '0000010699': ['mail'],
#  '0000010747': ['яндекс'],
#  '0000010771': ['комитет'],
#  '0000010802': ['яндекс', 'tj'],
#  '0000010806': ['одноклассники'],
#  '0000010835': ['комитет'],
#  '0000010911': ['microsoft'],
#  '0000010925': ['microsoft'],
#  '0000010941': ['yota'],
#  '0000010956': ['vk'],
#  '0000010973': ['microsoft'],
#  '0000011005': ['microsoft'],
#  '0000011025': ['microsoft'],
#  '0000011033': ['макс'],
#  '0000011064': ['microsoft'],
#  '0000011069': ['eset'],
#  '0000011072': ['microsoft'],
#  '0000011092': ['mail'],
#  '0000011148': ['microsoft'],
#  '0000011202': ['яндекс'],
#  '0000011242': ['microsoft'],
#  '0000011244': ['пик'],
#  '0000011265': ['metro'],
#  '0000011300': ['яндекс'],
#  '0000011320': ['логомашина'],
#  '0000011378': ['microsoft'],
#  '0000011400': ['spotify'],
#  '0000011408': ['microsoft'],
#  '0000011438': ['пик'],
#  '0000011451': ['mail.ru', 'mail'],
#  '0000011469': ['microsoft'],
#  '0000011481': ['логомашина'],
#  '0000011512': ['ivi'],
#  '0000011580': ['microsoft'],
#  '0000011648': ['ингосстрах'],
#  '0000011649': ['yota'],
#  '0000011692': ['mail', 'яндекс', 'mail.ru'],
#  '0000011711': ['microsoft'],
#  '0000011732': ['мэйл'],
#  '0000011760': ['microsoft'],
#  '0000011814': ['microsoft'],
#  '0000011966': ['yota'],
#  '0000011989': ['uniqlo'],
#  '0000012001': ['yota'],
#  '0000012051': ['ebay', 'microsoft'],
#  '0000012095': ['acer'],
#  '0000012099': ['яндекс'],
#  '0000012120': ['microsoft'],
#  '0000012123': ['tj'],
#  '0000012125': ['вконтакте'],
#  '0000012163': ['spotify'],
#  '0000012177': ['microsoft'],
#  '0000012223': ['яндекс'],
#  '0000012236': ['яндекс'],
#  '0000012318': ['microsoft'],
#  '0000012331': ['microsoft'],
#  '0000012377': ['qiwi'],
#  '0000012387': ['yota'],
#  '0000012430': ['mail', 'яндекс', 'одноклассники'],
#  '0000012440': ['microsoft'],
#  '0000012462': ['tj'],
#  '0000012571': ['yota'],
#  '0000012620': ['tj'],
#  '0000012642': ['яндекс'],
#  '0000012672': ['microsoft'],
#  '0000012674': ['одноклассники'],
#  '0000012697': ['microsoft'],
#  '0000012705': ['microsoft'],
#  '0000012707': ['intel'],
#  '0000012710': ['microsoft'],
#  '0000012737': ['макс'],
#  '0000012746': ['microsoft'],
#  '0000012796': ['microsoft'],
#  '0000012809': ['мегафон'],
#  '0000012868': ['яндекс'],
#  '0000012912': ['комитет'],
#  '0000012924': ['microsoft'],
#  '0000012930': ['макс'],
#  '0000012932': ['ростелеком'],
#  '0000012936': ['ростелеком'],
#  '0000012957': ['microsoft'],
#  '0000012961': ['ростелеком'],
#  '0000012983': ['tj'],
#  '0000012993': ['яндекс', 'вконтакте'],
#  '0000013059': ['fura'],
#  '0000013068': ['microsoft'],
#  '0000013102': ['microsoft'],
#  '0000013127': ['microsoft'],
#  '0000013165': ['yota'],
#  '0000013278': ['mail'],
#  '0000013317': ['didi'],
#  '0000013356': ['яндекс', 'контур'],
#  '0000013361': ['intel'],
#  '0000013383': ['acer'],
#  '0000013384': ['yota'],
#  '0000013408': ['microsoft'],
#  '0000013450': ['microsoft'],
#  '0000013495': ['microsoft'],
#  '0000013550': ['intel'],
#  '0000013556': ['microsoft'],
#  '0000013563': ['spotify'],
#  '0000013577': ['mail'],
#  '0000013583': ['microsoft'],
#  '0000013631': ['ростелеком'],
#  '0000013681': ['комитет'],
#  '0000013709': ['microsoft'],
#  '0000013710': ['яндекс'],
#  '0000013721': ['intel'],
#  '0000013726': ['microsoft'],
#  '0000013728': ['coub'],
#  '0000013741': ['мегафон'],
#  '0000013798': ['microsoft'],
#  '0000013841': ['яндекс'],
#  '0000013857': ['microsoft'],
#  '0000013866': ['microsoft'],
#  '0000013868': ['яндекс'],
#  '0000013894': ['вконтакте'],
#  '0000013945': ['вконтакте'],
#  '0000014043': ['tj', 'пик'],
#  '0000014052': ['microsoft'],
#  '0000014095': ['mail'],
#  '0000014107': ['yota'],
#  '0000014231': ['макс'],
#  '0000014254': ['яндекс'],
#  '0000014285': ['яндекс'],
#  '0000014406': ['microsoft'],
#  '0000014458': ['metro'],
#  '0000014460': ['вконтакте'],
#  '0000014468': ['microsoft'],
#  '0000014598': ['tj'],
#  '0000014605': ['яндекс'],
#  '0000014657': ['яндекс'],
#  '0000014693': ['spotify'],
#  '0000014714': ['microsoft'],
#  '0000014719': ['яндекс'],
#  '0000014735': ['яндекс'],
#  '0000014787': ['coub'],
#  '0000014808': ['mail'],
#  '0000014880': ['яндекс', 'mail', 'microsoft'],
#  '0000014913': ['microsoft'],
#  '0000014916': ['яндекс'],
#  '0000014929': ['gett'],
#  '0000014933': ['ростелеком'],
#  '0000014953': ['яндекс', 'spotify'],
#  '0000014959': ['microsoft'],
#  '0000014961': ['mail.ru', 'mail'],
#  '0000014969': ['макс'],
#  '0000015038': ['microsoft'],
#  '0000015062': ['microsoft'],
#  '0000015095': ['microsoft'],
#  '0000015107': ['intel'],
#  '0000015118': ['microsoft'],
#  '0000015219': ['microsoft'],
#  '0000015303': ['microsoft'],
#  '0000015305': ['яндекс'],
#  '0000015319': ['microsoft'],
#  '0000015372': ['microsoft'],
#  '0000015398': ['комитет'],
#  '0000015444': ['вконтакте'],
#  '0000015452': ['intel'],
#  '0000015477': ['медиалогия'],
#  '0000015485': ['intel'],
#  '0000015501': ['microsoft'],
#  '0000015519': ['яндекс'],
#  '0000015525': ['microsoft'],
#  '0000015547': ['вконтакте', 'tj'],
#  '0000015576': ['вконтакте', 'tj'],
#  '0000015603': ['okko', 'ivi'],
#  '0000015606': ['яндекс'],
#  '0000015617': ['fura'],
#  '0000015670': ['яндекс', 'microsoft'],
#  '0000015680': ['yota'],
#  '0000015695': ['spotify'],
#  '0000015766': ['макс'],
#  '0000015783': ['microsoft'],
#  '0000015875': ['yota'],
#  '0000015890': ['яндекс'],
#  '0000015909': ['microsoft', 'intel'],
#  '0000015910': ['microsoft'],
#  '0000015998': ['microsoft'],
#  '0000016001': ['microsoft', 'spotify'],
#  '0000016003': ['mail'],
#  '0000016010': ['microsoft'],
#  '0000016148': ['yota'],
#  '0000016184': ['авито'],
#  '0000016209': ['mail'],
#  '0000016212': ['microsoft'],
#  '0000016242': ['microsoft'],
#  '0000016246': ['mail'],
#  '0000016277': ['spotify'],
#  '0000016330': ['макс'],
#  '0000016350': ['яндекс'],
#  '0000016352': ['tj'],
#  '0000016379': ['яндекс'],
#  '0000016419': ['microsoft'],
#  '0000016444': ['вконтакте'],
#  '0000016447': ['microsoft'],
#  '0000016454': ['одноклассники'],
#  '0000016480': ['microsoft'],
#  '0000016565': ['mail'],
#  '0000016751': ['microsoft'],
#  '0000016785': ['вконтакте'],
#  '0000016835': ['microsoft'],
#  '0000016894': ['лайфхакер'],
#  '0000016963': ['spotify'],
#  '0000017034': ['mail'],
#  '0000017083': ['тинькофф'],
#  '0000017116': ['intel'],
#  '0000017139': ['яндекс', 'tj', 'selectel', 'intel'],
#  '0000017150': ['tj'],
#  '0000017220': ['комитет'],
#  '0000017296': ['yota'],
#  '0000017305': ['яндекс'],
#  '0000017312': ['spotify'],
#  '0000017327': ['qiwi'],
#  '0000017337': ['spotify'],
#  '0000017352': ['цифра'],
#  '0000017359': ['fura'],
#  '0000017362': ['fura'],
#  '0000017468': ['яндекс'],
#  '0000017488': ['boomstarter'],
#  '0000017489': ['mail.ru', 'мэйл', 'mail', 'vk'],
#  '0000017549': ['microsoft'],
#  '0000017558': ['vk'],
#  '0000017608': ['ozon'],
#  '0000017617': ['вконтакте'],
#  '0000017749': ['яндекс'],
#  '0000017766': ['microsoft'],
#  '0000017777': ['fura'],
#  '0000017796': ['вконтакте'],
#  '0000017802': ['вконтакте'],
#  '0000017808': ['spotify'],
#  '0000017829': ['microsoft'],
#  '0000017846': ['microsoft'],
#  '0000017850': ['microsoft'],
#  '0000017923': ['яндекс'],
#  '0000017963': ['евраз'],
#  '0000017974': ['вконтакте'],
#  '0000018009': ['яндекс'],
#  '0000018020': ['ростелеком'],
#  '0000018027': ['microsoft'],
#  '0000018055': ['манифест'],
#  '0000018064': ['microsoft'],
#  '0000018096': ['microsoft'],
#  '0000018107': ['intel'],
#  '0000018116': ['одноклассники'],
#  '0000018155': ['яндекс'],
#  '0000018160': ['комитет'],
#  '0000018189': ['mail', 'яндекс', 'mail.ru'],
#  '0000018247': ['microsoft'],
#  '0000018257': ['yota'],
#  '0000018259': ['microsoft'],
#  '0000018261': ['tj'],
#  '0000018278': ['metro'],
#  '0000018295': ['mail'],
#  '0000018369': ['players'],
#  '0000018391': ['metro'],
#  '0000018412': ['mail'],
#  '0000018499': ['microsoft'],
#  '0000018507': ['mail'],
#  '0000018519': ['макс'],
#  '0000018522': ['макс'],
#  '0000018535': ['макс'],
#  '0000018557': ['яндекс'],
#  '0000018568': ['одноклассники'],
#  '0000018583': ['одноклассники'],
#  '0000018627': ['яндекс'],
#  '0000018640': ['microsoft'],
#  '0000018658': ['tj'],
#  '0000018665': ['яндекс'],
#  '0000018680': ['яндекс'],
#  '0000018753': ['didi'],
#  '0000018778': ['пик'],
#  '0000018803': ['вконтакте'],
#  '0000018868': ['ростелеком'],
#  '0000018895': ['mail'],
#  '0000018901': ['mail', 'mail.ru'],
#  '0000019038': ['комитет'],
#  '0000019078': ['ivi'],
#  '0000019084': ['яндекс'],
#  '0000019100': ['вконтакте'],
#  '0000019170': ['точка'],
#  '0000019193': ['action'],
#  '0000019230': ['mail'],
#  '0000019299': ['пик'],
#  '0000019337': ['яндекс', 'spotify'],
#  '0000019382': ['яндекс'],
#  '0000019429': ['комитет'],
#  '0000019473': ['яндекс', 'авито', 'яндекс.маркет'],
#  '0000019476': ['microsoft'],
#  '0000019492': ['медиалогия'],
#  '0000019545': ['одноклассники'],
#  '0000019594': ['mail'],
#  '0000019646': ['yota'],
#  '0000019669': ['microsoft'],
#  '0000019705': ['ингосстрах'],
#  '0000019745': ['яндекс'],
#  '0000019751': ['яндекс'],
#  '0000019758': ['microsoft'],
#  '0000019761': ['microsoft'],
#  '0000019782': ['яндекс', 'qiwi'],
#  '0000019816': ['spotify'],
#  '0000019817': ['медиалогия'],
#  '0000019919': ['пик'],
#  '0000019979': ['вконтакте'],
#  '0000019980': ['яндекс'],
#  '0000019989': ['яндекс', 'одноклассники'],
#  '0000020021': ['одноклассники', 'вконтакте'],
#  '0000020025': ['microsoft'],
#  '0000020076': ['microsoft'],
#  '0000020098': ['ростелеком'],
#  '0000020150': ['microsoft'],
#  '0000020156': ['spotify'],
#  '0000020166': ['metro'],
#  '0000020213': ['yota'],
#  '0000020247': ['макс'],
#  '0000020312': ['одноклассники', 'microsoft'],
#  '0000020349': ['microsoft'],
#  '0000020437': ['microsoft'],
#  '0000020559': ['intel'],
#  '0000020560': ['ozon', 'microsoft'],
#  '0000020661': ['mail', 'mail.ru'],
#  '0000020670': ['spotify'],
#  '0000020688': ['мегафон'],
#  '0000020697': ['microsoft'],
#  '0000020745': ['metro'],
#  '0000020819': ['тинькофф'],
#  '0000020839': ['макс'],
#  '0000020856': ['макс'],
#  '0000020860': ['комитет'],
#  '0000020882': ['пик'],
#  '0000020883': ['microsoft'],
#  '0000020887': ['tj'],
#  '0000020888': ['яндекс'],
#  '0000021042': ['boomstarter'],
#  '0000021073': ['яндекс'],
#  '0000021074': ['intel'],
#  '0000021082': ['комитет'],
#  '0000021083': ['одноклассники'],
#  '0000021084': ['intel', 'microsoft'],
#  '0000021095': ['microsoft'],
#  '0000021118': ['яндекс'],
#  '0000021126': ['яндекс'],
#  '0000021179': ['яндекс'],
#  '0000021201': ['metro'],
#  '0000021246': ['microsoft'],
#  '0000021249': ['яндекс'],
#  '0000021267': ['макс'],
#  '0000021273': ['яндекс', 'mail'],
#  '0000021295': ['mail'],
#  '0000021312': ['пик'],
#  '0000021314': ['intel'],
#  '0000021315': ['комитет'],
#  '0000021378': ['крок'],
#  '0000021390': ['microsoft'],
#  '0000021401': ['microsoft'],
#  '0000021429': ['microsoft'],
#  '0000021513': ['microsoft', 'tj'],
#  '0000021527': ['автоваз'],
#  '0000021578': ['microsoft'],
#  '0000021588': ['яндекс', 'яндекс.маркет'],
#  '0000021625': ['spotify'],
#  '0000021651': ['ростелеком'],
#  '0000021653': ['макс'],
#  '0000021657': ['microsoft'],
#  '0000021698': ['microsoft'],
#  '0000021710': ['mail'],
#  '0000021712': ['metro'],
#  '0000021719': ['мегафон'],
#  '0000021778': ['яндекс', 'одноклассники'],
#  '0000021805': ['spotify'],
#  '0000021824': ['intel'],
#  '0000021835': ['яндекс'],
#  '0000021855': ['яндекс', 'яндекс.маркет'],
#  '0000021888': ['tj'],
#  '0000021897': ['vk', 'mail.ru', 'mail'],
#  '0000021918': ['яндекс'],
#  '0000021972': ['microsoft'],
#  '0000022000': ['вконтакте'],
#  '0000022005': ['microsoft'],
#  '0000022057': ['вконтакте'],
#  '0000022072': ['mail.ru', 'mail'],
#  '0000022147': ['microsoft', 'mail.ru', 'mail'],
#  '0000022155': ['mail.ru', 'mail'],
#  '0000022174': ['одноклассники'],
#  '0000022179': ['газпромбанк'],
#  '0000022181': ['microsoft'],
#  '0000022214': ['microsoft'],
#  '0000022257': ['одноклассники'],
#  '0000022268': ['макс'],
#  '0000022283': ['microsoft'],
#  '0000022285': ['microsoft'],
#  '0000022313': ['авито'],
#  '0000022368': ['microsoft'],
#  '0000022374': ['яндекс'],
#  '0000022379': ['яндекс'],
#  '0000022388': ['мегафон', 'ростелеком'],
#  '0000022400': ['microsoft'],
#  '0000022411': ['вконтакте', 'tj'],
#  '0000022458': ['eset'],
#  '0000022465': ['яндекс'],
#  '0000022485': ['mail'],
#  '0000022491': ['yota'],
#  '0000022496': ['газпромбанк'],
#  '0000022506': ['tj'],
#  '0000022530': ['газпромбанк'],
#  '0000022591': ['мегафон'],
#  '0000022618': ['simple'],
#  '0000022651': ['mail'],
#  '0000022669': ['vk'],
#  '0000022672': ['microsoft'],
#  '0000022681': ['комитет'],
#  '0000022728': ['пик'],
#  '0000022737': ['microsoft'],
#  '0000022778': ['mail.ru', 'mail', 'одноклассники'],
#  '0000022859': ['metro'],
#  '0000022872': ['комитет'],
#  '0000022879': ['сибур'],
#  '0000022894': ['microsoft'],
#  '0000022897': ['microsoft'],
#  '0000022914': ['badoo'],
#  '0000022964': ['mail'],
#  '0000022982': ['яндекс'],
#  '0000022987': ['action', 'tj', 'mail'],
#  '0000022999': ['mail'],
#  '0000023113': ['макс'],
#  '0000023118': ['ростелеком'],
#  '0000023167': ['мегафон'],
#  '0000023178': ['intel'],
#  '0000023219': ['макс'],
#  '0000023239': ['lamoda', 'одноклассники'],
#  '0000023271': ['яндекс'],
#  '0000023284': ['mail'],
#  '0000023296': ['microsoft'],
#  '0000023312': ['microsoft'],
#  '0000023333': ['microsoft'],
#  '0000023340': ['mail', 'tj'],
#  '0000023448': ['fura'],
#  '0000023458': ['badoo'],
#  '0000023481': ['mail'],
#  '0000023538': ['мегафон'],
#  '0000023551': ['макс'],
#  '0000023555': ['metro'],
#  '0000023583': ['microsoft'],
#  '0000023601': ['яндекс', 'mail.ru', 'mail', 'одноклассники'],
#  '0000023607': ['microsoft'],
#  '0000023610': ['microsoft'],
#  '0000023620': ['microsoft'],
#  '0000023629': ['microsoft'],
#  '0000023641': ['пик'],
#  '0000023678': ['одноклассники'],
#  '0000023691': ['microsoft'],
#  '0000023725': ['microsoft'],
#  '0000023730': ['яндекс'],
#  '0000023757': ['яндекс'],
#  '0000023776': ['intel'],
#  '0000023801': ['microsoft'],
#  '0000023809': ['яндекс'],
#  '0000023817': ['яндекс'],
#  '0000023822': ['вконтакте'],
#  '0000023827': ['тинькофф'],
#  '0000023835': ['вконтакте'],
#  '0000023876': ['mail', 'яндекс'],
#  '0000023902': ['макс'],
#  '0000023905': ['яндекс', 'mail.ru', 'mail', 'одноклассники'],
#  '0000023913': ['microsoft'],
#  '0000023933': ['комитет'],
#  '0000023937': ['тинькофф'],
#  '0000023943': ['макс'],
#  '0000024007': ['microsoft'],
#  '0000024009': ['комитет'],
#  '0000024019': ['microsoft'],
#  '0000024065': ['яндекс'],
#  '0000024066': ['макс'],
#  '0000024097': ['одноклассники'],
#  '0000024104': ['microsoft'],
#  '0000024118': ['mail', 'mail.ru'],
#  '0000024124': ['spotify'],
#  '0000024125': ['boomstarter'],
#  '0000024178': ['mail'],
#  '0000024182': ['тинькофф'],
#  '0000024187': ['тинькофф'],
#  '0000024204': ['яндекс'],
#  '0000024210': ['mail.ru', 'mail'],
#  '0000024213': ['контур'],
#  '0000024221': ['вконтакте'],
#  '0000024238': ['мегафон'],
#  '0000024283': ['metro', 'mail'],
#  '0000024338': ['яндекс'],
#  '0000024374': ['vk'],
#  '0000024387': ['тинькофф'],
#  '0000024388': ['boomstarter'],
#  '0000024419': ['mail'],
#  '0000024426': ['mail'],
#  '0000024471': ['honor'],
#  '0000024483': ['яндекс'],
#  '0000024489': ['microsoft'],
#  '0000024491': ['тинькофф'],
#  '0000024501': ['microsoft'],
#  '0000024508': ['boomstarter'],
#  '0000024533': ['комитет'],
#  '0000024561': ['макс'],
#  '0000024569': ['яндекс'],
#  '0000024573': ['макс'],
#  '0000024603': ['microsoft'],
#  '0000024604': ['fura'],
#  '0000024622': ['яндекс'],
#  '0000024636': ['одноклассники'],
#  '0000024650': ['mail'],
#  '0000024680': ['комитет'],
#  '0000024686': ['яндекс'],
#  '0000024747': ['ростелеком'],
#  '0000024786': ['макс'],
#  '0000024793': ['макс'],
#  '0000024809': ['microsoft'],
#  '0000024828': ['microsoft'],
#  '0000024859': ['mail.ru', 'mail'],
#  '0000024866': ['microsoft', 'mail.ru', 'mail'],
#  '0000024910': ['gett'],
#  '0000024919': ['яндекс'],
#  '0000024923': ['яндекс'],
#  '0000024930': ['mail'],
#  '0000024960': ['яндекс'],
#  '0000024972': ['microsoft'],
#  '0000025014': ['mail.ru', 'mail'],
#  '0000025015': ['microsoft'],
#  '0000025044': ['яндекс'],
#  '0000025120': ['intel'],
#  '0000025168': ['яндекс'],
#  '0000025184': ['комитет'],
#  '0000025203': ['яндекс'],
#  '0000025215': ['players'],
#  '0000025219': ['макс'],
#  '0000025240': ['вконтакте'],
#  '0000025248': ['spotify'],
#  '0000025249': ['mail'],
#  '0000025303': ['microsoft'],
#  '0000025311': ['microsoft'],
#  '0000025316': ['fura'],
#  '0000025329': ['яндекс'],
#  '0000025336': ['яндекс'],
#  '0000025371': ['яндекс'],
#  '0000025388': ['яндекс'],
#  '0000025415': ['microsoft'],
#  '0000025460': ['vk'],
#  '0000025478': ['microsoft'],
#  '0000025500': ['microsoft', 'яндекс', 'mail.ru', 'mail'],
#  '0000025502': ['vk'],
#  '0000025503': ['mail'],
#  '0000025508': ['яндекс', 'coub'],
#  '0000025520': ['mail', 'одноклассники'],
#  '0000025523': ['яндекс'],
#  '0000025579': ['яндекс'],
#  '0000025625': ['microsoft'],
#  '0000025626': ['mail'],
#  '0000025637': ['microsoft'],
#  '0000025640': ['yota'],
#  '0000025661': ['microsoft'],
#  '0000025690': ['яндекс'],
#  '0000025706': ['microsoft'],
#  '0000025717': ['spotify'],
#  '0000025726': ['яндекс'],
#  '0000025749': ['fura'],
#  '0000025767': ['boomstarter', 'globus'],
#  '0000025856': ['mail'],
#  '0000025861': ['макс'],
#  '0000025875': ['mail.ru', 'mail'],
#  '0000025876': ['mail'],
#  '0000025923': ['microsoft'],
#  '0000025944': ['комитет'],
#  '0000025971': ['fura'],
#  '0000025986': ['microsoft'],
#  '0000026021': ['mail'],
#  '0000026025': ['яндекс', 'chatfuel'],
#  '0000026043': ['fura'],
#  '0000026055': ['яндекс'],
#  '0000026068': ['mail'],
#  '0000026079': ['райффайзенбанк'],
#  '0000026095': ['яндекс'],
#  '0000026105': ['яндекс'],
#  '0000026107': ['mail'],
#  '0000026118': ['тинькофф'],
#  '0000026125': ['авито'],
#  '0000026140': ['яндекс', 'яндекс.маркет'],
#  '0000026143': ['vk'],
#  '0000026183': ['mindbox'],
#  '0000026187': ['пик'],
#  '0000026189': ['microsoft'],
#  '0000026230': ['яндекс', 'яндекс.маркет'],
#  '0000026326': ['яндекс'],
#  '0000026335': ['яндекс'],
#  '0000026339': ['microsoft'],
#  '0000026346': ['action'],
#  '0000026355': ['яндекс'],
#  '0000026380': ['тинькофф'],
#  '0000026382': ['mail'],
#  '0000026384': ['microsoft'],
#  '0000026391': ['яндекс'],
#  '0000026412': ['microsoft'],
#  '0000026446': ['tj'],
#  '0000026452': ['microsoft'],
#  '0000026480': ['microsoft'],
#  '0000026547': ['яндекс'],
#  '0000026584': ['яндекс'],
#  '0000026669': ['яндекс'],
#  '0000026687': ['spotify'],
#  '0000026713': ['точка'],
#  ...}

# %%
#with open('extracted_companies.pkl', 'wb') as f:
#    pickle.dump(extracted_companies, f)

# %%
edges = []
for key in extracted_companies.keys():
    if len(extracted_companies[key]) > 1:
        for element in itertools.product(*[extracted_companies[key], extracted_companies[key]]):
            edges.append(element)

# %%
edges
# Out:
# [('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'qiwi'),
#  ('qiwi', 'mail'),
#  ('qiwi', 'qiwi'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail'),
#  ('intel', 'intel'),
#  ('intel', 'microsoft'),
#  ('microsoft', 'intel'),
#  ('microsoft', 'microsoft'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('одноклассники', 'одноклассники'),
#  ('одноклассники', 'ivi'),
#  ('ivi', 'одноклассники'),
#  ('ivi', 'ivi'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'манифест'),
#  ('манифест', 'microsoft'),
#  ('манифест', 'манифест'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'intel'),
#  ('intel', 'microsoft'),
#  ('intel', 'intel'),
#  ('одноклассники', 'одноклассники'),
#  ('одноклассники', 'вконтакте'),
#  ('вконтакте', 'одноклассники'),
#  ('вконтакте', 'вконтакте'),
#  ('вконтакте', 'вконтакте'),
#  ('вконтакте', 'одноклассники'),
#  ('одноклассники', 'вконтакте'),
#  ('одноклассники', 'одноклассники'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'яндекс.маркет'),
#  ('яндекс.маркет', 'яндекс'),
#  ('яндекс.маркет', 'яндекс.маркет'),
#  ('медиалогия', 'медиалогия'),
#  ('медиалогия', 'вконтакте'),
#  ('вконтакте', 'медиалогия'),
#  ('вконтакте', 'вконтакте'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail'),
#  ('ozon', 'ozon'),
#  ('ozon', 'mail.ru'),
#  ('ozon', 'microsoft'),
#  ('ozon', 'mail'),
#  ('ozon', 'яндекс'),
#  ('mail.ru', 'ozon'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'microsoft'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'яндекс'),
#  ('microsoft', 'ozon'),
#  ('microsoft', 'mail.ru'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'mail'),
#  ('microsoft', 'яндекс'),
#  ('mail', 'ozon'),
#  ('mail', 'mail.ru'),
#  ('mail', 'microsoft'),
#  ('mail', 'mail'),
#  ('mail', 'яндекс'),
#  ('яндекс', 'ozon'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'microsoft'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'яндекс'),
#  ('microsoft', 'mail'),
#  ('яндекс', 'microsoft'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail'),
#  ('mail', 'microsoft'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'intel'),
#  ('intel', 'microsoft'),
#  ('intel', 'intel'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'tj'),
#  ('tj', 'microsoft'),
#  ('tj', 'tj'),
#  ('yota', 'yota'),
#  ('yota', 'intel'),
#  ('intel', 'yota'),
#  ('intel', 'intel'),
#  ('мегафон', 'мегафон'),
#  ('мегафон', 'yota'),
#  ('yota', 'мегафон'),
#  ('yota', 'yota'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'gett'),
#  ('gett', 'яндекс'),
#  ('gett', 'gett'),
#  ('мтс', 'мтс'),
#  ('мтс', 'мегафон'),
#  ('мегафон', 'мтс'),
#  ('мегафон', 'мегафон'),
#  ('лайфхакер', 'лайфхакер'),
#  ('лайфхакер', 'spotify'),
#  ('spotify', 'лайфхакер'),
#  ('spotify', 'spotify'),
#  ('gett', 'gett'),
#  ('gett', 'яндекс'),
#  ('яндекс', 'gett'),
#  ('яндекс', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'tj'),
#  ('tj', 'яндекс'),
#  ('tj', 'tj'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('ebay', 'ebay'),
#  ('ebay', 'microsoft'),
#  ('microsoft', 'ebay'),
#  ('microsoft', 'microsoft'),
#  ('mail', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'одноклассники'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'одноклассники'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'яндекс'),
#  ('одноклассники', 'одноклассники'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'вконтакте'),
#  ('вконтакте', 'яндекс'),
#  ('вконтакте', 'вконтакте'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'контур'),
#  ('контур', 'яндекс'),
#  ('контур', 'контур'),
#  ('tj', 'tj'),
#  ('tj', 'пик'),
#  ('пик', 'tj'),
#  ('пик', 'пик'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'microsoft'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail'),
#  ('mail', 'microsoft'),
#  ('microsoft', 'яндекс'),
#  ('microsoft', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'spotify'),
#  ('spotify', 'яндекс'),
#  ('spotify', 'spotify'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('вконтакте', 'вконтакте'),
#  ('вконтакте', 'tj'),
#  ('tj', 'вконтакте'),
#  ('tj', 'tj'),
#  ('вконтакте', 'вконтакте'),
#  ('вконтакте', 'tj'),
#  ('tj', 'вконтакте'),
#  ('tj', 'tj'),
#  ('okko', 'okko'),
#  ('okko', 'ivi'),
#  ('ivi', 'okko'),
#  ('ivi', 'ivi'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'microsoft'),
#  ('microsoft', 'яндекс'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'intel'),
#  ('intel', 'microsoft'),
#  ('intel', 'intel'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'spotify'),
#  ('spotify', 'microsoft'),
#  ('spotify', 'spotify'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'tj'),
#  ('яндекс', 'selectel'),
#  ('яндекс', 'intel'),
#  ('tj', 'яндекс'),
#  ('tj', 'tj'),
#  ('tj', 'selectel'),
#  ('tj', 'intel'),
#  ('selectel', 'яндекс'),
#  ('selectel', 'tj'),
#  ('selectel', 'selectel'),
#  ('selectel', 'intel'),
#  ('intel', 'яндекс'),
#  ('intel', 'tj'),
#  ('intel', 'selectel'),
#  ('intel', 'intel'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'мэйл'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'vk'),
#  ('мэйл', 'mail.ru'),
#  ('мэйл', 'мэйл'),
#  ('мэйл', 'mail'),
#  ('мэйл', 'vk'),
#  ('mail', 'mail.ru'),
#  ('mail', 'мэйл'),
#  ('mail', 'mail'),
#  ('mail', 'vk'),
#  ('vk', 'mail.ru'),
#  ('vk', 'мэйл'),
#  ('vk', 'mail'),
#  ('vk', 'vk'),
#  ('mail', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'spotify'),
#  ('spotify', 'яндекс'),
#  ('spotify', 'spotify'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'авито'),
#  ('яндекс', 'яндекс.маркет'),
#  ('авито', 'яндекс'),
#  ('авито', 'авито'),
#  ('авито', 'яндекс.маркет'),
#  ('яндекс.маркет', 'яндекс'),
#  ('яндекс.маркет', 'авито'),
#  ('яндекс.маркет', 'яндекс.маркет'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'qiwi'),
#  ('qiwi', 'яндекс'),
#  ('qiwi', 'qiwi'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'одноклассники'),
#  ('одноклассники', 'яндекс'),
#  ('одноклассники', 'одноклассники'),
#  ('одноклассники', 'одноклассники'),
#  ('одноклассники', 'вконтакте'),
#  ('вконтакте', 'одноклассники'),
#  ('вконтакте', 'вконтакте'),
#  ('одноклассники', 'одноклассники'),
#  ('одноклассники', 'microsoft'),
#  ('microsoft', 'одноклассники'),
#  ('microsoft', 'microsoft'),
#  ('ozon', 'ozon'),
#  ('ozon', 'microsoft'),
#  ('microsoft', 'ozon'),
#  ('microsoft', 'microsoft'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('intel', 'intel'),
#  ('intel', 'microsoft'),
#  ('microsoft', 'intel'),
#  ('microsoft', 'microsoft'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'tj'),
#  ('tj', 'microsoft'),
#  ('tj', 'tj'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'яндекс.маркет'),
#  ('яндекс.маркет', 'яндекс'),
#  ('яндекс.маркет', 'яндекс.маркет'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'одноклассники'),
#  ('одноклассники', 'яндекс'),
#  ('одноклассники', 'одноклассники'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'яндекс.маркет'),
#  ('яндекс.маркет', 'яндекс'),
#  ('яндекс.маркет', 'яндекс.маркет'),
#  ('vk', 'vk'),
#  ('vk', 'mail.ru'),
#  ('vk', 'mail'),
#  ('mail.ru', 'vk'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'vk'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'mail.ru'),
#  ('microsoft', 'mail'),
#  ('mail.ru', 'microsoft'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'microsoft'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('мегафон', 'мегафон'),
#  ('мегафон', 'ростелеком'),
#  ('ростелеком', 'мегафон'),
#  ('ростелеком', 'ростелеком'),
#  ('вконтакте', 'вконтакте'),
#  ('вконтакте', 'tj'),
#  ('tj', 'вконтакте'),
#  ('tj', 'tj'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('одноклассники', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('action', 'action'),
#  ('action', 'tj'),
#  ('action', 'mail'),
#  ('tj', 'action'),
#  ('tj', 'tj'),
#  ('tj', 'mail'),
#  ('mail', 'action'),
#  ('mail', 'tj'),
#  ('mail', 'mail'),
#  ('lamoda', 'lamoda'),
#  ('lamoda', 'одноклассники'),
#  ('одноклассники', 'lamoda'),
#  ('одноклассники', 'одноклассники'),
#  ('mail', 'mail'),
#  ('mail', 'tj'),
#  ('tj', 'mail'),
#  ('tj', 'tj'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'одноклассники'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('одноклассники', 'яндекс'),
#  ('одноклассники', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('mail', 'mail'),
#  ('mail', 'яндекс'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'одноклассники'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('одноклассники', 'яндекс'),
#  ('одноклассники', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('metro', 'metro'),
#  ('metro', 'mail'),
#  ('mail', 'metro'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'mail.ru'),
#  ('microsoft', 'mail'),
#  ('mail.ru', 'microsoft'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'microsoft'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'яндекс'),
#  ('microsoft', 'mail.ru'),
#  ('microsoft', 'mail'),
#  ('яндекс', 'microsoft'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('mail.ru', 'microsoft'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'microsoft'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'coub'),
#  ('coub', 'яндекс'),
#  ('coub', 'coub'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('boomstarter', 'boomstarter'),
#  ('boomstarter', 'globus'),
#  ('globus', 'boomstarter'),
#  ('globus', 'globus'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'chatfuel'),
#  ('chatfuel', 'яндекс'),
#  ('chatfuel', 'chatfuel'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'яндекс.маркет'),
#  ('яндекс.маркет', 'яндекс'),
#  ('яндекс.маркет', 'яндекс.маркет'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'яндекс.маркет'),
#  ('яндекс.маркет', 'яндекс'),
#  ('яндекс.маркет', 'яндекс.маркет'),
#  ('kwork', 'kwork'),
#  ('kwork', 'яндекс'),
#  ('kwork', 'qiwi'),
#  ('яндекс', 'kwork'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'qiwi'),
#  ('qiwi', 'kwork'),
#  ('qiwi', 'яндекс'),
#  ('qiwi', 'qiwi'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('одноклассники', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'microsoft'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'microsoft'),
#  ('microsoft', 'mail.ru'),
#  ('microsoft', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('tj', 'tj'),
#  ('tj', 'mail.ru'),
#  ('tj', 'mail'),
#  ('mail.ru', 'tj'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'tj'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('yota', 'yota'),
#  ('yota', 'яндекс.маркет'),
#  ('yota', 'яндекс'),
#  ('яндекс.маркет', 'yota'),
#  ('яндекс.маркет', 'яндекс.маркет'),
#  ('яндекс.маркет', 'яндекс'),
#  ('яндекс', 'yota'),
#  ('яндекс', 'яндекс.маркет'),
#  ('яндекс', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'honor'),
#  ('honor', 'microsoft'),
#  ('honor', 'honor'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'honor'),
#  ('honor', 'microsoft'),
#  ('honor', 'honor'),
#  ('ozon', 'ozon'),
#  ('ozon', 'mail.ru'),
#  ('ozon', 'mail'),
#  ('mail.ru', 'ozon'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'ozon'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'honor'),
#  ('honor', 'microsoft'),
#  ('honor', 'honor'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('вконтакте', 'вконтакте'),
#  ('вконтакте', 'fura'),
#  ('fura', 'вконтакте'),
#  ('fura', 'fura'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('metro', 'metro'),
#  ('metro', 'mail.ru'),
#  ('metro', 'mail'),
#  ('mail.ru', 'metro'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'metro'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'одноклассники'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('одноклассники', 'яндекс'),
#  ('одноклассники', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('макс', 'макс'),
#  ('макс', 'mail'),
#  ('mail', 'макс'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'qiwi'),
#  ('яндекс', 'яндекс.маркет'),
#  ('qiwi', 'яндекс'),
#  ('qiwi', 'qiwi'),
#  ('qiwi', 'яндекс.маркет'),
#  ('яндекс.маркет', 'яндекс'),
#  ('яндекс.маркет', 'qiwi'),
#  ('яндекс.маркет', 'яндекс.маркет'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('metro', 'metro'),
#  ('metro', 'mail'),
#  ('mail', 'metro'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('тинькофф', 'тинькофф'),
#  ('тинькофф', 'mail'),
#  ('mail', 'тинькофф'),
#  ('mail', 'mail'),
#  ('gett', 'gett'),
#  ('gett', 'яндекс'),
#  ('яндекс', 'gett'),
#  ('яндекс', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'мэйл'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('мэйл', 'яндекс'),
#  ('мэйл', 'мэйл'),
#  ('мэйл', 'mail.ru'),
#  ('мэйл', 'mail'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'мэйл'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'яндекс'),
#  ('mail', 'мэйл'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('ozon', 'ozon'),
#  ('ozon', 'мегафон'),
#  ('мегафон', 'ozon'),
#  ('мегафон', 'мегафон'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'одноклассники'),
#  ('яндекс', 'ростелеком'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail.ru', 'ростелеком'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('mail', 'ростелеком'),
#  ('одноклассники', 'яндекс'),
#  ('одноклассники', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('одноклассники', 'ростелеком'),
#  ('ростелеком', 'яндекс'),
#  ('ростелеком', 'mail.ru'),
#  ('ростелеком', 'mail'),
#  ('ростелеком', 'одноклассники'),
#  ('ростелеком', 'ростелеком'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('metro', 'metro'),
#  ('metro', 'ривьера'),
#  ('ривьера', 'metro'),
#  ('ривьера', 'ривьера'),
#  ('контур', 'контур'),
#  ('контур', 'microsoft'),
#  ('контур', 'яндекс'),
#  ('контур', 'mail'),
#  ('контур', 'intel'),
#  ('microsoft', 'контур'),
#  ('microsoft', 'microsoft'),
#  ('microsoft', 'яндекс'),
#  ('microsoft', 'mail'),
#  ('microsoft', 'intel'),
#  ('яндекс', 'контур'),
#  ('яндекс', 'microsoft'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'intel'),
#  ('mail', 'контур'),
#  ('mail', 'microsoft'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail'),
#  ('mail', 'intel'),
#  ('intel', 'контур'),
#  ('intel', 'microsoft'),
#  ('intel', 'яндекс'),
#  ('intel', 'mail'),
#  ('intel', 'intel'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'мегафон'),
#  ('мегафон', 'яндекс'),
#  ('мегафон', 'мегафон'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('макс', 'макс'),
#  ('макс', 'coub'),
#  ('coub', 'макс'),
#  ('coub', 'coub'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'spotify'),
#  ('spotify', 'яндекс'),
#  ('spotify', 'spotify'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('вконтакте', 'вконтакте'),
#  ('вконтакте', 'одноклассники'),
#  ('одноклассники', 'вконтакте'),
#  ('одноклассники', 'одноклассники'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('одноклассники', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('metro', 'metro'),
#  ('metro', 'мегафон'),
#  ('мегафон', 'metro'),
#  ('мегафон', 'мегафон'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'gett'),
#  ('gett', 'яндекс'),
#  ('gett', 'gett'),
#  ('okko', 'okko'),
#  ('okko', 'ivi'),
#  ('ivi', 'okko'),
#  ('ivi', 'ivi'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('вконтакте', 'вконтакте'),
#  ('вконтакте', 'mail'),
#  ('вконтакте', 'яндекс'),
#  ('mail', 'вконтакте'),
#  ('mail', 'mail'),
#  ('mail', 'яндекс'),
#  ('яндекс', 'вконтакте'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('boomstarter', 'boomstarter'),
#  ('boomstarter', 'mail'),
#  ('mail', 'boomstarter'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail.ru', 'fura'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('mail', 'fura'),
#  ('одноклассники', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('одноклассники', 'fura'),
#  ('fura', 'mail.ru'),
#  ('fura', 'mail'),
#  ('fura', 'одноклассники'),
#  ('fura', 'fura'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('intel', 'intel'),
#  ('intel', 'microsoft'),
#  ('microsoft', 'intel'),
#  ('microsoft', 'microsoft'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'gett'),
#  ('gett', 'яндекс'),
#  ('gett', 'gett'),
#  ('тинькофф', 'тинькофф'),
#  ('тинькофф', 'яндекс'),
#  ('яндекс', 'тинькофф'),
#  ('яндекс', 'яндекс'),
#  ('mail', 'mail'),
#  ('mail', 'одноклассники'),
#  ('mail', 'mail.ru'),
#  ('одноклассники', 'mail'),
#  ('одноклассники', 'одноклассники'),
#  ('одноклассники', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'одноклассники'),
#  ('mail.ru', 'mail.ru'),
#  ('tj', 'tj'),
#  ('tj', 'комитет'),
#  ('комитет', 'tj'),
#  ('комитет', 'комитет'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('яндекс', 'яндекс'),
#  ('яндекс', 'mail.ru'),
#  ('яндекс', 'mail'),
#  ('яндекс', 'microsoft'),
#  ('mail.ru', 'яндекс'),
#  ('mail.ru', 'mail.ru'),
#  ('mail.ru', 'mail'),
#  ('mail.ru', 'microsoft'),
#  ('mail', 'яндекс'),
#  ('mail', 'mail.ru'),
#  ('mail', 'mail'),
#  ('mail', 'microsoft'),
#  ('microsoft', 'яндекс'),
#  ('microsoft', 'mail.ru'),
#  ('microsoft', 'mail'),
#  ...]

# %%
edges_ = {}
for item in tqdm(edges):
    if item[0] != item[1]:
        if (not (item[0], item[1]) in edges_.keys()) and (not (item[1], item[0]) in edges_.keys()):
            edges_[item] = 0.0
        else:
            if (item[0], item[1]) in edges_.keys():
                edges_[item] += 1.0
            elif (item[1], item[0]) in edges_.keys():
                edges_[(item[1], item[0])] += 1.0
# Out:
# 100%|█████████████████████████████████| 12437/12437 [00:00<00:00, 375443.96it/s]

# %%
edges_
# Out:
# {('mail', 'mail.ru'): 735.0,
#  ('mail', 'qiwi'): 7.0,
#  ('яндекс', 'mail'): 497.0,
#  ('intel', 'microsoft'): 139.0,
#  ('одноклассники', 'ivi'): 15.0,
#  ('microsoft', 'манифест'): 1.0,
#  ('одноклассники', 'вконтакте'): 51.0,
#  ('яндекс', 'яндекс.маркет'): 63.0,
#  ('медиалогия', 'вконтакте'): 1.0,
#  ('ozon', 'mail.ru'): 7.0,
#  ('ozon', 'microsoft'): 11.0,
#  ('ozon', 'mail'): 23.0,
#  ('ozon', 'яндекс'): 61.0,
#  ('mail.ru', 'microsoft'): 27.0,
#  ('mail.ru', 'яндекс'): 211.0,
#  ('microsoft', 'mail'): 65.0,
#  ('microsoft', 'яндекс'): 91.0,
#  ('microsoft', 'tj'): 13.0,
#  ('yota', 'intel'): 3.0,
#  ('мегафон', 'yota'): 25.0,
#  ('яндекс', 'gett'): 67.0,
#  ('мтс', 'мегафон'): 3.0,
#  ('лайфхакер', 'spotify'): 7.0,
#  ('яндекс', 'tj'): 101.0,
#  ('ebay', 'microsoft'): 5.0,
#  ('mail', 'одноклассники'): 207.0,
#  ('яндекс', 'одноклассники'): 149.0,
#  ('яндекс', 'вконтакте'): 73.0,
#  ('яндекс', 'контур'): 11.0,
#  ('tj', 'пик'): 1.0,
#  ('яндекс', 'spotify'): 283.0,
#  ('вконтакте', 'tj'): 13.0,
#  ('okko', 'ivi'): 45.0,
#  ('microsoft', 'spotify'): 47.0,
#  ('яндекс', 'selectel'): 3.0,
#  ('яндекс', 'intel'): 15.0,
#  ('tj', 'selectel'): 1.0,
#  ('tj', 'intel'): 11.0,
#  ('selectel', 'intel'): 1.0,
#  ('mail.ru', 'мэйл'): 3.0,
#  ('mail.ru', 'vk'): 11.0,
#  ('мэйл', 'mail'): 3.0,
#  ('мэйл', 'vk'): 1.0,
#  ('mail', 'vk'): 13.0,
#  ('яндекс', 'авито'): 39.0,
#  ('авито', 'яндекс.маркет'): 1.0,
#  ('яндекс', 'qiwi'): 29.0,
#  ('одноклассники', 'microsoft'): 7.0,
#  ('мегафон', 'ростелеком'): 65.0,
#  ('mail.ru', 'одноклассники'): 109.0,
#  ('action', 'tj'): 7.0,
#  ('action', 'mail'): 1.0,
#  ('tj', 'mail'): 13.0,
#  ('lamoda', 'одноклассники'): 1.0,
#  ('metro', 'mail'): 9.0,
#  ('яндекс', 'coub'): 1.0,
#  ('boomstarter', 'globus'): 1.0,
#  ('яндекс', 'chatfuel'): 1.0,
#  ('kwork', 'яндекс'): 1.0,
#  ('kwork', 'qiwi'): 1.0,
#  ('tj', 'mail.ru'): 5.0,
#  ('yota', 'яндекс.маркет'): 1.0,
#  ('yota', 'яндекс'): 33.0,
#  ('microsoft', 'honor'): 27.0,
#  ('вконтакте', 'fura'): 1.0,
#  ('metro', 'mail.ru'): 1.0,
#  ('макс', 'mail'): 9.0,
#  ('qiwi', 'яндекс.маркет'): 1.0,
#  ('тинькофф', 'mail'): 47.0,
#  ('яндекс', 'мэйл'): 3.0,
#  ('ozon', 'мегафон'): 3.0,
#  ('яндекс', 'ростелеком'): 33.0,
#  ('mail.ru', 'ростелеком'): 19.0,
#  ('mail', 'ростелеком'): 59.0,
#  ('одноклассники', 'ростелеком'): 27.0,
#  ('metro', 'ривьера'): 1.0,
#  ('контур', 'microsoft'): 1.0,
#  ('контур', 'mail'): 3.0,
#  ('контур', 'intel'): 1.0,
#  ('mail', 'intel'): 13.0,
#  ('яндекс', 'мегафон'): 43.0,
#  ('макс', 'coub'): 1.0,
#  ('metro', 'мегафон'): 1.0,
#  ('вконтакте', 'mail'): 19.0,
#  ('boomstarter', 'mail'): 1.0,
#  ('mail.ru', 'fura'): 1.0,
#  ('mail', 'fura'): 1.0,
#  ('одноклассники', 'fura'): 1.0,
#  ('тинькофф', 'яндекс'): 209.0,
#  ('tj', 'комитет'): 99.0,
#  ('uniqlo', 'mail'): 1.0,
#  ('макс', 'яндекс'): 43.0,
#  ('fura', 'яндекс'): 3.0,
#  ('mail', 'мегафон'): 55.0,
#  ('комитет', 'яндекс'): 21.0,
#  ('ebay', 'mail'): 5.0,
#  ('максимателеком', 'яндекс'): 1.0,
#  ('metro', 'vk'): 3.0,
#  ('самокат', 'tj'): 1.0,
#  ('yota', 'mail'): 25.0,
#  ('yota', 'мтс'): 3.0,
#  ('yota', 'одноклассники'): 7.0,
#  ('mail', 'мтс'): 1.0,
#  ('мтс', 'яндекс'): 1.0,
#  ('мтс', 'одноклассники'): 1.0,
#  ('яндекс', 'делимобиль'): 35.0,
#  ('делимобиль', 'gett'): 7.0,
#  ('yota', 'vk'): 5.0,
#  ('yota', 'mail.ru'): 13.0,
#  ('тинькофф', 'fbs'): 1.0,
#  ('тинькофф', 'tj'): 1.0,
#  ('fbs', 'tj'): 1.0,
#  ('tj', 'мастера'): 1.0,
#  ('spotify', 'fbs'): 1.0,
#  ('тинькофф', 'microsoft'): 17.0,
#  ('яндекс.дзен', 'яндекс'): 113.0,
#  ('яндекс', 'okko'): 57.0,
#  ('mail', 'badoo'): 9.0,
#  ('qiwi', 'yota'): 1.0,
#  ('fura', 'microsoft'): 1.0,
#  ('microsoft', 'metro'): 7.0,
#  ('microsoft', 'acer'): 11.0,
#  ('metro', 'acer'): 1.0,
#  ('мегафон', 'microsoft'): 7.0,
#  ('mail.ru', 'мегафон'): 21.0,
#  ('тинькофф', 'точка'): 11.0,
#  ('тинькофф', 'lamoda'): 3.0,
#  ('тинькофф', 'ozon'): 5.0,
#  ('тинькофф', 'россельхозбанк'): 3.0,
#  ('точка', 'lamoda'): 1.0,
#  ('точка', 'ozon'): 1.0,
#  ('точка', 'яндекс'): 7.0,
#  ('точка', 'россельхозбанк'): 1.0,
#  ('lamoda', 'ozon'): 17.0,
#  ('lamoda', 'яндекс'): 17.0,
#  ('lamoda', 'россельхозбанк'): 1.0,
#  ('ozon', 'россельхозбанк'): 1.0,
#  ('яндекс', 'россельхозбанк'): 1.0,
#  ('мегафон', 'райффайзенбанк'): 1.0,
#  ('райффайзенбанк', 'microsoft'): 1.0,
#  ('gett', 'одноклассники'): 3.0,
#  ('simple', 'microsoft'): 1.0,
#  ('вконтакте', 'mail.ru'): 11.0,
#  ('mail.ru', 'мастера'): 1.0,
#  ('mail', 'мастера'): 1.0,
#  ('ivi', 'selectel'): 1.0,
#  ('вконтакте', 'badoo'): 1.0,
#  ('вконтакте', 'ivi'): 1.0,
#  ('яндекс', 'badoo'): 3.0,
#  ('яндекс', 'ivi'): 21.0,
#  ('badoo', 'ivi'): 1.0,
#  ('badoo', 'одноклассники'): 7.0,
#  ('ivi', 'mail'): 13.0,
#  ('тинькофф', 'revolut'): 47.0,
#  ('intel', 'тинькофф'): 5.0,
#  ('microsoft', 'eset'): 1.0,
#  ('yota', 'okko'): 3.0,
#  ('gett', 'mail.ru'): 5.0,
#  ('gett', 'mail'): 5.0,
#  ('макс', 'microsoft'): 3.0,
#  ('tj', 'coub'): 31.0,
#  ('tj', 'одноклассники'): 7.0,
#  ('tj', 'ростелеком'): 19.0,
#  ('spotify', 'tj'): 21.0,
#  ('tj', 'boomstarter'): 3.0,
#  ('acer', 'intel'): 9.0,
#  ('рбк', 'tj'): 1.0,
#  ('одноклассники', 'комитет'): 19.0,
#  ('ростелеком', 'yota'): 31.0,
#  ('gett', 'badoo'): 1.0,
#  ('badoo', 'mail.ru'): 3.0,
#  ('badoo', 'финам'): 3.0,
#  ('mail.ru', 'финам'): 5.0,
#  ('финам', 'mail'): 5.0,
#  ('финам', 'одноклассники'): 1.0,
#  ('spotify', 'mail'): 19.0,
#  ('boomstarter', 'яндекс'): 3.0,
#  ('комитет', 'вконтакте'): 3.0,
#  ('ebay', 'авито'): 5.0,
#  ('тинькофф', 'yota'): 19.0,
#  ('skyeng', 'tj'): 7.0,
#  ('одноклассники', 'мегафон'): 11.0,
#  ('тинькофф', 'mail.ru'): 13.0,
#  ('пик', 'икра'): 1.0,
#  ('россельхозбанк', 'газпромбанк'): 11.0,
#  ('комитет', 'макс'): 3.0,
#  ('didi', 'intel'): 3.0,
#  ('spotify', 'mail.ru'): 9.0,
#  ('мастера', 'microsoft'): 3.0,
#  ('комитет', 'ростелеком'): 19.0,
#  ('mail.ru', 'контур'): 1.0,
#  ('mail.ru', 'медиалогия'): 1.0,
#  ('mail', 'медиалогия'): 1.0,
#  ('контур', 'медиалогия'): 1.0,
#  ('яндекс', 'медиалогия'): 1.0,
#  ('макс', 'одноклассники'): 1.0,
#  ('bright', 'сибур'): 1.0,
#  ('яндекс.драйв', 'яндекс'): 77.0,
#  ('яндекс.драйв', 'делимобиль'): 19.0,
#  ('пик', 'вконтакте'): 1.0,
#  ('тинькофф', 'мтс'): 1.0,
#  ('макс', 'sigur'): 1.0,
#  ('microsoft', 'sigur'): 1.0,
#  ('тинькофф', 'райффайзенбанк'): 15.0,
#  ('модульбанк', 'мегафон'): 1.0,
#  ('модульбанк', 'тинькофф'): 5.0,
#  ('модульбанк', 'ростелеком'): 1.0,
#  ('мегафон', 'тинькофф'): 13.0,
#  ('тинькофф', 'ростелеком'): 7.0,
#  ('mail.ru', 'intel'): 11.0,
#  ('mail.ru', 'qiwi'): 3.0,
#  ('mail.ru', 'acer'): 1.0,
#  ('intel', 'qiwi'): 1.0,
#  ('qiwi', 'acer'): 1.0,
#  ('mail', 'acer'): 1.0,
#  ('тинькофф', 'badoo'): 1.0,
#  ('яндекс', 'рбк'): 1.0,
#  ('рбк', 'mail'): 1.0,
#  ('тинькофф', 'грузовичкоф'): 1.0,
#  ('тинькофф', 'acer'): 3.0,
#  ('яндекс', 'грузовичкоф'): 1.0,
#  ('яндекс', 'acer'): 3.0,
#  ('грузовичкоф', 'acer'): 1.0,
#  ('badoo', 'microsoft'): 3.0,
#  ('vk', 'одноклассники'): 3.0,
#  ('яндекс', 'vk'): 23.0,
#  ('автоваз', 'microsoft'): 1.0,
#  ('mail.ru', 'lamoda'): 1.0,
#  ('mail', 'lamoda'): 9.0,
#  ('комитет', 'рбк'): 1.0,
#  ('яндекс.дзен', 'вконтакте'): 19.0,
#  ('microsoft', 'gett'): 3.0,
#  ('microsoft', 'лайфхакер'): 5.0,
#  ('microsoft', 'skyeng'): 7.0,
#  ('microsoft', 'ivideon'): 1.0,
#  ('microsoft', 'cloudpayments'): 1.0,
#  ('microsoft', 'lingualeo'): 1.0,
#  ('microsoft', 'втб'): 1.0,
#  ('gett', 'лайфхакер'): 1.0,
#  ('gett', 'skyeng'): 3.0,
#  ('gett', 'ivideon'): 1.0,
#  ('gett', 'spotify'): 1.0,
#  ('gett', 'cloudpayments'): 1.0,
#  ('gett', 'lingualeo'): 1.0,
#  ('gett', 'втб'): 1.0,
#  ('лайфхакер', 'skyeng'): 1.0,
#  ('лайфхакер', 'яндекс'): 1.0,
#  ('лайфхакер', 'ivideon'): 1.0,
#  ('лайфхакер', 'cloudpayments'): 1.0,
#  ('лайфхакер', 'lingualeo'): 1.0,
#  ('лайфхакер', 'одноклассники'): 1.0,
#  ('лайфхакер', 'втб'): 1.0,
#  ('skyeng', 'яндекс'): 3.0,
#  ('skyeng', 'ivideon'): 1.0,
#  ('skyeng', 'spotify'): 1.0,
#  ('skyeng', 'cloudpayments'): 1.0,
#  ('skyeng', 'lingualeo'): 1.0,
#  ('skyeng', 'одноклассники'): 5.0,
#  ('skyeng', 'втб'): 1.0,
#  ('яндекс', 'ivideon'): 1.0,
#  ('яндекс', 'cloudpayments'): 1.0,
#  ('яндекс', 'lingualeo'): 1.0,
#  ('яндекс', 'втб'): 1.0,
#  ('ivideon', 'spotify'): 1.0,
#  ('ivideon', 'cloudpayments'): 1.0,
#  ('ivideon', 'lingualeo'): 1.0,
#  ('ivideon', 'одноклассники'): 1.0,
#  ('ivideon', 'втб'): 1.0,
#  ('spotify', 'cloudpayments'): 1.0,
#  ('spotify', 'lingualeo'): 1.0,
#  ('spotify', 'одноклассники'): 9.0,
#  ('spotify', 'втб'): 1.0,
#  ('cloudpayments', 'lingualeo'): 1.0,
#  ('cloudpayments', 'одноклассники'): 1.0,
#  ('cloudpayments', 'втб'): 1.0,
#  ('lingualeo', 'одноклассники'): 1.0,
#  ('lingualeo', 'втб'): 1.0,
#  ('одноклассники', 'втб'): 1.0,
#  ('вконтакте', 'microsoft'): 3.0,
#  ('комитет', 'skyeng'): 1.0,
#  ('комитет', 'gett'): 1.0,
#  ('аскона', 'одноклассники'): 1.0,
#  ('badoo', 'ростелеком'): 1.0,
#  ('макс', 'tj'): 51.0,
#  ('точка', 'tj'): 1.0,
#  ('ozon', 'делимобиль'): 1.0,
#  ('mail.ru', 'комитет'): 3.0,
#  ('комитет', 'mail'): 33.0,
#  ('яндекс', 'цифра'): 3.0,
#  ('цифра', 'microsoft'): 1.0,
#  ('яндекс', 'joom'): 3.0,
#  ('ozon', 'joom'): 1.0,
#  ('комитет', 'intel'): 1.0,
#  ('ebay', 'mail.ru'): 1.0,
#  ('пик', 'microsoft'): 7.0,
#  ('икра', 'spotify'): 1.0,
#  ('макс', 'metro'): 1.0,
#  ('яндекс', 'ситимобил'): 57.0,
#  ('ситимобил', 'mail.ru'): 9.0,
#  ('ситимобил', 'mail'): 41.0,
#  ('ситимобил', 'мегафон'): 3.0,
#  ('яндекс', 'яндекс.услуги'): 5.0,
#  ('tj', 'сибур'): 1.0,
#  ('luxoft', 'mail'): 1.0,
#  ('luxoft', 'яндекс'): 1.0,
#  ('luxoft', 'pixonic'): 1.0,
#  ('mail', 'pixonic'): 1.0,
#  ('яндекс', 'pixonic'): 1.0,
#  ('gett', 'tj'): 1.0,
#  ('финам', 'microsoft'): 1.0,
#  ('делимобиль', 'ситимобил'): 1.0,
#  ('ситимобил', 'gett'): 5.0,
#  ('ситимобил', 'яндекс.драйв'): 3.0,
#  ('gett', 'яндекс.драйв'): 3.0,
#  ('яндекс', 'манифест'): 5.0,
#  ('ростелеком', 'райффайзенбанк'): 1.0,
#  ('ebay', 'макс'): 1.0,
#  ('ebay', 'яндекс'): 3.0,
#  ('авито', 'макс'): 1.0,
#  ('яндекс.драйв', 'яндекс.дзен'): 1.0,
#  ('яндекс.дзен', 'mail.ru'): 3.0,
#  ('яндекс.дзен', 'mail'): 3.0,
#  ('yota', 'tj'): 29.0,
#  ('вконтакте', 'intel'): 1.0,
#  ('яндекс.дзен', 'одноклассники'): 3.0,
#  ('тинькофф', 'gett'): 1.0,
#  ('тинькофф', 'ivi'): 1.0,
#  ('gett', 'ivi'): 1.0,
#  ('gett', 'ozon'): 3.0,
#  ('ivi', 'ozon'): 1.0,
#  ('spotify', 'vk'): 9.0,
#  ('mail', 'авито'): 7.0,
#  ('яндекс.дзен', 'intel'): 1.0,
#  ('qiwi', 'revolut'): 1.0,
#  ('яндекс', 'яндекс.шеф'): 13.0,
#  ('яндекс.драйв', 'spotify'): 1.0,
#  ('комитет', 'microsoft'): 7.0,
#  ('яндекс', 'honor'): 19.0,
#  ('одноклассники', 'honor'): 3.0,
#  ('honor', 'яндекс.шеф'): 1.0,
#  ('okko', 'мегафон'): 13.0,
#  ('okko', 'яндекс.драйв'): 3.0,
#  ('okko', 'mail.ru'): 7.0,
#  ('okko', 'mail'): 35.0,
#  ('яндекс.драйв', 'mail.ru'): 1.0,
#  ('яндекс.драйв', 'mail'): 1.0,
#  ('тинькофф', 'вконтакте'): 1.0,
#  ('ростелеком', 'microsoft'): 27.0,
#  ('яндекс.драйв', 'яндекс.шеф'): 1.0,
#  ('intel', 'honor'): 13.0,
#  ('metro', 'tj'): 1.0,
#  ('спортмастер', 'мегафон'): 1.0,
#  ('яндекс', 'яндекс.лавка'): 37.0,
#  ('яндекс', 'райффайзенбанк'): 3.0,
#  ('сбер', 'мегафон'): 13.0,
#  ('metro', 'пик'): 9.0,
#  ('bright', 'логомашина'): 1.0,
#  ('яндекс', 'столото'): 5.0,
#  ('точка', 'metro'): 1.0,
#  ('okko', 'ситимобил'): 25.0,
#  ('okko', 'яндекс.маркет'): 1.0,
#  ('ситимобил', 'яндекс.маркет'): 1.0,
#  ('яндекс.маркет', 'mail'): 1.0,
#  ('winstrike', 'одноклассники'): 1.0,
#  ('столото', 'ситимобил'): 1.0,
#  ('столото', 'mail'): 1.0,
#  ('столото', 'ростелеком'): 1.0,
#  ('столото', 'yota'): 1.0,
#  ('ситимобил', 'ростелеком'): 1.0,
#  ('ситимобил', 'yota'): 1.0,
#  ('bright', 'honor'): 1.0,
#  ('точка', 'яндекс.дзен'): 1.0,
#  ('точка', 'авито'): 1.0,
#  ('яндекс.дзен', 'авито'): 1.0,
#  ('tj', 'winstrike'): 1.0,
#  ('coub', 'winstrike'): 1.0,
#  ('одноклассники', 'райффайзенбанк'): 3.0,
#  ('газпромбанк', 'райффайзенбанк'): 7.0,
#  ('whoosh', 'самокат'): 5.0,
#  ('whoosh', 'яндекс'): 11.0,
#  ('самокат', 'яндекс'): 19.0,
#  ('versus.legal', 'контур'): 1.0,
#  ('яндекс', 'модульбанк'): 3.0,
#  ('точка', 'модульбанк'): 1.0,
#  ('metro', 'сбер'): 1.0,
#  ('mail', 'сбер'): 33.0,
#  ('spotify', 'honor'): 1.0,
#  ('вконтакте', 'skyeng'): 1.0,
#  ('bright', 'делимобиль'): 1.0,
#  ('bright', 'microsoft'): 3.0,
#  ('делимобиль', 'microsoft'): 1.0,
#  ('газпромбанк', 'mail.ru'): 1.0,
#  ('газпромбанк', 'mail'): 3.0,
#  ('райффайзенбанк', 'россельхозбанк'): 3.0,
#  ('райффайзенбанк', 'mail.ru'): 1.0,
#  ('райффайзенбанк', 'mail'): 5.0,
#  ('россельхозбанк', 'mail.ru'): 1.0,
#  ('россельхозбанк', 'mail'): 1.0,
#  ('spotify', 'intel'): 1.0,
#  ('вконтакте', 'spotify'): 5.0,
#  ('вконтакте', 'vk'): 13.0,
#  ('вконтакте', 'ozon'): 1.0,
#  ('ozon', 'одноклассники'): 5.0,
#  ('макс', 'spotify'): 7.0,
#  ('сбер', 'цифра'): 1.0,
#  ('комитет', 'coub'): 31.0,
#  ('мегафон', 'цифра'): 1.0,
#  ('okko', 'spotify'): 3.0,
#  ('ivi', 'spotify'): 1.0,
#  ('яндекс', 'ингосстрах'): 1.0,
#  ('mail.ru', 'didi'): 1.0,
#  ('intel', 'ситимобил'): 1.0,
#  ('intel', 'gett'): 1.0,
#  ('ситимобил', 'microsoft'): 1.0,
#  ('ситимобил', 'didi'): 1.0,
#  ('microsoft', 'didi'): 1.0,
#  ('gett', 'didi'): 1.0,
#  ('didi', 'mail'): 1.0,
#  ('didi', 'яндекс'): 1.0,
#  ('столото', 'qiwi'): 1.0,
#  ('metro', 'тинькофф'): 5.0,
#  ('макс', 'ростелеком'): 1.0,
#  ('мтс', 'honor'): 1.0,
#  ('simple', 'яндекс.дзен'): 1.0,
#  ('simple', 'яндекс'): 5.0,
#  ('тинькофф', 'втб'): 1.0,
#  ('пик', 'цифра'): 1.0,
#  ('тинькофф', 'инвитро'): 1.0,
#  ('инвитро', 'яндекс'): 7.0,
#  ('badoo', 'tiktok'): 1.0,
#  ('microsoft', 'tiktok'): 1.0,
#  ('setters', 'spotify'): 1.0,
#  ('комитет', 'манифест'): 1.0,
#  ('сбис', 'ростелеком'): 1.0,
#  ('тинькофф', 'газпромбанк'): 3.0,
#  ('пик', 'intel'): 1.0,
#  ('комитет', 'сбер'): 7.0,
#  ('microsoft', 'ivi'): 1.0,
#  ('honor', 'тинькофф'): 5.0,
#  ('тинькофф', 'одноклассники'): 3.0,
#  ('okko', 'ростелеком'): 1.0,
#  ('ivi', 'ростелеком'): 1.0,
#  ('setters', 'яндекс'): 1.0,
#  ('okko', 'одноклассники'): 11.0,
#  ('яндекс', 'сбермаркет'): 1.0,
#  ('okko', 'яндекс.лавка'): 1.0,
#  ('okko', 'сбермаркет'): 1.0,
#  ('ситимобил', 'яндекс.лавка'): 1.0,
#  ('ситимобил', 'ivi'): 1.0,
#  ('ситимобил', 'сбермаркет'): 5.0,
#  ('яндекс.драйв', 'яндекс.лавка'): 1.0,
#  ('яндекс.драйв', 'ivi'): 1.0,
#  ('яндекс.драйв', 'сбермаркет'): 1.0,
#  ('яндекс.лавка', 'ivi'): 1.0,
#  ('яндекс.лавка', 'сбермаркет'): 1.0,
#  ('ivi', 'сбермаркет'): 1.0,
#  ('бланк', 'комитет'): 5.0,
#  ('qiwi', 'тинькофф'): 3.0,
#  ('qiwi', 'metro'): 1.0,
#  ('geekbrains', 'microsoft'): 1.0,
#  ('semrush', 'яндекс'): 1.0,
#  ('ситимобил', 'модульбанк'): 1.0,
#  ('ситимобил', 'spotify'): 1.0,
#  ('ситимобил', 'одноклассники'): 1.0,
#  ('модульбанк', 'spotify'): 1.0,
#  ('модульбанк', 'mail'): 1.0,
#  ('модульбанк', 'одноклассники'): 1.0,
#  ('самокат', 'mail'): 33.0,
#  ('ситимобил', 'tj'): 1.0,
#  ('microsoft', 'action'): 3.0,
#  ('пик', 'яндекс'): 9.0,
#  ('пик', 'самокат'): 1.0,
#  ('пик', 'яндекс.лавка'): 1.0,
#  ('самокат', 'яндекс.лавка'): 1.0,
#  ('honor', 'acer'): 1.0,
#  ('heineken', 'microsoft'): 1.0,
#  ('авито', 'мастера'): 3.0,
#  ('тинькофф', 'уралсиб'): 1.0,
#  ('тнт', 'вконтакте'): 1.0,
#  ('авито', 'тинькофф'): 3.0,
#  ('yota', 'microsoft'): 3.0,
#  ('okko', 'vk'): 1.0,
#  ('okko', 'microsoft'): 3.0,
#  ('vk', 'microsoft'): 7.0,
#  ('яндекс.дзен', 'vk'): 1.0,
#  ('авиасейлс', 'яндекс'): 1.0,
#  ('action', 'intel'): 1.0,
#  ('циан', 'яндекс'): 1.0,
#  ('циан', 'mail'): 1.0,
#  ('яндекс', 'мастера'): 3.0,
#  ('яндекс.дзен', 'мастера'): 1.0,
#  ('ростелеком', 'сибур'): 1.0,
#  ('комитет', 'selectel'): 1.0,
#  ('selectel', 'mail.ru'): 1.0,
#  ('selectel', 'mail'): 1.0,
#  ('skillbox', 'mail'): 3.0,
#  ('skillbox', 'яндекс'): 1.0,
#  ('microsoft', 'яндекс.маркет'): 1.0,
#  ('honor', 'яндекс.маркет'): 1.0,
#  ('тинькофф', 'ситимобил'): 1.0,
#  ('qiwi', 'одноклассники'): 1.0,
#  ('qiwi', 'райффайзенбанк'): 3.0,
#  ('пик', 'тинькофф'): 1.0,
#  ('яндекс', 'сбер'): 81.0,
#  ('gett', 'яндекс.маркет'): 1.0,
#  ('gett', 'lamoda'): 1.0,
#  ('яндекс.маркет', 'lamoda'): 5.0,
#  ('яндекс.маркет', 'ozon'): 11.0,
#  ('yota', 'spotify'): 11.0,
#  ('мегафон', 'spotify'): 1.0,
#  ('spotify', 'selectel'): 1.0,
#  ('сбер', 'сберзвук'): 5.0,
#  ('сбер', 'самокат'): 31.0,
#  ('сбер', 'okko'): 43.0,
#  ('сбер', 'lamoda'): 7.0,
#  ('сбер', 'ozon'): 11.0,
#  ('сбер', 'макс'): 7.0,
#  ('сберзвук', 'самокат'): 5.0,
#  ('сберзвук', 'mail'): 5.0,
#  ('сберзвук', 'okko'): 5.0,
#  ('сберзвук', 'lamoda'): 5.0,
#  ('сберзвук', 'ozon'): 5.0,
#  ('сберзвук', 'макс'): 5.0,
#  ('сберзвук', 'яндекс'): 5.0,
#  ('самокат', 'okko'): 25.0,
#  ('самокат', 'lamoda'): 5.0,
#  ('самокат', 'ozon'): 5.0,
#  ('самокат', 'макс'): 5.0,
#  ('okko', 'lamoda'): 5.0,
#  ('okko', 'ozon'): 5.0,
#  ('okko', 'макс'): 5.0,
#  ('lamoda', 'макс'): 5.0,
#  ('ozon', 'макс'): 5.0,
#  ('авито', 'yota'): 11.0,
#  ('vk', 'tj'): 9.0,
#  ('контур', 'газпромбанк'): 3.0,
#  ('тинькофф', 'joom'): 3.0,
#  ('qiwi', 'joom'): 1.0,
#  ('joom', 'райффайзенбанк'): 1.0,
#  ('пик', 'honor'): 1.0,
#  ('поселок', 'vk'): 1.0,
#  ('комитет', 'контур'): 1.0,
#  ('точка', 'yota'): 3.0,
#  ('microsoft', 'revolut'): 5.0,
#  ('mail', 'revolut'): 5.0,
#  ('revolut', 'яндекс'): 41.0,
#  ('ситимобил', 'сбер'): 25.0,
#  ('ситимобил', 'самокат'): 35.0,
#  ('мегафон', 'самокат'): 1.0,
#  ('tj', 'skillfactory'): 5.0,
#  ('skillfactory', 'ростелеком'): 5.0,
#  ('skillfactory', 'skyeng'): 5.0,
#  ('ростелеком', 'skyeng'): 5.0,
#  ('mail.ru', 'яндекс.лавка'): 1.0,
#  ('mail', 'яндекс.лавка'): 1.0,
#  ('сбер', 'honor'): 13.0,
#  ('сбер', 'сбермаркет'): 1.0,
#  ('тинькофф', 'сбер'): 23.0,
#  ('мегафон', 'waves'): 5.0,
#  ('tj', 'логомашина'): 3.0,
#  ('okko', 'tj'): 27.0,
#  ('skillbox', 'сбер'): 1.0,
#  ('honor', 'mail'): 9.0,
#  ('тинькофф', 'самокат'): 9.0,
#  ('мегафон', 'honor'): 7.0,
#  ('россельхозбанк', 'сбер'): 3.0,
#  ('сбер', 'газпромбанк'): 1.0,
#  ('сбер', 'райффайзенбанк'): 1.0,
#  ('тинькофф', 'skillbox'): 3.0,
#  ('сбер', 'ivi'): 7.0,
#  ('сбер', 'одноклассники'): 7.0,
#  ('мегафон', 'ivi'): 7.0,
#  ('intel', 'макс'): 5.0,
#  ('вконтакте', 'wise'): 1.0,
#  ('вконтакте', 'metro'): 1.0,
#  ('ozon', 'skyeng'): 5.0,
#  ('сбер', 'инвитро'): 3.0,
#  ('okko', 'metro'): 1.0,
#  ('metro', 'яндекс'): 3.0,
#  ('манифест', 'action'): 5.0,
#  ('вконтакте', 'яндекс.маркет'): 1.0,
#  ('сбер', 'microsoft'): 9.0,
#  ('сбер', 'mail.ru'): 3.0,
#  ('сбер', 'intel'): 3.0,
#  ('honor', 'mail.ru'): 3.0,
#  ('сбер', 'yota'): 1.0,
#  ('мегафон', 'макс'): 1.0,
#  ('тинькофф', 'макс'): 1.0,
#  ('макс', 'mail.ru'): 1.0,
#  ('wise', 'тинькофф'): 31.0,
#  ('wise', 'revolut'): 31.0,
#  ('wise', 'яндекс'): 31.0,
#  ('eset', 'яндекс'): 1.0,
#  ('timeless', 'spotify'): 17.0,
#  ('яндекс', 'yandex.cloud'): 1.0,
#  ('мастера', 'макс'): 1.0,
#  ('яндекс.лавка', 'макс'): 1.0,
#  ('фоксфорд', 'учи.ру'): 1.0,
#  ('яндекс', 'aitarget'): 1.0,
#  ('мегафон', 'газпромбанк'): 1.0,
#  ('газпромбанк', 'яндекс'): 1.0,
#  ('газпромбанк', 'ростелеком'): 1.0,
#  ('тинькофф', 'spotify'): 3.0,
#  ('revolut', 'spotify'): 3.0,
#  ('комитет', 'точка'): 9.0,
#  ('макс', 'wise'): 1.0,
#  ('spotify', 'пик'): 3.0,
#  ('simple', 'ozon'): 3.0,
#  ('simple', 'авито'): 3.0,
#  ('simple', 'mail'): 3.0,
#  ('ozon', 'авито'): 7.0,
#  ('тинькофф', 'skillfactory'): 1.0,
#  ('skillfactory', 'skillbox'): 1.0,
#  ('ситимобил', 'вконтакте'): 1.0,
#  ('yota', 'макс'): 13.0,
#  ('комитет', 'whoosh'): 1.0,
#  ('okko', 'контур'): 1.0,
#  ('пик', 'сбер'): 1.0,
#  ('пик', 'ozon'): 1.0,
#  ('metro', 'intel'): 1.0,
#  ('ситимобил', 'whoosh'): 7.0,
#  ('самокат', 'metro'): 1.0,
#  ('whoosh', 'ozon'): 3.0,
#  ('whoosh', 'одноклассники'): 3.0,
#  ('точка', 'райффайзенбанк'): 1.0,
#  ('сбер', 'яндекс.маркет'): 1.0,
#  ('макс', 'пик'): 1.0,
#  ('spotify', 'wise'): 5.0,
#  ('комитет', 'honor'): 5.0,
#  ('вконтакте', 'авито'): 1.0,
#  ('тнт', 'tj'): 13.0}

# %%
G = nx.Graph()
for key in edges_.keys():
    G.add_weighted_edges_from([(key[0], key[1], edges_[key])])

# %%
degrees = dict(networkx.degree(G))
networkx.set_node_attributes(G, name='degree', values=degrees)

# %%
number_to_adjust_by = 3
adjusted_node_size = dict([(node, degree+number_to_adjust_by) for node, degree in networkx.degree(G)])
networkx.set_node_attributes(G, name='adjusted_node_size', values=adjusted_node_size)

# %%
from networkx.algorithms import community
communities = community.greedy_modularity_communities(G, weight='weight', resolution=0.8)

# %%
# Create empty dictionaries
modularity_class = {}
modularity_color = {}
colors = (
'#3288bd',
'#66c2a5',
'#abdda4',
'#e6f598',
'#fee08b',
'#fdae61',
'#f46d43',
'#d53e4f',   
'#8c2d04',
)
#Loop through each community in the network
for community_number, community in enumerate(communities[:8]):
    #For each member of the community, add their community number and a distinct color
    for name in community: 
        modularity_class[name] = community_number
        modularity_color[name] = colors[community_number]

# %%
networkx.set_node_attributes(G, modularity_class, 'modularity_class')
networkx.set_node_attributes(G, modularity_color, 'modularity_color')

# %%
#Choose colors for node and edge highlighting
node_highlight_color = 'white'
edge_highlight_color = 'black'
edge_color = 'gray'

#Choose attributes from G network to size and color by — setting manual size (e.g. 10) or color (e.g. 'skyblue') also allowed
size_by_this_attribute = 'adjusted_node_size'
color_by_this_attribute = 'modularity_color'

#Pick a color palette — Blues8, Reds8, Purples8, Oranges8, Viridis8
color_palette = Blues8

#Choose a title!
title = 'Companies graph'


#Establish which categories will appear when hovering over each node
HOVER_TOOLTIPS = [
       ("Companies", "@index"),
        ("Degree", "@degree"),
         ("Modularity Class", "@modularity_class"),
      #  ("Modularity Color", "$color[swatch]:modularity_color"),
]

#Create a plot — set dimensions, toolbar, and title
plot = figure(tooltips = HOVER_TOOLTIPS,
              tools="pan,wheel_zoom,save,reset", active_scroll='wheel_zoom',
            x_range=Range1d(-10.1, 10.1), y_range=Range1d(-10.1, 10.1), title=title)

#Create a network graph object
# https://networkx.github.io/documentation/networkx-1.9/reference/generated/networkx.drawing.layout.spring_layout.html
network_graph = from_networkx(G, networkx.spring_layout, scale=10, center=(0, 0))

#Set node sizes and colors according to node degree (color as category from attribute)
network_graph.node_renderer.glyph = Circle(size=size_by_this_attribute, fill_color=color_by_this_attribute)



#Set node highlight colors
network_graph.node_renderer.hover_glyph = Circle(size=size_by_this_attribute, fill_color=node_highlight_color, line_width=2)
network_graph.node_renderer.selection_glyph = Circle(size=size_by_this_attribute, fill_color=node_highlight_color, line_width=2)

#Set edge opacity and width
network_graph.edge_renderer.glyph = MultiLine(line_alpha=0.3, line_color=edge_color, line_width=1)
#Set edge highlight colors
network_graph.edge_renderer.selection_glyph = MultiLine(line_color=edge_highlight_color, line_width=2)
network_graph.edge_renderer.hover_glyph = MultiLine(line_color=edge_highlight_color, line_width=2)

#Highlight nodes and edges
network_graph.selection_policy = NodesAndLinkedEdges()
network_graph.inspection_policy = NodesAndLinkedEdges()

plot.renderers.append(network_graph)

#Add Labels
x, y = zip(*network_graph.layout_provider.graph_layout.values())
node_labels = list(G.nodes())
source = ColumnDataSource({'x': x, 'y': y, 'name': [node_labels[i] for i in range(len(x))]})
labels = LabelSet(x='x', y='y', text='name', source=source, background_fill_color='white', text_font_size='10px', background_fill_alpha=.7)
plot.renderers.append(labels)

show(plot)
#save(plot, filename=f"{title}.html")

# %%
with open('edges_vc.pkl', 'wb') as f:
    pickle.dump(edges, f)

# %%
with open('edges_vc_.pkl', 'wb') as f:
    pickle.dump(edges_, f)

# %%
len(G.nodes)
# Out:
# 116

# %%
len(G.edges)
# Out:
# 631
